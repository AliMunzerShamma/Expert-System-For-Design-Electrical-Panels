# %% [markdown]
# # Packges -.-

# %%
from pyknow import *

from tkinter import *
from tkinter import ttk
import tkinter as tk

# %% [markdown]
# # Facts Classes -.-

# %%
class Horse_Power_B_200_220(Fact):
    pass

class Horse_Power_B_380(Fact):
    pass

class Horse_Power_B_415(Fact):
    pass

class Horse_Power_A_200_220(Fact):
    pass

class Horse_Power_A_380(Fact):
    pass

class Horse_Power_A_415(Fact):
    pass

class Volt(Fact):
    pass

class Boot_type(Fact):
    pass

class motor_full_load_current(Fact):
    pass

class heater_designation(Fact):
    pass

class Horse_Power(Fact):
    pass

class Fuse_VDE0660_9T_Time_delay(Fact):
    pass

class Type_designation_of_Contactor_MCM_and_MCD (Fact):
    pass

class Type_designation_of_Contactor_MCS (Fact):
    pass

class Type_designation_of_Magnetic_Startar (Fact):
    pass
A='motor full load current : '
cA='type designation of Magnetic Starter    MS-K : '
AA='associated thermal overload relay    TH-K : '
c='type designation of contactor MCM and MCD S-K : '
c1='type designation of contactor MCS S-K : '
KP='type designation of thermal overload relay TH-K : '
A1='heater designation :  '
A2='fuse (VDE0660 gT time-delay) : '
N='MCCB     NF : '
A3='operating current rating : '
m='wire size recommended (Line side)* : '
m1='(Load side)** : '

# %% [markdown]
# # KnowledgeEngine Class -.-

# %%
class Board_Design(KnowledgeEngine):
    MCCB_A =''
    FUSE_A =''
    MS_A =''
    OLR_A = ''
    MOTOR_A = ''
    TEXE_A_HP = ''
    TEXT_A_A = ''
    TEXT_A_cA = ''
    TEXT_A_AA = ''
    TEXT_A_A1 = ''
    TEXT_A_A2 = ''
    TEXT_A_N = ''
    TEXT_A_A3 = ''
    TEXT_A_m = ''
    
    MCCB_B = ''
    FUSE_B = ''
    OLR_B = ''
    MCM_B_MCD = ''
    MCS_B = ''
    MOTOR_B = ''
    TEXT_B_HP = ''
    TEXT_B_A = ''
    TEXT_B_C = ''
    TEXT_B_C1 = ''
    TEXT_B_KP = ''
    TEXT_B_A1 = ''
    TEXT_B_A2 = ''
    TEXT_B_N = ''
    TEXT_B_A3 = ''
    TEXT_B_m = ''
    TEXT_B_m1 = ''
#_________________________________________________________________________________________________________________________________
#                                                        B V:200 -> 220
#_________________________________________________________________________________________________________________________________

    @Rule (Horse_Power_B_200_220('220'))
    def Horse_Power_B_200_220_220(Self):
        print('220')
        print(A + ' 520 A')
        print(c + ' 300')
        print(c1 + ' 105')
        print(KP + ' 600+CT KP')
        print(A1 + ' 500 A')
        print(A2 + ' 630 A')
        print(N + ' 800-SS')
        print(A3 + ' 800 A')
        print(m + ' 240 mm^2')
        print(m1 + ' 185 mm^2')
        #VAR___________________________________________
        Board_Design.MCCB_B = ' 800-SS'
        Board_Design.FUSE_B = ' 630 A'
        Board_Design.OLR_B = ' 600+CT KP'
        Board_Design.MCM_B_MCD = ' 300'
        Board_Design.MCS_B = ' 105'
        Board_Design.MOTOR_B = ' 520 A'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '220'
        Board_Design.TEXT_B_A = A + ' 520 A'
        Board_Design.TEXT_B_C = c + ' 300'
        Board_Design.TEXT_B_C1 = c1 + ' 105'
        Board_Design.TEXT_B_KP = KP + ' 600+CT KP'
        Board_Design.TEXT_B_A1 = A1 + ' 500 A'
        Board_Design.TEXT_B_A2 = A2 + ' 630 A'
        Board_Design.TEXT_B_N = N + ' 800-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 800 A'
        Board_Design.TEXT_B_m = m + ' 240 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 185 mm^2'
        
    @Rule (Horse_Power_B_200_220('180'))
    def Horse_Power_B_200_220_180(Self):
        print('180')
        print(A + ' 420 A')
        print(c + ' 300')
        print(c1 + ' 105')
        print(KP + ' 600+CT KP')
        print(A1 + ' 500 A')
        print(A2 + ' 500 A')
        print(N + ' 800-SS')
        print(A3 + ' 700 A')
        print(m + ' 185 mm^2')
        print(m1 + ' 120 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 420 A'
        Board_Design.MCM_B_MCD = ' 300'
        Board_Design.MCS_B = ' 105'
        Board_Design.OLR_B = ' 600+CT KP'
        Board_Design.FUSE_B = ' 500 A'
        Board_Design.MCCB_B = ' 800-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '180'
        Board_Design.TEXT_B_A = A + ' 420 A'
        Board_Design.TEXT_B_C = c + ' 300'
        Board_Design.TEXT_B_C1 = c1 + ' 105'
        Board_Design.TEXT_B_KP = KP + ' 600+CT KP'
        Board_Design.TEXT_B_A1 = A1 + ' 500 A'
        Board_Design.TEXT_B_A2 = A2 + ' 500 A'
        Board_Design.TEXT_B_N = N + ' 800-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 700 A'
        Board_Design.TEXT_B_m = m + ' 185 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 120 mm^2'
        
    @Rule (Horse_Power_B_200_220('150'))
    def Horse_Power_B_200_220_150(Self):
        print('150')
        print(A + ' 350 A')
        print(c + ' 220')
        print(c1 + ' 80')
        print(KP + ' 400HZ KP')
        print(A1 + ' 330 A')
        print(A2 + ' 400 A')
        print(N + ' 630-SS')
        print(A3 + ' 600 A')
        print(m + ' 150 mm^2')
        print(m1 + ' 95 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 350 A'
        Board_Design.MCM_B_MCD = ' 220'
        Board_Design.MCS_B = ' 80'
        Board_Design.OLR_B = ' 400HZ KP'
        Board_Design.FUSE_B = ' 400 A'
        Board_Design.MCCB_B = ' 630-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '150'
        Board_Design.TEXT_B_A = A + ' 350 A'
        Board_Design.TEXT_B_C = c + ' 220'
        Board_Design.TEXT_B_C1 = c1 + ' 80'
        Board_Design.TEXT_B_KP = KP + ' 400HZ KP'
        Board_Design.TEXT_B_A1 = A1 + ' 330 A'
        Board_Design.TEXT_B_A2 = A2 + ' 400 A'
        Board_Design.TEXT_B_N = N + ' 630-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 600 A'
        Board_Design.TEXT_B_m = m + ' 150 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 95 mm^2'
        
    @Rule (Horse_Power_B_200_220('125'))
    def Horse_Power_B_200_220_125(Self):
        print('125')
        print(A + ' 295 A')
        print(c + ' 180')
        print(c1 + ' 65')
        print(KP + ' 400HZ KP')
        print(A1 + ' 250 A')
        print(A2 + ' 400 A')
        print(N + ' 630-SS')
        print(A3 + ' 400 A')
        print(m + ' 150 mm^2')
        print(m1 + ' 70 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 295 A'
        Board_Design.MCM_B_MCD = ' 180'
        Board_Design.MCS_B = ' 65'
        Board_Design.OLR_B = ' 400HZ KP'
        Board_Design.FUSE_B = ' 400 A'
        Board_Design.MCCB_B = ' 630-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '125'
        Board_Design.TEXT_B_A = A + ' 295 A'
        Board_Design.TEXT_B_C = c + ' 180'
        Board_Design.TEXT_B_C1 = c1 + ' 65'
        Board_Design.TEXT_B_KP = KP + ' 400HZ KP'
        Board_Design.TEXT_B_A1 = A1 + ' 250 A'
        Board_Design.TEXT_B_A2 = A2 + ' 400 A'
        Board_Design.TEXT_B_N = N + ' 630-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 400 A'
        Board_Design.TEXT_B_m = m + ' 150 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 70 mm^2'
        
    @Rule (Horse_Power_B_200_220('100'))
    def Horse_Power_B_200_220_100(Self):
        print('100')
        print(A + ' 245 A')
        print(c + ' 150')
        print(c1 + ' 50')
        print(KP + ' 220HZ KP')
        print(A1 + ' 210 A')
        print(A2 + ' 315 A')
        print(N + ' 400-SS')
        print(A3 + ' 400 A')
        print(m + ' 150 mm^2')
        print(m1 + ' 50 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 245 A'
        Board_Design.MCM_B_MCD = ' 150'
        Board_Design.MCS_B = ' 50'
        Board_Design.OLR_B = ' 220HZ KP'
        Board_Design.FUSE_B = ' 315 A'
        Board_Design.MCCB_B = ' 400-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '100'
        Board_Design.TEXT_B_A = A + ' 245 A'
        Board_Design.TEXT_B_C = c + ' 150'
        Board_Design.TEXT_B_C1 = c1 + ' 50'
        Board_Design.TEXT_B_KP = KP + ' 220HZ KP'
        Board_Design.TEXT_B_A1 = A1 + ' 210 A'
        Board_Design.TEXT_B_A2 = A2 + ' 315 A'
        Board_Design.TEXT_B_N = N + ' 400-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 400 A'
        Board_Design.TEXT_B_m = m + ' 150 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 50 mm^2'
        
    @Rule (Horse_Power_B_200_220('85'))
    def Horse_Power_B_200_220_85(Self):
        print('85')
        print(A + ' 202 A')
        print(c + ' 125')
        print(c1 + ' 50')
        print(KP + ' 220HZ KP')
        print(A1 + ' 180 A')
        print(A2 + ' 250 A')
        print(N + ' 400-SS')
        print(A3 + ' 300 A')
        print(m + ' 95 mm^2')
        print(m1 + ' 35 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 202 A'
        Board_Design.MCM_B_MCD = ' 125'
        Board_Design.MCS_B = ' 50'
        Board_Design.OLR_B = ' 220HZ KP'
        Board_Design.FUSE_B = ' 250 A'
        Board_Design.MCCB_B = ' 400-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '85'
        Board_Design.TEXT_B_A = A + ' 202 A'
        Board_Design.TEXT_B_C = c + ' 125'
        Board_Design.TEXT_B_C1 = c1 + ' 50'
        Board_Design.TEXT_B_KP = KP + ' 220HZ KP'
        Board_Design.TEXT_B_A1 = A1 + ' 180 A'
        Board_Design.TEXT_B_A2 = A2 + ' 250 A'
        Board_Design.TEXT_B_N = N + ' 400-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 300 A'
        Board_Design.TEXT_B_m = m + ' 95 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 35 mm^2'
        
    @Rule (Horse_Power_B_200_220('75'))
    def Horse_Power_B_200_220_75(Self):
        print('75')
        print(A + ' 180 A')
        print(c + ' 105')
        print(c1 + ' 35')
        print(KP + ' 220HZ KP')
        print(A1 + ' 150 A')
        print(A2 + ' 220 A')
        print(N + ' 400-SS')
        print(A3 + ' 300 A')
        print(m + ' 95 mm^2')
        print(m1 + ' 35 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 180 A'
        Board_Design.MCM_B_MCD = ' 105'
        Board_Design.MCS_B = ' 35'
        Board_Design.OLR_B = ' 220HZ KP'
        Board_Design.FUSE_B = ' 220 A'
        Board_Design.MCCB_B = ' 400-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '75'
        Board_Design.TEXT_B_A = A + ' 180 A'
        Board_Design.TEXT_B_C = c + ' 105'
        Board_Design.TEXT_B_C1 = c1 + ' 35'
        Board_Design.TEXT_B_KP = KP + ' 220HZ KP'
        Board_Design.TEXT_B_A1 = A1 + ' 150 A'
        Board_Design.TEXT_B_A2 = A2 + ' 220 A'
        Board_Design.TEXT_B_N = N + ' 400-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 300 A'
        Board_Design.TEXT_B_m = m + ' 95 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 35 mm^2'
        
    @Rule (Horse_Power_B_200_220('60'))
    def Horse_Power_B_200_220_60(Self):
        print('60')
        print(A + ' 148 A')
        print(c + ' 80')
        print(c1 + ' 25')
        print(KP + ' 120TA KP')
        print(A1 + ' 125 A')
        print(A2 + ' 200 A')
        print(N + ' 250-SS')
        print(A3 + ' 250 A')
        print(m + ' 70 mm^2')
        print(m1 + ' 25 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 148 A'
        Board_Design.MCM_B_MCD = ' 80'
        Board_Design.MCS_B = ' 25'
        Board_Design.OLR_B = ' 120TA KP'
        Board_Design.FUSE_B = ' 200 A'
        Board_Design.MCCB_B = ' 250-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '60'
        Board_Design.TEXT_B_A = A + ' 148 A'
        Board_Design.TEXT_B_C = c + ' 80'
        Board_Design.TEXT_B_C1 = c1 + ' 25'
        Board_Design.TEXT_B_KP = KP + ' 120TA KP'
        Board_Design.TEXT_B_A1 = A1 + ' 125 A'
        Board_Design.TEXT_B_A2 = A2 + ' 200 A'
        Board_Design.TEXT_B_N = N + ' 250-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 250 A'
        Board_Design.TEXT_B_m = m + ' 70 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 25 mm^2'
    
    @Rule (Horse_Power_B_200_220('50'))
    def Horse_Power_B_200_220_50(Self):
        print('50')
        print(A + ' 124 A')
        print(c + ' 80')
        print(c1 + ' 25')
        print(KP + ' 120TA KP')
        print(A1 + ' 105 A')
        print(A2 + ' 160 A')
        print(N + ' 250-SS')
        print(A3 + ' 225 A')
        print(m + ' 50 mm^2')
        print(m1 + ' 25 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 124 A'
        Board_Design.MCM_B_MCD = ' 80'
        Board_Design.MCS_B = ' 25'
        Board_Design.OLR_B = ' 120TA KP'
        Board_Design.FUSE_B = ' 160 A'
        Board_Design.MCCB_B = ' 250-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '50'
        Board_Design.TEXT_B_A = A + ' 124 A'
        Board_Design.TEXT_B_C = c + ' 80'
        Board_Design.TEXT_B_C1 = c1 + ' 25'
        Board_Design.TEXT_B_KP = KP + ' 120TA KP'
        Board_Design.TEXT_B_A1 = A1 + ' 105 A'
        Board_Design.TEXT_B_A2 = A2 + ' 160 A'
        Board_Design.TEXT_B_N = N + ' 250-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 225 A'
        Board_Design.TEXT_B_m = m + ' 50 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 25 mm^2'
        
    @Rule (Horse_Power_B_200_220('40'))
    def Horse_Power_B_200_220_40(Self):
        print('40')
        print(A + ' 100 A')
        print(c + ' 65')
        print(c1 + ' 25')
        print(KP + ' 120TA KP')
        print(A1 + ' 105 A')
        print(A2 + ' 125 A')
        print(N + ' 250-SS')
        print(A3 + ' 175 A')
        print(m + ' 50 mm^2')
        print(m1 + ' 16 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 100 A'
        Board_Design.MCM_B_MCD = ' 65'
        Board_Design.MCS_B = ' 25'
        Board_Design.OLR_B = ' 120TA KP'
        Board_Design.FUSE_B = ' 125 A'
        Board_Design.MCCB_B = ' 250-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '40'
        Board_Design.TEXT_B_A = A + ' 100 A'
        Board_Design.TEXT_B_C = c + ' 65'
        Board_Design.TEXT_B_C1 = c1 + ' 25'
        Board_Design.TEXT_B_KP = KP + ' 120TA KP'
        Board_Design.TEXT_B_A1 = A1 + ' 105 A'
        Board_Design.TEXT_B_A2 = A2 + ' 125 A'
        Board_Design.TEXT_B_N = N + ' 250-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 175 A'
        Board_Design.TEXT_B_m = m + ' 50 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 16 mm^2'
        
    @Rule (Horse_Power_B_200_220('30'))
    def Horse_Power_B_200_220_30(Self):
        print('30')
        print(A + ' 75 A')
        print(c + ' 50')
        print(c1 + ' 20')
        print(KP + ' 120 KP')
        print(A1 + ' 82 A')
        print(A2 + ' 100 A')
        print(N + ' 160-SS')
        print(A3 + ' 150 A')
        print(m + ' 35 mm^2')
        print(m1 + ' 10 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 75 A'
        Board_Design.MCM_B_MCD = ' 50'
        Board_Design.MCS_B = ' 20'
        Board_Design.OLR_B = ' 120 KP'
        Board_Design.FUSE_B = ' 100 A'
        Board_Design.MCCB_B = ' 160-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '30'
        Board_Design.TEXT_B_A = A + ' 75 A'
        Board_Design.TEXT_B_C = c + ' 50'
        Board_Design.TEXT_B_C1 = c1 + ' 20'
        Board_Design.TEXT_B_KP = KP + ' 120 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 82 A'
        Board_Design.TEXT_B_A2 = A2 + ' 100 A'
        Board_Design.TEXT_B_N = N + ' 160-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 150 A'
        Board_Design.TEXT_B_m = m + ' 35 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 10 mm^2'
        
    @Rule (Horse_Power_B_200_220('25'))
    def Horse_Power_B_200_220_25(Self):
        print('25')
        print(A + ' 62 A')
        print(c + ' 35')
        print(c1 + ' 20')
        print(KP + ' 60 KP')
        print(A1 + ' 54 A')
        print(A2 + ' 100 A')
        print(N + ' 100-SS')
        print(A3 + ' 100 A')
        print(m + ' 25 mm^2')
        print(m1 + ' 6 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 62 A'
        Board_Design.MCM_B_MCD = ' 35'
        Board_Design.MCS_B = ' 20'
        Board_Design.OLR_B = ' 60 KP'
        Board_Design.FUSE_B = ' 100 A'
        Board_Design.MCCB_B = ' 100-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '25'
        Board_Design.TEXT_B_A = A + ' 62 A'
        Board_Design.TEXT_B_C = c + ' 35'
        Board_Design.TEXT_B_C1 = c1 + ' 20'
        Board_Design.TEXT_B_KP = KP + ' 60 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 54 A'
        Board_Design.TEXT_B_A2 = A2 + ' 100 A'
        Board_Design.TEXT_B_N = N + ' 100-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 100 A'
        Board_Design.TEXT_B_m = m + ' 25 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 6 mm^2'
        
    @Rule (Horse_Power_B_200_220('20'))
    def Horse_Power_B_200_220_20(Self):
        print('20')
        print(A + ' 50 A')
        print(c + ' 25')
        print(c1 + ' 20')
        print(KP + ' 60 KP')
        print(A1 + ' 42 A')
        print(A2 + ' 80 A')
        print(N + ' 100-SS')
        print(A3 + ' 100 A')
        print(m + ' 25 mm^2')
        print(m1 + ' 6 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 50 A'
        Board_Design.MCM_B_MCD = ' 25'
        Board_Design.MCS_B = ' 20'
        Board_Design.OLR_B = ' 60 KP'
        Board_Design.FUSE_B = ' 80 A'
        Board_Design.MCCB_B = ' 100-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '20'
        Board_Design.TEXT_B_A = A + ' 50 A'
        Board_Design.TEXT_B_C = c + ' 25'
        Board_Design.TEXT_B_C1 = c1 + ' 20'
        Board_Design.TEXT_B_KP = KP + ' 60 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 42 A'
        Board_Design.TEXT_B_A2 = A2 + ' 80 A'
        Board_Design.TEXT_B_N = N + ' 100-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 100 A'
        Board_Design.TEXT_B_m = m + ' 25 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 6 mm^2'
        
    @Rule (Horse_Power_B_200_220('15'))
    def Horse_Power_B_200_220_15(Self):
        print('15')
        print(A + ' 39 A')
        print(c + ' 20')
        print(c1 + ' 11')
        print(KP + ' 60 KP')
        print(A1 + ' 35 A')
        print(A2 + ' 63 A')
        print(N + ' 100-SS')
        print(A3 + ' 75 A')
        print(m + ' 16 mm^2')
        print(m1 + ' 4 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 39 A'
        Board_Design.MCM_B_MCD = ' 20'
        Board_Design.MCS_B = ' 11'
        Board_Design.OLR_B = ' 60 KP'
        Board_Design.FUSE_B = ' 63 A'
        Board_Design.MCCB_B = ' 100-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '15'
        Board_Design.TEXT_B_A = A + ' 39 A'
        Board_Design.TEXT_B_C = c + ' 20'
        Board_Design.TEXT_B_C1 = c1 + ' 11'
        Board_Design.TEXT_B_KP = KP + ' 60 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 35 A'
        Board_Design.TEXT_B_A2 = A2 + ' 63 A'
        Board_Design.TEXT_B_N = N + ' 100-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 75 A'
        Board_Design.TEXT_B_m = m + ' 16 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 4 mm^2'
        
    @Rule (Horse_Power_B_200_220('10'))
    def Horse_Power_B_200_220_10(Self):
        print('10')
        print(A + ' 26.5 A')
        print(c + ' 18')
        print(c1 + ' 11')
        print(KP + ' 20TA KP')
        print(A1 + ' 29 A')
        print(A2 + ' 40 A')
        print(N + ' 50-SH')
        print(A3 + ' 60 A')
        print(m + ' 10 mm^2')
        print(m1 + ' 2.5 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 26.5 A'
        Board_Design.MCM_B_MCD = ' 18'
        Board_Design.MCS_B = ' 11'
        Board_Design.OLR_B = ' 20TA KP'
        Board_Design.FUSE_B = ' 40 A'
        Board_Design.MCCB_B = ' 50-SH'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '10'
        Board_Design.TEXT_B_A = A + ' 26.5 A'
        Board_Design.TEXT_B_C = c + ' 18'
        Board_Design.TEXT_B_C1 = c1 + ' 11'
        Board_Design.TEXT_B_KP = KP + ' 20TA KP'
        Board_Design.TEXT_B_A1 = A1 + ' 29 A'
        Board_Design.TEXT_B_A2 = A2 + ' 40 A'
        Board_Design.TEXT_B_N = N + ' 50-SH'
        Board_Design.TEXT_B_A3 = A3 + ' 60 A'
        Board_Design.TEXT_B_m = m + ' 10 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 2.5 mm^2'
        
    @Rule (Horse_Power_B_200_220('7.5'))
    def Horse_Power_B_200_220_7(Self):
        print('7.5')
        print(A + ' 20 A')
        print(c + ' 12')
        print(c1 + ' 11')
        print(KP + ' 20 KP')
        print(A1 + ' 19 A')
        print(A2 + ' 32 A')
        print(N + ' 50-SH')
        print(A3 + ' 40 A')
        print(m + ' 6 mm^2')
        print(m1 + ' 1.5 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 20 A'
        Board_Design.MCM_B_MCD = ' 12'
        Board_Design.MCS_B = ' 11'
        Board_Design.OLR_B = ' 20 KP'
        Board_Design.FUSE_B = ' 32 A'
        Board_Design.MCCB_B = ' 50-SH'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '7.5'
        Board_Design.TEXT_B_A = A + ' 20 A'
        Board_Design.TEXT_B_C = c + ' 12'
        Board_Design.TEXT_B_C1 = c1 + ' 11'
        Board_Design.TEXT_B_KP = KP + ' 20 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 19 A'
        Board_Design.TEXT_B_A2 = A2 + ' 32 A'
        Board_Design.TEXT_B_N = N + ' 50-SH'
        Board_Design.TEXT_B_A3 = A3 + ' 40 A'
        Board_Design.TEXT_B_m = m + ' 6 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 1.5 mm^2'
        
    @Rule (Horse_Power_B_200_220('5.5'))
    def Horse_Power_B_200_220_5(Self):
        print('5.5')
        print(A + ' 15.2 A')
        print(c + ' 12')
        print(c1 + ' 11')
        print(KP + ' 20 KP')
        print(A1 + ' 15 A')
        print(A2 + ' 32 A')
        print(N + ' 30-SH')
        print(A3 + ' 30 A')
        print(m + ' 4 mm^2')
        print(m1 + ' 1.5 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 15.2 A'
        Board_Design.MCM_B_MCD = ' 12'
        Board_Design.MCS_B = ' 11'
        Board_Design.OLR_B = ' 20 KP'
        Board_Design.FUSE_B = ' 32 A'
        Board_Design.MCCB_B = ' 30-SH'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '5.5'
        Board_Design.TEXT_B_A = A + ' 15.2 A'
        Board_Design.TEXT_B_C = c + ' 12'
        Board_Design.TEXT_B_C1 = c1 + ' 11'
        Board_Design.TEXT_B_KP = KP + ' 20 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 15 A'
        Board_Design.TEXT_B_A2 = A2 + ' 32 A'
        Board_Design.TEXT_B_N = N + ' 30-SH'
        Board_Design.TEXT_B_A3 = A3 + ' 30 A'
        Board_Design.TEXT_B_m = m + ' 4 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 1.5 mm^2'
        
    @Rule (Horse_Power_B_200_220('4'))
    def Horse_Power_B_200_220_4(Self):
        print('4')
        print(A + ' 11.5 A')
        print(c + ' 12')
        print(c1 + ' 11')
        print(KP + ' 20 KP')
        print(A1 + ' 11 A')
        print(A2 + ' 20 A')
        print(N + ' 30-SS')
        print(A3 + ' 20 A')
        print(m + ' 2.5 mm^2')
        print(m1 + ' 1.5 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 11.5 A'
        Board_Design.MCM_B_MCD = ' 12'
        Board_Design.MCS_B = ' 11'
        Board_Design.OLR_B = ' 20 KP'
        Board_Design.FUSE_B = ' 20 A'
        Board_Design.MCCB_B = ' 30-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '4'
        Board_Design.TEXT_B_A = A + ' 11.5 A'
        Board_Design.TEXT_B_C = c + ' 12'
        Board_Design.TEXT_B_C1 = c1 + ' 11'
        Board_Design.TEXT_B_KP = KP + ' 20 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 11 A'
        Board_Design.TEXT_B_A2 = A2 + ' 20 A'
        Board_Design.TEXT_B_N = N + ' 30-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 20 A'
        Board_Design.TEXT_B_m = m + ' 2.5 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 1.5 mm^2'
        
    @Rule (Horse_Power_B_200_220('3'))
    def Horse_Power_B_200_220_3(Self):
        print('3')
        print(A + ' 8.7 A')
        print(c + ' 12')
        print(c1 + ' 11')
        print(KP + ' 20 KP')
        print(A1 + ' 9 A')
        print(A2 + ' 16 A')
        print(N + ' 30-SS')
        print(A3 + ' 20 A')
        print(m + ' 1.5 mm^2')
        print(m1 + ' 1.5 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 8.7 A'
        Board_Design.MCM_B_MCD = ' 12'
        Board_Design.MCS_B = ' 11'
        Board_Design.OLR_B = ' 20 KP'
        Board_Design.FUSE_B = ' 16 A'
        Board_Design.MCCB_B = ' 30-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '3'
        Board_Design.TEXT_B_A = A + ' 8.7 A'
        Board_Design.TEXT_B_C = c + ' 12'
        Board_Design.TEXT_B_C1 = c1 + ' 11'
        Board_Design.TEXT_B_KP = KP + ' 20 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 9 A'
        Board_Design.TEXT_B_A2 = A2 + ' 16 A'
        Board_Design.TEXT_B_N = N + ' 30-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 20 A'
        Board_Design.TEXT_B_m = m + ' 1.5 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 1.5 mm^2'
#_________________________________________________________________________________________________________________________________
#                                                        B  V : 380
#_________________________________________________________________________________________________________________________________ 

    @Rule (Horse_Power_B_380('340'))
    def Horse_Power_B_380_340(Self):
        print('340')
        print(A + ' 475 A')
        print(c + ' 300')
        print(c1 + ' 105')
        print(KP + ' 600 +CT KP')
        print(A1 + ' 500 A')
        print(A2 + ' 630 A')
        print(N + ' 800-SS')
        print(A3 + ' 800 A')
        print(m + ' 240 mm^2')
        print(m1 + ' 150 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 475 A'
        Board_Design.MCM_B_MCD = ' 300'
        Board_Design.MCS_B = ' 105'
        Board_Design.OLR_B = ' 600+CT KP'
        Board_Design.FUSE_B = ' 630 A'
        Board_Design.MCCB_B = ' 800-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '340'
        Board_Design.TEXT_B_A = A + ' 475 A'
        Board_Design.TEXT_B_C = c + ' 300'
        Board_Design.TEXT_B_C1 = c1 + ' 105'
        Board_Design.TEXT_B_KP = KP + ' 600+CT KP'
        Board_Design.TEXT_B_A1 = A1 + ' 500 A'
        Board_Design.TEXT_B_A2 = A2 + ' 630 A'
        Board_Design.TEXT_B_N = N + ' 800-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 800 A'
        Board_Design.TEXT_B_m = m + ' 240 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 150 mm^2'
        
    @Rule (Horse_Power_B_380('270'))
    def Horse_Power_B_380_270(Self):
        print('270')
        print(A + ' 360 A')
        print(c + ' 220')
        print(c1 + ' 80')
        print(KP + ' 400 HZ KP')
        print(A1 + ' 330 A')
        print(A2 + ' 400 A')
        print(N + ' 630-SS')
        print(A3 + ' 600 A')
        print(m + ' 185 mm^2')
        print(m1 + ' 95 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 360 A'
        Board_Design.MCM_B_MCD = ' 220'
        Board_Design.MCS_B = ' 80'
        Board_Design.OLR_B = ' 400HZ KP'
        Board_Design.FUSE_B = ' 400 A'
        Board_Design.MCCB_B = ' 630-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '270'
        Board_Design.TEXT_B_A = A + ' 360 A'
        Board_Design.TEXT_B_C = c + ' 220'
        Board_Design.TEXT_B_C1 = c1 + ' 80'
        Board_Design.TEXT_B_KP = KP + ' 400HZ KP'
        Board_Design.TEXT_B_A1 = A1 + ' 330 A'
        Board_Design.TEXT_B_A2 = A2 + ' 400 A'
        Board_Design.TEXT_B_N = N + ' 630-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 600 A'
        Board_Design.TEXT_B_m = m + ' 185 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 95 mm^2'
        
    @Rule (Horse_Power_B_380('220'))
    def Horse_Power_B_380_220(Self):
        print('220')
        print(A + ' 290 A')
        print(c + ' 180')
        print(c1 + ' 65')
        print(KP + ' 400 HZ KP')
        print(A1 + ' 250 A')
        print(A2 + ' 315 A')
        print(N + ' 630-SS')
        print(A3 + ' 500 A')
        print(m + ' 150 mm^2')
        print(m1 + ' 70 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 290 A'
        Board_Design.MCM_B_MCD = ' 180'
        Board_Design.MCS_B = ' 65'
        Board_Design.OLR_B = ' 400HZ KP'
        Board_Design.FUSE_B = ' 315 A'
        Board_Design.MCCB_B = ' 630-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '220'
        Board_Design.TEXT_B_A = A + ' 290 A'
        Board_Design.TEXT_B_C = c + ' 180'
        Board_Design.TEXT_B_C1 = c1 + ' 65'
        Board_Design.TEXT_B_KP = KP + ' 400HZ KP'
        Board_Design.TEXT_B_A1 = A1 + ' 250 A'
        Board_Design.TEXT_B_A2 = A2 + ' 315 A'
        Board_Design.TEXT_B_N = N + ' 630-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 500 A'
        Board_Design.TEXT_B_m = m + ' 150 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 70 mm^2'
        
    @Rule (Horse_Power_B_380('180'))
    def Horse_Power_B_380_180(Self):
        print('180')
        print(A + ' 245 A')
        print(c + ' 150')
        print(c1 + ' 50')
        print(KP + ' 220 HZ KP')
        print(A1 + ' 210 A')
        print(A2 + ' 250 A')
        print(N + ' 400-SS')
        print(A3 + ' 400 A')
        print(m + ' 150 mm^2')
        print(m1 + ' 50 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 245 A'
        Board_Design.MCM_B_MCD = ' 150'
        Board_Design.MCS_B = ' 50'
        Board_Design.OLR_B = ' 220HZ KP'
        Board_Design.FUSE_B = ' 250 A'
        Board_Design.MCCB_B = ' 400-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '180'
        Board_Design.TEXT_B_A = A + ' 245 A'
        Board_Design.TEXT_B_C = c + ' 150'
        Board_Design.TEXT_B_C1 = c1 + ' 50'
        Board_Design.TEXT_B_KP = KP + ' 220HZ KP'
        Board_Design.TEXT_B_A1 = A1 + ' 210 A'
        Board_Design.TEXT_B_A2 = A2 + ' 250 A'
        Board_Design.TEXT_B_N = N + ' 400-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 400 A'
        Board_Design.TEXT_B_m = m + ' 150 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 50 mm^2'
        
    @Rule (Horse_Power_B_380('150'))
    def Horse_Power_B_380_150(Self):
        print('150')
        print(A + ' 205 A')
        print(c + ' 125')
        print(c1 + ' 50')
        print(KP + ' 220 HZ KP')
        print(A1 + ' 180 A')
        print(A2 + ' 250 A')
        print(N + ' 400-SS')
        print(A3 + ' 300 A')
        print(m + ' 95 mm^2')
        print(m1 + ' 35 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 205 A'
        Board_Design.MCM_B_MCD = ' 125'
        Board_Design.MCS_B = ' 50'
        Board_Design.OLR_B = ' 220HZ KP'
        Board_Design.FUSE_B = ' 250 A'
        Board_Design.MCCB_B = ' 400-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '150'
        Board_Design.TEXT_B_A = A + ' 205 A'
        Board_Design.TEXT_B_C = c + ' 125'
        Board_Design.TEXT_B_C1 = c1 + ' 50'
        Board_Design.TEXT_B_KP = KP + ' 220HZ KP'
        Board_Design.TEXT_B_A1 = A1 + ' 180 A'
        Board_Design.TEXT_B_A2 = A2 + ' 250 A'
        Board_Design.TEXT_B_N = N + ' 400-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 300 A'
        Board_Design.TEXT_B_m = m + ' 95 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 35 mm^2'
        
    @Rule (Horse_Power_B_380('125'))
    def Horse_Power_B_380_125(Self):
        print('125')
        print(A + ' 168 A')
        print(c + ' 105')
        print(c1 + ' 35')
        print(KP + ' 220 HZ KP')
        print(A1 + ' 150 A')
        print(A2 + ' 200 A')
        print(N + ' 250-SS')
        print(A3 + ' 250 A')
        print(m + ' 70 mm^2')
        print(m1 + ' 35 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 168 A'
        Board_Design.MCM_B_MCD = ' 105'
        Board_Design.MCS_B = ' 35'
        Board_Design.OLR_B = ' 220HZ KP'
        Board_Design.FUSE_B = ' 200 A'
        Board_Design.MCCB_B = ' 250-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '125'
        Board_Design.TEXT_B_A = A + ' 168 A'
        Board_Design.TEXT_B_C = c + ' 105'
        Board_Design.TEXT_B_C1 = c1 + ' 35'
        Board_Design.TEXT_B_KP = KP + ' 220HZ KP'
        Board_Design.TEXT_B_A1 = A1 + ' 150 A'
        Board_Design.TEXT_B_A2 = A2 + ' 200 A'
        Board_Design.TEXT_B_N = N + ' 250-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 250 A'
        Board_Design.TEXT_B_m = m + ' 70 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 35 mm^2'
        
    @Rule (Horse_Power_B_380('100'))
    def Horse_Power_B_380_100(Self):
        print('100')
        print(A + ' 140 A')
        print(c + ' 80')
        print(c1 + ' 25')
        print(KP + ' 120 TA KP')
        print(A1 + ' 125 A')
        print(A2 + ' 160 A')
        print(N + ' 250-SS')
        print(A3 + ' 225 A')
        print(m + ' 50 mm^2')
        print(m1 + ' 25 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 140 A'
        Board_Design.MCM_B_MCD = ' 80'
        Board_Design.MCS_B = ' 25'
        Board_Design.OLR_B = ' 120TA KP'
        Board_Design.FUSE_B = ' 160 A'
        Board_Design.MCCB_B = ' 250-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '100'
        Board_Design.TEXT_B_A = A + ' 140 A'
        Board_Design.TEXT_B_C = c + ' 80'
        Board_Design.TEXT_B_C1 = c1 + ' 25'
        Board_Design.TEXT_B_KP = KP + ' 120TA KP'
        Board_Design.TEXT_B_A1 = A1 + ' 125 A'
        Board_Design.TEXT_B_A2 = A2 + ' 160 A'
        Board_Design.TEXT_B_N = N + ' 250-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 225 A'
        Board_Design.TEXT_B_m = m + ' 50 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 25 mm^2'
        
    @Rule (Horse_Power_B_380('75'))
    def Horse_Power_B_380_75(Self):
        print('75')
        print(A + ' 105 A')
        print(c + ' 65')
        print(c1 + ' 25')
        print(KP + ' 120 TA KP')
        print(A1 + ' 105 A')
        print(A2 + ' 125 A')
        print(N + ' 250-SS')
        print(A3 + ' 175 A')
        print(m + ' 50 mm^2')
        print(m1 + ' 16 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 105 A'
        Board_Design.MCM_B_MCD = ' 65'
        Board_Design.MCS_B = ' 25'
        Board_Design.OLR_B = ' 120TA KP'
        Board_Design.FUSE_B = ' 125 A'
        Board_Design.MCCB_B = ' 250-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '75'
        Board_Design.TEXT_B_A = A + ' 105 A'
        Board_Design.TEXT_B_C = c + ' 65'
        Board_Design.TEXT_B_C1 = c1 + ' 25'
        Board_Design.TEXT_B_KP = KP + ' 120TA KP'
        Board_Design.TEXT_B_A1 = A1 + ' 105 A'
        Board_Design.TEXT_B_A2 = A2 + ' 125 A'
        Board_Design.TEXT_B_N = N + ' 250-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 175 A'
        Board_Design.TEXT_B_m = m + ' 50 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 16 mm^2'
        
    @Rule (Horse_Power_B_380('60'))
    def Horse_Power_B_380_60(Self):
        print('60')
        print(A + ' 86 A')
        print(c + ' 50')
        print(c1 + ' 20')
        print(KP + ' 120  KP')
        print(A1 + ' 82 A')
        print(A2 + ' 100 A')
        print(N + ' 160-SS')
        print(A3 + ' 125 A')
        print(m + ' 35 mm^2')
        print(m1 + ' 10 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 86 A'
        Board_Design.MCM_B_MCD = ' 50'
        Board_Design.MCS_B = ' 20'
        Board_Design.OLR_B = ' 120 KP'
        Board_Design.FUSE_B = ' 100 A'
        Board_Design.MCCB_B = ' 160-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '60'
        Board_Design.TEXT_B_A = A + ' 86 A'
        Board_Design.TEXT_B_C = c + ' 50'
        Board_Design.TEXT_B_C1 = c1 + ' 20'
        Board_Design.TEXT_B_KP = KP + ' 120 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 82 A'
        Board_Design.TEXT_B_A2 = A2 + ' 100 A'
        Board_Design.TEXT_B_N = N + ' 160-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 125 A'
        Board_Design.TEXT_B_m = m + ' 35 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 10 mm^2'
        
    @Rule (Horse_Power_B_380('50'))
    def Horse_Power_B_380_50(Self):
        print('50')
        print(A + ' 72 A')
        print(c + ' 50')
        print(c1 + ' 20')
        print(KP + ' 120  KP')
        print(A1 + ' 82 A')
        print(A2 + ' 100 A')
        print(N + ' 100-SS')
        print(A3 + ' 100 A')
        print(m + ' 25 mm^2')
        print(m1 + ' 6 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 72 A'
        Board_Design.MCM_B_MCD = ' 50'
        Board_Design.MCS_B = ' 20'
        Board_Design.OLR_B = ' 120 KP'
        Board_Design.FUSE_B = ' 100 A'
        Board_Design.MCCB_B = ' 100-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '50'
        Board_Design.TEXT_B_A = A + ' 72 A'
        Board_Design.TEXT_B_C = c + ' 50'
        Board_Design.TEXT_B_C1 = c1 + ' 20'
        Board_Design.TEXT_B_KP = KP + ' 120 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 82 A'
        Board_Design.TEXT_B_A2 = A2 + ' 100 A'
        Board_Design.TEXT_B_N = N + ' 100-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 100 A'
        Board_Design.TEXT_B_m = m + ' 25 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 6 mm^2'
        
    @Rule (Horse_Power_B_380('40'))
    def Horse_Power_B_380_40(Self):
        print('40')
        print(A + ' 57 A')
        print(c + ' 35')
        print(c1 + ' 20')
        print(KP + ' 60  KP')
        print(A1 + ' 54 A')
        print(A2 + ' 63 A')
        print(N + ' 100-SS')
        print(A3 + ' 100 A')
        print(m + ' 25 mm^2')
        print(m1 + ' 6 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 57 A'
        Board_Design.MCM_B_MCD = ' 35'
        Board_Design.MCS_B = ' 20'
        Board_Design.OLR_B = ' 60 KP'
        Board_Design.FUSE_B = ' 63 A'
        Board_Design.MCCB_B = ' 100-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '40'
        Board_Design.TEXT_B_A = A + ' 57 A'
        Board_Design.TEXT_B_C = c + ' 35'
        Board_Design.TEXT_B_C1 = c1 + ' 20'
        Board_Design.TEXT_B_KP = KP + ' 60 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 54 A'
        Board_Design.TEXT_B_A2 = A2 + ' 63 A'
        Board_Design.TEXT_B_N = N + ' 100-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 100 A'
        Board_Design.TEXT_B_m = m + ' 25 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 6 mm^2'
        
    @Rule (Horse_Power_B_380('30'))
    def Horse_Power_B_380_30(Self):
        print('30')
        print(A + ' 43 A')
        print(c + ' 25')
        print(c1 + ' 20')
        print(KP + ' 60  KP')
        print(A1 + ' 42 A')
        print(A2 + ' 63 A')
        print(N + ' 100-SS')
        print(A3 + ' 75 A')
        print(m + ' 16 mm^2')
        print(m1 + ' 4 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 43 A'
        Board_Design.MCM_B_MCD = ' 25'
        Board_Design.MCS_B = ' 20'
        Board_Design.OLR_B = ' 60 KP'
        Board_Design.FUSE_B = ' 63 A'
        Board_Design.MCCB_B = ' 100-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '30'
        Board_Design.TEXT_B_A = A + ' 43 A'
        Board_Design.TEXT_B_C = c + ' 25'
        Board_Design.TEXT_B_C1 = c1 + ' 20'
        Board_Design.TEXT_B_KP = KP + ' 60 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 42 A'
        Board_Design.TEXT_B_A2 = A2 + ' 63 A'
        Board_Design.TEXT_B_N = N + ' 100-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 75 A'
        Board_Design.TEXT_B_m = m + ' 16 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 4 mm^2'
        
    @Rule (Horse_Power_B_380('25'))
    def Horse_Power_B_380_25(Self):
        print('25')
        print(A + ' 37 A')
        print(c + ' 20')
        print(c1 + ' 11')
        print(KP + ' 60  KP')
        print(A1 + ' 35 A')
        print(A2 + ' 40 A')
        print(N + ' 60-SH')
        print(A3 + ' 60 A')
        print(m + ' 10 mm^2')
        print(m1 + ' 2.5 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 37 A'
        Board_Design.MCM_B_MCD = ' 20'
        Board_Design.MCS_B = ' 11'
        Board_Design.OLR_B = ' 60 KP'
        Board_Design.FUSE_B = ' 40 A'
        Board_Design.MCCB_B = ' 60-SH'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '25'
        Board_Design.TEXT_B_A = A + ' 37 A'
        Board_Design.TEXT_B_C = c + ' 20'
        Board_Design.TEXT_B_C1 = c1 + ' 11'
        Board_Design.TEXT_B_KP = KP + ' 60 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 35 A'
        Board_Design.TEXT_B_A2 = A2 + ' 40 A'
        Board_Design.TEXT_B_N = N + ' 60-SH'
        Board_Design.TEXT_B_A3 = A3 + ' 60 A'
        Board_Design.TEXT_B_m = m + ' 10 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 2.5 mm^2'
        
    @Rule (Horse_Power_B_380('20'))
    def Horse_Power_B_380_20(Self):
        print('20')
        print(A + ' 30 A')
        print(c + ' 20')
        print(c1 + ' 11')
        print(KP + ' 60 KP')
        print(A1 + ' 29 A')
        print(A2 + ' 40 A')
        print(N + ' 60-SH')
        print(A3 + ' 60 A')
        print(m + ' 10 mm^2')
        print(m1 + ' 2.5 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 30 A'
        Board_Design.MCM_B_MCD = ' 20'
        Board_Design.MCS_B = ' 11'
        Board_Design.OLR_B = ' 60 KP'
        Board_Design.FUSE_B = ' 40 A'
        Board_Design.MCCB_B = ' 60-SH'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '20'
        Board_Design.TEXT_B_A = A + ' 30 A'
        Board_Design.TEXT_B_C = c + ' 20'
        Board_Design.TEXT_B_C1 = c1 + ' 11'
        Board_Design.TEXT_B_KP = KP + ' 60 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 29 A'
        Board_Design.TEXT_B_A2 = A2 + ' 40 A'
        Board_Design.TEXT_B_N = N + ' 60-SH'
        Board_Design.TEXT_B_A3 = A3 + ' 60 A'
        Board_Design.TEXT_B_m = m + ' 10 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 2.5 mm^2'
        
    @Rule (Horse_Power_B_380('15'))
    def Horse_Power_B_380_15(Self):
        print('15')
        print(A + ' 22 A')
        print(c + ' 18 UA-AX2')
        print(c1 + ' 11')
        print(KP + ' 20 TA KP')
        print(A1 + ' 22 A')
        print(A2 + ' 32 A')
        print(N + ' 50-SH')
        print(A3 + ' 50 A')
        print(m + ' 6 mm^2')
        print(m1 + ' 1.5 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 22 A'
        Board_Design.MCM_B_MCD = ' 18'
        Board_Design.MCS_B = ' 11'
        Board_Design.OLR_B = ' 20TA KP'
        Board_Design.FUSE_B = ' 32 A'
        Board_Design.MCCB_B = ' 50-SH'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '15'
        Board_Design.TEXT_B_A = A + ' 22 A'
        Board_Design.TEXT_B_C = c + ' 18'
        Board_Design.TEXT_B_C1 = c1 + ' 11'
        Board_Design.TEXT_B_KP = KP + ' 20TA KP'
        Board_Design.TEXT_B_A1 = A1 + ' 22 A'
        Board_Design.TEXT_B_A2 = A2 + ' 32 A'
        Board_Design.TEXT_B_N = N + ' 50-SH'
        Board_Design.TEXT_B_A3 = A3 + ' 50 A'
        Board_Design.TEXT_B_m = m + ' 6 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 1.5 mm^2'
        
    @Rule (Horse_Power_B_380('10'))
    def Horse_Power_B_380_10(Self):
        print('10')
        print(A + ' 16 A')
        print(c + ' 12 ')
        print(c1 + ' 11')
        print(KP + ' 20 TA KP')
        print(A1 + ' 15 A')
        print(A2 + ' 32 A')
        print(N + ' 50-SH')
        print(A3 + ' 30 A')
        print(m + ' 4 mm^2')
        print(m1 + ' 1.5 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 16 A'
        Board_Design.MCM_B_MCD = ' 12'
        Board_Design.MCS_B = ' 11'
        Board_Design.OLR_B = ' 20TA KP'
        Board_Design.FUSE_B = ' 32 A'
        Board_Design.MCCB_B = ' 50-SH'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '10'
        Board_Design.TEXT_B_A = A + ' 16 A'
        Board_Design.TEXT_B_C = c + ' 12'
        Board_Design.TEXT_B_C1 = c1 + ' 11'
        Board_Design.TEXT_B_KP = KP + ' 20TA KP'
        Board_Design.TEXT_B_A1 = A1 + ' 15 A'
        Board_Design.TEXT_B_A2 = A2 + ' 32 A'
        Board_Design.TEXT_B_N = N + ' 50-SH'
        Board_Design.TEXT_B_A3 = A3 + ' 30 A'
        Board_Design.TEXT_B_m = m + ' 4 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 1.5 mm^2'
        
    @Rule (Horse_Power_B_380('7.5'))
    def Horse_Power_B_380_7(Self):
        print('7.5')
        print(A + ' 11.8 A')
        print(c + ' 12 ')
        print(c1 + ' 11')
        print(KP + ' 20 TA KP')
        print(A1 + ' 11 A')
        print(A2 + ' 20 A')
        print(N + ' 30-SS')
        print(A3 + ' 30 A')
        print(m + ' 2.5 mm^2')
        print(m1 + ' 1.5 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 11.8 A'
        Board_Design.MCM_B_MCD = ' 12'
        Board_Design.MCS_B = ' 11'
        Board_Design.OLR_B = ' 20TA KP'
        Board_Design.FUSE_B = ' 20 A'
        Board_Design.MCCB_B = ' 30-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '7.5'
        Board_Design.TEXT_B_A = A + ' 11.8 A'
        Board_Design.TEXT_B_C = c + ' 12'
        Board_Design.TEXT_B_C1 = c1 + ' 11'
        Board_Design.TEXT_B_KP = KP + ' 20TA KP'
        Board_Design.TEXT_B_A1 = A1 + ' 11 A'
        Board_Design.TEXT_B_A2 = A2 + ' 20 A'
        Board_Design.TEXT_B_N = N + ' 30-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 30 A'
        Board_Design.TEXT_B_m = m + ' 2.5 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 1.5 mm^2'
        
    @Rule (Horse_Power_B_380('5.5'))
    def Horse_Power_B_380_5(Self):
        print('5.5')
        print(A + ' 8.7 A')
        print(c + ' 12 ')
        print(c1 + ' 11')
        print(KP + ' 20 TA KP')
        print(A1 + ' 9 A')
        print(A2 + ' 16 A')
        print(N + ' 30-SS')
        print(A3 + ' 20 A')
        print(m + ' 1.5 mm^2')
        print(m1 + ' 1.5 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 8.7 A'
        Board_Design.MCM_B_MCD = ' 12'
        Board_Design.MCS_B = ' 11'
        Board_Design.OLR_B = ' 20TA KP'
        Board_Design.FUSE_B = ' 16 A'
        Board_Design.MCCB_B = ' 30-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '5.5'
        Board_Design.TEXT_B_A = A + ' 8.7 A'
        Board_Design.TEXT_B_C = c + ' 12'
        Board_Design.TEXT_B_C1 = c1 + ' 11'
        Board_Design.TEXT_B_KP = KP + ' 20TA KP'
        Board_Design.TEXT_B_A1 = A1 + ' 9 A'
        Board_Design.TEXT_B_A2 = A2 + ' 16 A'
        Board_Design.TEXT_B_N = N + ' 30-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 20 A'
        Board_Design.TEXT_B_m = m + ' 1.5 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 1.5 mm^2'
        
    @Rule (Horse_Power_B_380('4'))
    def Horse_Power_B_380_4(Self):
        print('4')
        print(A + ' 6.8 A')
        print(c + ' 12 ')
        print(c1 + ' 11')
        print(KP + ' 20 TA KP')
        print(A1 + ' 6.6 A')
        print(A2 + ' 16 A')
        print(N + ' 30-SS')
        print(A3 + ' 15 A')
        print(m + ' 1.5 mm^2')
        print(m1 + ' 1.5 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 6.8 A'
        Board_Design.MCM_B_MCD = ' 12'
        Board_Design.MCS_B = ' 11'
        Board_Design.OLR_B = ' 20TA KP'
        Board_Design.FUSE_B = ' 16 A'
        Board_Design.MCCB_B = ' 30-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '4'
        Board_Design.TEXT_B_A = A + ' 6.8 A'
        Board_Design.TEXT_B_C = c + ' 12'
        Board_Design.TEXT_B_C1 = c1 + ' 11'
        Board_Design.TEXT_B_KP = KP + ' 20TA KP'
        Board_Design.TEXT_B_A1 = A1 + ' 6.6 A'
        Board_Design.TEXT_B_A2 = A2 + ' 16 A'
        Board_Design.TEXT_B_N = N + ' 30-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 15 A'
        Board_Design.TEXT_B_m = m + ' 1.5 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 1.5 mm^2'
        
    @Rule (Horse_Power_B_380('3'))
    def Horse_Power_B_380_3(Self):
        print('3')
        print(A + ' 5.1 A')
        print(c + ' 12 ')
        print(c1 + ' 11')
        print(KP + ' 20 TA KP')
        print(A1 + ' 5 A')
        print(A2 + ' 12 A')
        print(N + ' 30-SS')
        print(A3 + ' 10 A')
        print(m + ' 1.5 mm^2')
        print(m1 + ' 1.5 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 5.1 A'
        Board_Design.MCM_B_MCD = ' 12'
        Board_Design.MCS_B = ' 11'
        Board_Design.OLR_B = ' 20TA KP'
        Board_Design.FUSE_B = ' 16 A'
        Board_Design.MCCB_B = ' 30-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '3'
        Board_Design.TEXT_B_A = A + ' 5.1 A'
        Board_Design.TEXT_B_C = c + ' 12'
        Board_Design.TEXT_B_C1 = c1 + ' 11'
        Board_Design.TEXT_B_KP = KP + ' 20TA KP'
        Board_Design.TEXT_B_A1 = A1 + ' 5 A'
        Board_Design.TEXT_B_A2 = A2 + ' 12 A'
        Board_Design.TEXT_B_N = N + ' 30-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 10 A'
        Board_Design.TEXT_B_m = m + ' 1.5 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 1.5 mm^2'

#_________________________________________________________________________________________________________________________________
#                                                        B  V : 415
#_________________________________________________________________________________________________________________________________

    @Rule (Horse_Power_B_415('340'))
    def Horse_Power_B_415_340(Self):
        print('340')
        print(A + ' 435 A')
        print(c + ' 300')
        print(c1 + ' 105')
        print(KP + ' 600+CT KP')
        print(A1 + ' 500 A')
        print(A2 + ' 630 A')
        print(N + ' 800-SS')
        print(A3 + ' 700 A')
        print(m + ' 240 mm^2')
        print(m1 + ' 150 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 435 A'
        Board_Design.MCM_B_MCD = ' 300'
        Board_Design.MCS_B = ' 105'
        Board_Design.OLR_B = ' 600+CT KP'
        Board_Design.FUSE_B = ' 630 A'
        Board_Design.MCCB_B = ' 800-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '340'
        Board_Design.TEXT_B_A = A + ' 435 A'
        Board_Design.TEXT_B_C = c + ' 300'
        Board_Design.TEXT_B_C1 = c1 + ' 105'
        Board_Design.TEXT_B_KP = KP + ' 600+CT KP'
        Board_Design.TEXT_B_A1 = A1 + ' 500 A'
        Board_Design.TEXT_B_A2 = A2 + ' 630 A'
        Board_Design.TEXT_B_N = N + ' 800-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 700 A'
        Board_Design.TEXT_B_m = m + ' 240 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 150 mm^2'
        
    @Rule (Horse_Power_B_415('270'))
    def Horse_Power_B_415_270(Self):
        print('270')
        print(A + ' 328 A')
        print(c + ' 220')
        print(c1 + ' 80')
        print(KP + ' 400+CT KP')
        print(A1 + ' 330 A')
        print(A2 + ' 400 A')
        print(N + ' 630-SS')
        print(A3 + ' 600 A')
        print(m + ' 185 mm^2')
        print(m1 + ' 95 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 328 A'
        Board_Design.MCM_B_MCD = ' 220'
        Board_Design.MCS_B = ' 80'
        Board_Design.OLR_B = ' 400+CT KP'
        Board_Design.FUSE_B = ' 400 A'
        Board_Design.MCCB_B = ' 630-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '270'
        Board_Design.TEXT_B_A = A + ' 328 A'
        Board_Design.TEXT_B_C = c + ' 220'
        Board_Design.TEXT_B_C1 = c1 + ' 80'
        Board_Design.TEXT_B_KP = KP + ' 400+CT KP'
        Board_Design.TEXT_B_A1 = A1 + ' 330 A'
        Board_Design.TEXT_B_A2 = A2 + ' 400 A'
        Board_Design.TEXT_B_N = N + ' 630-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 600 A'
        Board_Design.TEXT_B_m = m + ' 185 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 95 mm^2'
        
    @Rule (Horse_Power_B_415('220'))
    def Horse_Power_B_415_220(Self):
        print('220')
        print(A + ' 270 A')
        print(c + ' 180')
        print(c1 + ' 65')
        print(KP + ' 400HZ KP')
        print(A1 + ' 250 A')
        print(A2 + ' 315 A')
        print(N + ' 630-SS')
        print(A3 + ' 500 A')
        print(m + ' 150 mm^2')
        print(m1 + ' 70 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 270 A'
        Board_Design.MCM_B_MCD = ' 180'
        Board_Design.MCS_B = ' 65'
        Board_Design.OLR_B = ' 400HZ KP'
        Board_Design.FUSE_B = ' 315 A'
        Board_Design.MCCB_B = ' 630-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '220'
        Board_Design.TEXT_B_A = A + ' 270 A'
        Board_Design.TEXT_B_C = c + ' 180'
        Board_Design.TEXT_B_C1 = c1 + ' 65'
        Board_Design.TEXT_B_KP = KP + ' 400HZ KP'
        Board_Design.TEXT_B_A1 = A1 + ' 250 A'
        Board_Design.TEXT_B_A2 = A2 + ' 315 A'
        Board_Design.TEXT_B_N = N + ' 630-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 500 A'
        Board_Design.TEXT_B_m = m + ' 150 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 70 mm^2'
        
    @Rule (Horse_Power_B_415('180'))
    def Horse_Power_B_415_180(Self):
        print('180')
        print(A + ' 230 A')
        print(c + ' 150')
        print(c1 + ' 50')
        print(KP + ' 220HZ KP')
        print(A1 + ' 210 A')
        print(A2 + ' 250 A')
        print(N + ' 400-SS')
        print(A3 + ' 400 A')
        print(m + ' 150 mm^2')
        print(m1 + ' 50 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 230 A'
        Board_Design.MCM_B_MCD = ' 150'
        Board_Design.MCS_B = ' 50'
        Board_Design.OLR_B = ' 220HZ KP'
        Board_Design.FUSE_B = ' 250 A'
        Board_Design.MCCB_B = ' 400-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '180'
        Board_Design.TEXT_B_A = A + ' 230 A'
        Board_Design.TEXT_B_C = c + ' 150'
        Board_Design.TEXT_B_C1 = c1 + ' 50'
        Board_Design.TEXT_B_KP = KP + ' 220HZ KP'
        Board_Design.TEXT_B_A1 = A1 + ' 210 A'
        Board_Design.TEXT_B_A2 = A2 + ' 250 A'
        Board_Design.TEXT_B_N = N + ' 400-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 400 A'
        Board_Design.TEXT_B_m = m + ' 150 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 50 mm^2'
        
    @Rule (Horse_Power_B_415('150'))
    def Horse_Power_B_415_150(Self):
        print('150')
        print(A + ' 190 A')
        print(c + ' 125')
        print(c1 + ' 50')
        print(KP + ' 220HZ KP')
        print(A1 + ' 180 A')
        print(A2 + ' 250 A')
        print(N + ' 400-SS')
        print(A3 + ' 300 A')
        print(m + ' 95 mm^2')
        print(m1 + ' 35 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 190 A'
        Board_Design.MCM_B_MCD = ' 125'
        Board_Design.MCS_B = ' 50'
        Board_Design.OLR_B = ' 220HZ KP'
        Board_Design.FUSE_B = ' 250 A'
        Board_Design.MCCB_B = ' 400-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '150'
        Board_Design.TEXT_B_A = A + ' 190 A'
        Board_Design.TEXT_B_C = c + ' 125'
        Board_Design.TEXT_B_C1 = c1 + ' 50'
        Board_Design.TEXT_B_KP = KP + ' 220HZ KP'
        Board_Design.TEXT_B_A1 = A1 + ' 180 A'
        Board_Design.TEXT_B_A2 = A2 + ' 250 A'
        Board_Design.TEXT_B_N = N + ' 400-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 300 A'
        Board_Design.TEXT_B_m = m + ' 95 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 35 mm^2'
        
    @Rule (Horse_Power_B_415('125'))
    def Horse_Power_B_415_125(Self):
        print('125')
        print(A + ' 160 A')
        print(c + ' 105')
        print(c1 + ' 35')
        print(KP + ' 220HZ KP')
        print(A1 + ' 150 A')
        print(A2 + ' 160 A')
        print(N + ' 250-SS')
        print(A3 + ' 250 A')
        print(m + ' 70 mm^2')
        print(m1 + ' 35 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 160 A'
        Board_Design.MCM_B_MCD = ' 105'
        Board_Design.MCS_B = ' 35'
        Board_Design.OLR_B = ' 220HZ KP'
        Board_Design.FUSE_B = ' 160 A'
        Board_Design.MCCB_B = ' 250-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '125'
        Board_Design.TEXT_B_A = A + ' 160 A'
        Board_Design.TEXT_B_C = c + ' 105'
        Board_Design.TEXT_B_C1 = c1 + ' 35'
        Board_Design.TEXT_B_KP = KP + ' 220HZ KP'
        Board_Design.TEXT_B_A1 = A1 + ' 150 A'
        Board_Design.TEXT_B_A2 = A2 + ' 160 A'
        Board_Design.TEXT_B_N = N + ' 250-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 250 A'
        Board_Design.TEXT_B_m = m + ' 70 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 35 mm^2'
        
    @Rule (Horse_Power_B_415('100'))
    def Horse_Power_B_415_100(Self):
        print('100')
        print(A + ' 130 A')
        print(c + ' 80')
        print(c1 + ' 25')
        print(KP + ' 120TA KP')
        print(A1 + ' 125 A')
        print(A2 + ' 160 A')
        print(N + ' 250-SS')
        print(A3 + ' 225 A')
        print(m + ' 50 mm^2')
        print(m1 + ' 25 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 130 A'
        Board_Design.MCM_B_MCD = ' 80'
        Board_Design.MCS_B = ' 25'
        Board_Design.OLR_B = ' 120TA KP'
        Board_Design.FUSE_B = ' 160 A'
        Board_Design.MCCB_B = ' 250-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '100'
        Board_Design.TEXT_B_A = A + ' 130 A'
        Board_Design.TEXT_B_C = c + ' 80'
        Board_Design.TEXT_B_C1 = c1 + ' 25'
        Board_Design.TEXT_B_KP = KP + ' 120TA KP'
        Board_Design.TEXT_B_A1 = A1 + ' 125 A'
        Board_Design.TEXT_B_A2 = A2 + ' 160 A'
        Board_Design.TEXT_B_N = N + ' 250-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 225 A'
        Board_Design.TEXT_B_m = m + ' 50 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 25 mm^2'
        
    @Rule (Horse_Power_B_200_220('75'))
    def Horse_Power_B_200_220_75(Self):
        print('75')
        print(A + ' 98 A')
        print(c + ' 65')
        print(c1 + ' 25')
        print(KP + ' 120TA KP')
        print(A1 + ' 105 A')
        print(A2 + ' 125 A')
        print(N + ' 250-SS')
        print(A3 + ' 175 A')
        print(m + ' 50 mm^2')
        print(m1 + ' 16 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 98 A'
        Board_Design.MCM_B_MCD = ' 65'
        Board_Design.MCS_B = ' 25'
        Board_Design.OLR_B = ' 120TA KP'
        Board_Design.FUSE_B = ' 125 A'
        Board_Design.MCCB_B = ' 250-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '75'
        Board_Design.TEXT_B_A = A + ' 98 A'
        Board_Design.TEXT_B_C = c + ' 65'
        Board_Design.TEXT_B_C1 = c1 + ' 25'
        Board_Design.TEXT_B_KP = KP + ' 120TA KP'
        Board_Design.TEXT_B_A1 = A1 + ' 105 A'
        Board_Design.TEXT_B_A2 = A2 + ' 125 A'
        Board_Design.TEXT_B_N = N + ' 250-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 175 A'
        Board_Design.TEXT_B_m = m + ' 50 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 16 mm^2'
        
    @Rule (Horse_Power_B_415('60'))
    def Horse_Power_B_415_60(Self):
        print('60')
        print(A + ' 79 A')
        print(c + ' 50')
        print(c1 + ' 20')
        print(KP + ' 120 KP')
        print(A1 + ' 82 A')
        print(A2 + ' 100 A')
        print(N + ' 160-SS')
        print(A3 + ' 125 A')
        print(m + ' 35 mm^2')
        print(m1 + ' 10 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 79 A'
        Board_Design.MCM_B_MCD = ' 50'
        Board_Design.MCS_B = ' 20'
        Board_Design.OLR_B = ' 120 KP'
        Board_Design.FUSE_B = ' 100 A'
        Board_Design.MCCB_B = ' 160-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '60'
        Board_Design.TEXT_B_A = A + ' 79 A'
        Board_Design.TEXT_B_C = c + ' 50'
        Board_Design.TEXT_B_C1 = c1 + ' 20'
        Board_Design.TEXT_B_KP = KP + ' 120 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 82 A'
        Board_Design.TEXT_B_A2 = A2 + ' 100 A'
        Board_Design.TEXT_B_N = N + ' 160-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 125 A'
        Board_Design.TEXT_B_m = m + ' 35 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 10 mm^2'
        
    @Rule (Horse_Power_B_415('50'))
    def Horse_Power_B_415_50(Self):
        print('50')
        print(A + ' 67 A')
        print(c + ' 50')
        print(c1 + ' 20')
        print(KP + ' 120 KP')
        print(A1 + ' 82 A')
        print(A2 + ' 100 A')
        print(N + ' 100-SS')
        print(A3 + ' 100 A')
        print(m + ' 25 mm^2')
        print(m1 + ' 6 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 67 A'
        Board_Design.MCM_B_MCD = ' 50'
        Board_Design.MCS_B = ' 20'
        Board_Design.OLR_B = ' 120 KP'
        Board_Design.FUSE_B = ' 100 A'
        Board_Design.MCCB_B = ' 100-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '50'
        Board_Design.TEXT_B_A = A + ' 67 A'
        Board_Design.TEXT_B_C = c + ' 50'
        Board_Design.TEXT_B_C1 = c1 + ' 20'
        Board_Design.TEXT_B_KP = KP + ' 120 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 82 A'
        Board_Design.TEXT_B_A2 = A2 + ' 100 A'
        Board_Design.TEXT_B_N = N + ' 100-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 100 A'
        Board_Design.TEXT_B_m = m + ' 25 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 6 mm^2'
        
    @Rule (Horse_Power_B_415('40'))
    def Horse_Power_B_415_40(Self):
        print('40')
        print(A + ' 54 A')
        print(c + ' 35')
        print(c1 + ' 20')
        print(KP + ' 60 KP')
        print(A1 + ' 54 A')
        print(A2 + ' 63 A')
        print(N + ' 100-SS')
        print(A3 + ' 100 A')
        print(m + ' 25 mm^2')
        print(m1 + ' 6 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 54 A'
        Board_Design.MCM_B_MCD = ' 35'
        Board_Design.MCS_B = ' 20'
        Board_Design.OLR_B = ' 60 KP'
        Board_Design.FUSE_B = ' 63 A'
        Board_Design.MCCB_B = ' 100-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '40'
        Board_Design.TEXT_B_A = A + ' 54 A'
        Board_Design.TEXT_B_C = c + ' 35'
        Board_Design.TEXT_B_C1 = c1 + ' 20'
        Board_Design.TEXT_B_KP = KP + ' 60 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 54 A'
        Board_Design.TEXT_B_A2 = A2 + ' 63 A'
        Board_Design.TEXT_B_N = N + ' 100-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 100 A'
        Board_Design.TEXT_B_m = m + ' 25 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 6 mm^2'
        
    @Rule (Horse_Power_B_415('30'))
    def Horse_Power_B_415_30(Self):
        print('30')
        print(A + ' 40 A')
        print(c + ' 25')
        print(c1 + ' 20')
        print(KP + ' 60 KP')
        print(A1 + ' 42 A')
        print(A2 + ' 63 A')
        print(N + ' 100-SS')
        print(A3 + ' 75 A')
        print(m + ' 16 mm^2')
        print(m1 + ' 4 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 40 A'
        Board_Design.MCM_B_MCD = ' 25'
        Board_Design.MCS_B = ' 20'
        Board_Design.OLR_B = ' 60 KP'
        Board_Design.FUSE_B = ' 63 A'
        Board_Design.MCCB_B = ' 100-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '30'
        Board_Design.TEXT_B_A = A + ' 40 A'
        Board_Design.TEXT_B_C = c + ' 25'
        Board_Design.TEXT_B_C1 = c1 + ' 20'
        Board_Design.TEXT_B_KP = KP + ' 60 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 42 A'
        Board_Design.TEXT_B_A2 = A2 + ' 63 A'
        Board_Design.TEXT_B_N = N + ' 100-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 75 A'
        Board_Design.TEXT_B_m = m + ' 16 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 4 mm^2'
        
    @Rule (Horse_Power_B_415('25'))
    def Horse_Power_B_415_25(Self):
        print('25')
        print(A + ' 35 A')
        print(c + ' 20')
        print(c1 + ' 11')
        print(KP + ' 60 KP')
        print(A1 + ' 35 A')
        print(A2 + ' 40 A')
        print(N + ' 60-SH')
        print(A3 + ' 60 A')
        print(m + ' 10 mm^2')
        print(m1 + ' 2.5 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 35 A'
        Board_Design.MCM_B_MCD = ' 20'
        Board_Design.MCS_B = ' 11'
        Board_Design.OLR_B = ' 60 KP'
        Board_Design.FUSE_B = ' 40 A'
        Board_Design.MCCB_B = ' 60-SH'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '25'
        Board_Design.TEXT_B_A = A + ' 35 A'
        Board_Design.TEXT_B_C = c + ' 20'
        Board_Design.TEXT_B_C1 = c1 + ' 11'
        Board_Design.TEXT_B_KP = KP + ' 60 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 35 A'
        Board_Design.TEXT_B_A2 = A2 + ' 40 A'
        Board_Design.TEXT_B_N = N + ' 60-SH'
        Board_Design.TEXT_B_A3 = A3 + ' 60 A'
        Board_Design.TEXT_B_m = m + ' 10 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 2.5 mm^2'
        
    @Rule (Horse_Power_B_415('20'))
    def Horse_Power_B_415_20(Self):
        print('20')
        print(A + ' 28 A')
        print(c + ' 20')
        print(c1 + ' 11')
        print(KP + ' 60 KP')
        print(A1 + ' 29 A')
        print(A2 + ' 40 A')
        print(N + ' 60-SH')
        print(A3 + ' 60 A')
        print(m + ' 10 mm^2')
        print(m1 + ' 2.5 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 28 A'
        Board_Design.MCM_B_MCD = ' 20'
        Board_Design.MCS_B = ' 11'
        Board_Design.OLR_B = ' 60 KP'
        Board_Design.FUSE_B = ' 40 A'
        Board_Design.MCCB_B = ' 60-SH'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '20'
        Board_Design.TEXT_B_A = A + ' 28 A'
        Board_Design.TEXT_B_C = c + ' 20'
        Board_Design.TEXT_B_C1 = c1 + ' 11'
        Board_Design.TEXT_B_KP = KP + ' 60 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 29 A'
        Board_Design.TEXT_B_A2 = A2 + ' 40 A'
        Board_Design.TEXT_B_N = N + ' 60-SH'
        Board_Design.TEXT_B_A3 = A3 + ' 60 A'
        Board_Design.TEXT_B_m = m + ' 10 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 2.5 mm^2'
        
    @Rule (Horse_Power_B_415('15'))
    def Horse_Power_B_415_15(Self):
        print('15')
        print(A + ' 21 A')
        print(c + ' 18UA.A*2')
        print(c1 + ' 11')
        print(KP + ' 20TA KP')
        print(A1 + ' 22 A')
        print(A2 + ' 32 A')
        print(N + ' 50-SH')
        print(A3 + ' 50 A')
        print(m + ' 6 mm^2')
        print(m1 + ' 1.5 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 21 A'
        Board_Design.MCM_B_MCD = ' 18'
        Board_Design.MCS_B = ' 11'
        Board_Design.OLR_B = ' 20TA KP'
        Board_Design.FUSE_B = ' 32 A'
        Board_Design.MCCB_B = ' 50-SH'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '15'
        Board_Design.TEXT_B_A = A + ' 21 A'
        Board_Design.TEXT_B_C = c + ' 18'
        Board_Design.TEXT_B_C1 = c1 + ' 11'
        Board_Design.TEXT_B_KP = KP + ' 20TA KP'
        Board_Design.TEXT_B_A1 = A1 + ' 22 A'
        Board_Design.TEXT_B_A2 = A2 + ' 32 A'
        Board_Design.TEXT_B_N = N + ' 50-SH'
        Board_Design.TEXT_B_A3 = A3 + ' 50 A'
        Board_Design.TEXT_B_m = m + ' 6 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 1.5 mm^2'
        
    @Rule (Horse_Power_B_415('10'))
    def Horse_Power_B_415_10(Self):
        print('10')
        print(A + ' 15 A')
        print(c + ' 12')
        print(c1 + ' 11')
        print(KP + ' 20 KP')
        print(A1 + ' 15 A')
        print(A2 + ' 32 A')
        print(N + ' 50-SH')
        print(A3 + ' 30 A')
        print(m + ' 4 mm^2')
        print(m1 + ' 1.5 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 15 A'
        Board_Design.MCM_B_MCD = ' 12'
        Board_Design.MCS_B = ' 11'
        Board_Design.OLR_B = ' 20 KP'
        Board_Design.FUSE_B = ' 32 A'
        Board_Design.MCCB_B = ' 50-SH'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '10'
        Board_Design.TEXT_B_A = A + ' 15 A'
        Board_Design.TEXT_B_C = c + ' 12'
        Board_Design.TEXT_B_C1 = c1 + ' 11'
        Board_Design.TEXT_B_KP = KP + ' 20 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 15 A'
        Board_Design.TEXT_B_A2 = A2 + ' 32 A'
        Board_Design.TEXT_B_N = N + ' 50-SH'
        Board_Design.TEXT_B_A3 = A3 + ' 30 A'
        Board_Design.TEXT_B_m = m + ' 4 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 1.5 mm^2'
        
    @Rule (Horse_Power_B_415('7.5'))
    def Horse_Power_B_415_7(Self):
        print('7.5')
        print(A + ' 11 A')
        print(c + ' 12')
        print(c1 + ' 11')
        print(KP + ' 20 KP')
        print(A1 + ' 11 A')
        print(A2 + ' 20 A')
        print(N + ' 30-SS')
        print(A3 + ' 30 A')
        print(m + ' 2.5 mm^2')
        print(m1 + ' 1.5 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 11 A'
        Board_Design.MCM_B_MCD = ' 12'
        Board_Design.MCS_B = ' 11'
        Board_Design.OLR_B = ' 20 KP'
        Board_Design.FUSE_B = ' 20 A'
        Board_Design.MCCB_B = ' 30-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '7.5'
        Board_Design.TEXT_B_A = A + ' 11 A'
        Board_Design.TEXT_B_C = c + ' 12'
        Board_Design.TEXT_B_C1 = c1 + ' 11'
        Board_Design.TEXT_B_KP = KP + ' 20 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 11 A'
        Board_Design.TEXT_B_A2 = A2 + ' 20 A'
        Board_Design.TEXT_B_N = N + ' 30-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 30 A'
        Board_Design.TEXT_B_m = m + ' 2.5 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 1.5 mm^2'
        
    @Rule (Horse_Power_B_415('5.5'))
    def Horse_Power_B_415_5(Self):
        print('5.5')
        print(A + ' 8 A')
        print(c + ' 12')
        print(c1 + ' 11')
        print(KP + ' 20 KP')
        print(A1 + ' 9 A')
        print(A2 + ' 16 A')
        print(N + ' 30-SS')
        print(A3 + ' 20 A')
        print(m + ' 1.5 mm^2')
        print(m1 + ' 1.5 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 8 A'
        Board_Design.MCM_B_MCD = ' 12'
        Board_Design.MCS_B = ' 11'
        Board_Design.OLR_B = ' 20 KP'
        Board_Design.FUSE_B = ' 16 A'
        Board_Design.MCCB_B = ' 30-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '5.5'
        Board_Design.TEXT_B_A = A + ' 8 A'
        Board_Design.TEXT_B_C = c + ' 12'
        Board_Design.TEXT_B_C1 = c1 + ' 11'
        Board_Design.TEXT_B_KP = KP + ' 20 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 9 A'
        Board_Design.TEXT_B_A2 = A2 + ' 16 A'
        Board_Design.TEXT_B_N = N + ' 30-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 20 A'
        Board_Design.TEXT_B_m = m + ' 1.5 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 1.5 mm^2'
        
    @Rule (Horse_Power_B_415('4'))
    def Horse_Power_B_415_4(Self):
        print('4')
        print(A + ' 6.3 A')
        print(c + ' 12')
        print(c1 + ' 11')
        print(KP + ' 20 KP')
        print(A1 + ' 6.6 A')
        print(A2 + ' 16 A')
        print(N + ' 30-SS')
        print(A3 + ' 15 A')
        print(m + ' 1.5 mm^2')
        print(m1 + ' 1.5 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 6.3 A'
        Board_Design.MCM_B_MCD = ' 12'
        Board_Design.MCS_B = ' 11'
        Board_Design.OLR_B = ' 20 KP'
        Board_Design.FUSE_B = ' 16 A'
        Board_Design.MCCB_B = ' 30-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '4'
        Board_Design.TEXT_B_A = A + ' 6.3 A'
        Board_Design.TEXT_B_C = c + ' 12'
        Board_Design.TEXT_B_C1 = c1 + ' 11'
        Board_Design.TEXT_B_KP = KP + ' 20 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 6.6 A'
        Board_Design.TEXT_B_A2 = A2 + ' 16 A'
        Board_Design.TEXT_B_N = N + ' 30-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 15 A'
        Board_Design.TEXT_B_m = m + ' 1.5 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 1.5 mm^2'
        
    @Rule (Horse_Power_B_200_220('3'))
    def Horse_Power_B_200_220_3(Self):
        print('3')
        print(A + ' 5.0 A')
        print(c + ' 12')
        print(c1 + ' 11')
        print(KP + ' 20 KP')
        print(A1 + ' 5 A')
        print(A2 + ' 12 A')
        print(N + ' 30-SS')
        print(A3 + ' 10 A')
        print(m + ' 1.5 mm^2')
        print(m1 + ' 1.5 mm^2')
        #VAR___________________________________________
        Board_Design.MOTOR_B = ' 5.0 A'
        Board_Design.MCM_B_MCD = ' 12'
        Board_Design.MCS_B = ' 11'
        Board_Design.OLR_B = ' 20 KP'
        Board_Design.FUSE_B = ' 12 A'
        Board_Design.MCCB_B = ' 30-SS'
        #TEXT__________________________________________
        Board_Design.TEXT_B_HP = 'HP : ' + '3'
        Board_Design.TEXT_B_A = A + ' 5.0 A'
        Board_Design.TEXT_B_C = c + ' 12'
        Board_Design.TEXT_B_C1 = c1 + ' 11'
        Board_Design.TEXT_B_KP = KP + ' 20 KP'
        Board_Design.TEXT_B_A1 = A1 + ' 5 A'
        Board_Design.TEXT_B_A2 = A2 + ' 12 A'
        Board_Design.TEXT_B_N = N + ' 30-SS'
        Board_Design.TEXT_B_A3 = A3 + ' 10 A'
        Board_Design.TEXT_B_m = m + ' 1.5 mm^2'
        Board_Design.TEXT_B_m1 = m1 + ' 1.5 mm^2'
        
#_________________________________________________________________________________________________________________________________
#                                                        A  V : 200 -> 220
#_________________________________________________________________________________________________________________________________
        
    
    @Rule (Horse_Power_A_200_220('100'))
    def Horse_Power_A_200_220_100(Self):
        print('100')
        print(A + ' 245 A')
        print(cA + ' 220 KPPMCG')
        print(AA + ' 220RH KP')
        print(A1 + ' 210 A')
        print(A2 + ' 500 A') 
        print(N + ' 400-SS') 
        print(A3 + ' 400 A')
        print(m + ' 150 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 245 A'
        Board_Design.MS_A = ' 220 KPPMCG'
        Board_Design.OLR_A = ' 220RH KP'
        Board_Design.FUSE_A =' 500 A'
        Board_Design.MCCB_A =' 400-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '100'
        Board_Design.Text_A_A = A + ' 245 A'
        Board_Design.Text_A_cA = cA + ' 220 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 220RH KP'
        Board_Design.Text_A_A1 = A1 + ' 210 A'
        Board_Design.Text_A_A2 = A2 + ' 500 A'
        Board_Design.Text_A_N = N + ' 400-SS'
        Board_Design.Text_A_A3 = A3 + ' 400 A'
        Board_Design.Text_A_m = m + ' 150 mm^2'
        
    @Rule (Horse_Power_A_200_220('75'))
    def Horse_Power_A_200_220_75(Self):
        print('75')
        print(A + ' 180 A')
        print(cA + ' 180 KPPMCG')
        print(AA + ' 220RH KP')
        print(A1 + ' 150 A')
        print(A2 + ' 400 A')
        print(N + ' 400-SS')
        print(A3 + ' 300 A')
        print(m + ' 95 mm^2') 
        #VAR______________________________
        Board_Design.MOTOR_A = ' 180 A'
        Board_Design.MS_A = ' 180 KPPMCG'
        Board_Design.OLR_A = ' 220RH KP'
        Board_Design.FUSE_A =' 400 A'
        Board_Design.MCCB_A =' 400-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '75'
        Board_Design.Text_A_A = A + ' 180 A'
        Board_Design.Text_A_cA = cA + ' 180 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 220RH KP'
        Board_Design.Text_A_A1 = A1 + ' 150 A'
        Board_Design.Text_A_A2 = A2 + ' 400 A'
        Board_Design.Text_A_N = N + ' 400-SS'
        Board_Design.Text_A_A3 = A3 + ' 300 A'
        Board_Design.Text_A_m = m + ' 95 mm^2'
        
    @Rule (Horse_Power_A_200_220('60'))
    def Horse_Power_A_200_220_60(Self):
        print('60')
        print(A + ' 148 A')
        print(cA + ' 150 KPPMCG')
        print(AA + ' 120TA KP')
        print(A1 + ' 125 A')
        print(A2 + ' 315 A')
        print(N + ' 250-SS')
        print(A3 + ' 250 A')
        print(m + ' 70 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 148 A'
        Board_Design.MS_A = ' 150 KPPMCG'
        Board_Design.OLR_A = ' 120TA KP'
        Board_Design.FUSE_A =' 315 A'
        Board_Design.MCCB_A =' 250-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '60'
        Board_Design.Text_A_A = A + ' 148 A'
        Board_Design.Text_A_cA = cA + ' 150 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 120TA KP'
        Board_Design.Text_A_A1 = A1 + ' 125 A'
        Board_Design.Text_A_A2 = A2 + ' 315 A'
        Board_Design.Text_A_N = N + ' 250-SS'
        Board_Design.Text_A_A3 = A3 + ' 250 A'
        Board_Design.Text_A_m = m + ' 70 mm^2'
        
    @Rule (Horse_Power_A_200_220('50'))
    def Horse_Power_A_200_220_50(Self):
        print('50')
        print(A + ' 124 A')
        print(cA + ' 125 KPPMCG')
        print(AA + ' 120TA KP')
        print(A1 + ' 105 A')
        print(A2 + ' 315 A')
        print(N + ' 250-SS')
        print(A3 + ' 225 A')
        print(m + ' 50 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 124 A'
        Board_Design.MS_A = ' 125 KPPMCG'
        Board_Design.OLR_A = ' 120TA KP'
        Board_Design.FUSE_A =' 315 A'
        Board_Design.MCCB_A =' 250-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '50'
        Board_Design.Text_A_A = A + ' 124 A'
        Board_Design.Text_A_cA = cA + ' 125 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 120TA KP'
        Board_Design.Text_A_A1 = A1 + ' 105 A'
        Board_Design.Text_A_A2 = A2 + ' 315 A'
        Board_Design.Text_A_N = N + ' 250-SS'
        Board_Design.Text_A_A3 = A3 + ' 225 A'
        Board_Design.Text_A_m = m + ' 50 mm^2'
        
    @Rule (Horse_Power_A_200_220('40'))
    def Horse_Power_A_200_220_40(Self):
        print('40')
        print(A + ' 100 A')
        print(cA + ' 105 KPPMCG')
        print(AA + ' 60TA KP')
        print(A1 + ' 95 A')
        print(A2 + ' 200 A')
        print(N + ' 250-SS')
        print(A3 + ' 175 A')
        print(m + ' 50 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 100 A'
        Board_Design.MS_A = ' 105 KPPMCG'
        Board_Design.OLR_A = ' 60TA KP'
        Board_Design.FUSE_A =' 200 A'
        Board_Design.MCCB_A =' 250-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '40'
        Board_Design.Text_A_A = A + ' 100 A'
        Board_Design.Text_A_cA = cA + ' 105 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 60TA KP'
        Board_Design.Text_A_A1 = A1 + ' 95 A'
        Board_Design.Text_A_A2 = A2 + ' 200 A'
        Board_Design.Text_A_N = N + ' 250-SS'
        Board_Design.Text_A_A3 = A3 + ' 175 A'
        Board_Design.Text_A_m = m + ' 50 mm^2'
        
        
    @Rule (Horse_Power_A_200_220('30'))
    def Horse_Power_A_200_220_30(Self):
        print('30')
        print(A + ' 75 A')
        print(cA + ' 80 KPPMCG')
        print(AA + ' 60TA KP')
        print(A1 + ' 82 A')
        print(A2 + ' 200 A')
        print(N + ' 160-SS')
        print(A3 + ' 150 A')
        print(m + ' 35 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 75 A'
        Board_Design.MS_A = ' 80 KPPMCG'
        Board_Design.OLR_A = ' 60TA KP'
        Board_Design.FUSE_A =' 200 A'
        Board_Design.MCCB_A =' 160-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '30'
        Board_Design.Text_A_A = A + ' 75 A'
        Board_Design.Text_A_cA = cA + ' 80 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 60TA KP'
        Board_Design.Text_A_A1 = A1 + ' 82 A'
        Board_Design.Text_A_A2 = A2 + ' 200 A'
        Board_Design.Text_A_N = N + ' 160-SS'
        Board_Design.Text_A_A3 = A3 + ' 150 A'
        Board_Design.Text_A_m = m + ' 35 mm^2'
        
    @Rule (Horse_Power_A_200_220('25'))
    def Horse_Power_A_200_220_25(Self):
        print('25')
        print(A + ' 62 A')
        print(cA + ' 65 KPPMCG')
        print(AA + ' 60 KP')
        print(A1 + ' 54 A')
        print(A2 + ' 160 A')
        print(N + ' 100-SS')
        print(A3 + ' 100 A')
        print(m + ' 25 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 62 A'
        Board_Design.MS_A = ' 65 KPPMCG'
        Board_Design.OLR_A = ' 60 KP'
        Board_Design.FUSE_A =' 160 A'
        Board_Design.MCCB_A =' 100-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '25'
        Board_Design.Text_A_A = A + ' 62 A'
        Board_Design.Text_A_cA = cA + ' 65 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 60 KP'
        Board_Design.Text_A_A1 = A1 + ' 54 A'
        Board_Design.Text_A_A2 = A2 + ' 160 A'
        Board_Design.Text_A_N = N + ' 100-SS'
        Board_Design.Text_A_A3 = A3 + ' 100 A'
        Board_Design.Text_A_m = m + ' 25 mm^2'
        
    @Rule (Horse_Power_A_200_220('20'))
    def Horse_Power_A_200_220_20(Self):
        print('20')
        print(A + ' 50 A')
        print(cA + ' 50 KPPMCG')
        print(AA + ' 60 KP')
        print(A1 + ' 54 A')
        print(A2 + ' 160 A')
        print(N + ' 100-SS')
        print(A3 + ' 100 A')
        print(m + ' 25 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 50 A'
        Board_Design.MS_A = ' 50 KPPMCG'
        Board_Design.OLR_A = ' 60 KP'
        Board_Design.FUSE_A =' 160 A'
        Board_Design.MCCB_A =' 100-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '20'
        Board_Design.Text_A_A = A + ' 50 A'
        Board_Design.Text_A_cA = cA + ' 50 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 60 KP'
        Board_Design.Text_A_A1 = A1 + ' 54 A'
        Board_Design.Text_A_A2 = A2 + ' 160 A'
        Board_Design.Text_A_N = N + ' 100-SS'
        Board_Design.Text_A_A3 = A3 + ' 100 A'
        Board_Design.Text_A_m = m + ' 25 mm^2'
        
    @Rule (Horse_Power_A_200_220('15'))
    def Horse_Power_A_200_220_15(Self):
        print('15')
        print(A + ' 39 A')
        print(cA + ' 35 KPPMCG')
        print(AA + ' 20TA KP')
        print(A1 + ' 35 A')
        print(A2 + ' 80 A')
        print(N + ' 100-SS')
        print(A3 + ' 75 A')
        print(m + ' 16 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 39 A'
        Board_Design.MS_A = ' 35 KPPMCG'
        Board_Design.OLR_A = ' 20TA KP'
        Board_Design.FUSE_A =' 80 A'
        Board_Design.MCCB_A =' 100-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '15'
        Board_Design.Text_A_A = A + ' 39 A'
        Board_Design.Text_A_cA = cA + ' 35 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 20TA KP'
        Board_Design.Text_A_A1 = A1 + ' 35 A'
        Board_Design.Text_A_A2 = A2 + ' 80 A'
        Board_Design.Text_A_N = N + ' 100-SS'
        Board_Design.Text_A_A3 = A3 + ' 75 A'
        Board_Design.Text_A_m = m + ' 16 mm^2'
        
    @Rule (Horse_Power_A_200_220('10'))
    def Horse_Power_A_200_220_10(Self):
        print('10')
        print(A + ' 26.5 A')
        print(cA + ' 25 KPPMCG')
        print(AA + ' 20TA KP')
        print(A1 + ' 29 A')
        print(A2 + ' 80 A')
        print(N + ' 50-SH')
        print(A3 + ' 60 A')
        print(m + ' 10 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 26.5 A'
        Board_Design.MS_A = ' 25 KPPMCG'
        Board_Design.OLR_A = ' 20TA KP'
        Board_Design.FUSE_A =' 80 A'
        Board_Design.MCCB_A =' 50-SH'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '10'
        Board_Design.Text_A_A = A + ' 26.5 A'
        Board_Design.Text_A_cA = cA + ' 25 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 20TA KP'
        Board_Design.Text_A_A1 = A1 + ' 29 A'
        Board_Design.Text_A_A2 = A2 + ' 80 A'
        Board_Design.Text_A_N = N + ' 50-SH'
        Board_Design.Text_A_A3 = A3 + ' 60 A'
        Board_Design.Text_A_m = m + ' 10 mm^2'
        
    @Rule (Horse_Power_A_200_220('7.5'))
    def Horse_Power_A_200_220_7(Self):
        print('7.5')
        print(A + ' 20 A')
        print(cA + ' 20-21 KPPMCG')
        print(AA + ' 20 KP')
        print(A1 + ' 19 A')
        print(A2 + ' 50 A')
        print(N + ' 50-SH')
        print(A3 + ' 40 A')
        print(m + ' 6 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 20 A'
        Board_Design.MS_A = ' 20-21 KPPMCG'
        Board_Design.OLR_A = ' 20 KP'
        Board_Design.FUSE_A =' 50 A'
        Board_Design.MCCB_A =' 50-SH'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '7.5'
        Board_Design.Text_A_A = A + ' 20 A'
        Board_Design.Text_A_cA = cA + ' 20-21 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 20 KP'
        Board_Design.Text_A_A1 = A1 + ' 19 A'
        Board_Design.Text_A_A2 = A2 + ' 50 A'
        Board_Design.Text_A_N = N + ' 50-SH'
        Board_Design.Text_A_A3 = A3 + ' 40 A'
        Board_Design.Text_A_m = m + ' 6 mm^2'
        
    @Rule (Horse_Power_A_200_220('5.5'))
    def Horse_Power_A_200_220_5_5(Self):
        print('5.5')
        print(A + ' 15.2 A')
        print(cA + ' 18 KPPMCG')
        print(AA + ' 18 KP')
        print(A1 + ' 15 A')
        print(A2 + ' 50 A')
        print(N + ' 30-SS')
        print(A3 + ' 30 A')
        print(m + ' 4 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 15.2 A'
        Board_Design.MS_A = ' 18 KPPMCG'
        Board_Design.OLR_A = ' 18 KP'
        Board_Design.FUSE_A =' 50 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '5.5'
        Board_Design.Text_A_A = A + ' 15.2 A'
        Board_Design.Text_A_cA = cA + ' 18 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 18 KP'
        Board_Design.Text_A_A1 = A1 + ' 15 A'
        Board_Design.Text_A_A2 = A2 + ' 50 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 40 A'
        Board_Design.Text_A_m = m + ' 4 mm^2'
        
    @Rule (Horse_Power_A_200_220('5'))
    def Horse_Power_A_200_220_5(Self):
        print('5')
        print(A + ' 14.2 A')
        print(cA + ' 18 KPPMCG')
        print(AA + ' 18 KP')
        print(A1 + ' 15 A')
        print(A2 + ' 50 A')
        print(N + ' 30-SS')
        print(A3 + ' 30 A')
        print(m + ' 4 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 14.2 A'
        Board_Design.MS_A = ' 18 KPPMCG'
        Board_Design.OLR_A = ' 18 KP'
        Board_Design.FUSE_A =' 50 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '5'
        Board_Design.Text_A_A = A + ' 14.2 A'
        Board_Design.Text_A_cA = cA + ' 18 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 18 KP'
        Board_Design.Text_A_A1 = A1 + ' 15 A'
        Board_Design.Text_A_A2 = A2 + ' 50 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 30 A'
        Board_Design.Text_A_m = m + ' 4 mm^2'
        
    @Rule (Horse_Power_A_200_220('4'))
    def Horse_Power_A_200_220_4(Self):
        print('4')
        print(A + ' 11.5 A')
        print(cA + ' 11 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 11 A')
        print(A2 + ' 35 A')
        print(N + ' 30-SS')
        print(A3 + ' 20 A')
        print(m + ' 2.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 11.5 A'
        Board_Design.MS_A = ' 11 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 35 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '4'
        Board_Design.Text_A_A = A + ' 11.5 A'
        Board_Design.Text_A_cA = cA + ' 11 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 11 A'
        Board_Design.Text_A_A2 = A2 + ' 35 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 20 A'
        Board_Design.Text_A_m = m + ' 2.5 mm^2'
        
    @Rule (Horse_Power_A_200_220('3'))
    def Horse_Power_A_200_220_3(Self):
        print('3')
        print(A + ' 8.7 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 9 A')
        print(A2 + ' 25 A')
        print(N + ' 30-SS')
        print(A3 + ' 20 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 8.7 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 25 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '3'
        Board_Design.Text_A_A = A + ' 8.7 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 9 A'
        Board_Design.Text_A_A2 = A2 + ' 25 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 20 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_200_220('2'))
    def Horse_Power_A_200_220_2(Self):
        print('2')
        print(A + ' 6.1 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 6.6 A')
        print(A2 + ' 20 A')
        print(N + ' 30-SS')
        print(A3 + ' 15 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 6.1 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 20 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '2'
        Board_Design.Text_A_A = A + ' 6.1 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 6.6 A'
        Board_Design.Text_A_A2 = A2 + ' 20 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 15 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_200_220('1.5'))
    def Horse_Power_A_200_220_1_5(Self):
        print('1.5')
        print(A + ' 4.5 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 5 A')
        print(A2 + ' 16 A')
        print(N + ' 30-SS')
        print(A3 + ' 10 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 4.5 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 16 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '1.5'
        Board_Design.Text_A_A = A + ' 4.5 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 5 A'
        Board_Design.Text_A_A2 = A2 + ' 16 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 10 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_200_220('1'))
    def Horse_Power_A_200_220_1(Self):
        print('1')
        print(A + ' 3.5 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 3.6 A')
        print(A2 + ' 16 A')
        print(N + ' 30-SS')
        print(A3 + ' 10 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 3.5 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 16 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '1'
        Board_Design.Text_A_A = A + ' 3.5 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 3.6 A'
        Board_Design.Text_A_A2 = A2 + ' 16 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 10 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_200_220('0.75'))
    def Horse_Power_A_200_220_0_75(Self):
        print('0.75')
        print(A + ' 2.7 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 2.5 A')
        print(A2 + ' 10 A')
        print(N + ' 30-SS')
        print(A3 + ' 5 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 2.7 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 10 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '0.75'
        Board_Design.Text_A_A = A + ' 2.7 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 2.5 A'
        Board_Design.Text_A_A2 = A2 + ' 10 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 5 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_200_220('0.5'))
    def Horse_Power_A_200_220_0_5(Self):
        print('0.5')
        print(A + ' 2.1 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 2.1 A')
        print(A2 + ' 6 A')
        print(N + ' 30-SS')
        print(A3 + ' 5 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 2.1 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 6 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '0.5'
        Board_Design.Text_A_A = A + ' 2.1 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 2.1 A'
        Board_Design.Text_A_A2 = A2 + ' 6 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 5 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_200_220('1/3'))
    def Horse_Power_A_200_220_0_33(Self):
        print('1/3')
        print(A + ' 1.5 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 1.7 A')
        print(A2 + ' 6 A')
        print(N + ' 30-SS')
        print(A3 + ' 3 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 1.5 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 6 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '1/3'
        Board_Design.Text_A_A = A + ' 1.5 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 1.7 A'
        Board_Design.Text_A_A2 = A2 + ' 6 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 3 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_200_220('0.25'))
    def Horse_Power_A_200_220_0_25(Self):
        print('0.25')
        print(A + ' 1.2 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 1.3 A')
        print(A2 + ' 4 A')
        print(N + ' 30-SS')
        print(A3 + ' 3 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 1.2 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 4 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '0.25'
        Board_Design.Text_A_A = A + ' 1.2 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 1.3 A'
        Board_Design.Text_A_A2 = A2 + ' 4 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 3 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_200_220('1/6'))
    def Horse_Power_A_200_220_5_0_1667(Self):
        print('1/6')
        print(A + ' 0.8 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 0.9 A')
        print(A2 + ' 4 A')
        print(N + ' 30-SS')
        print(A3 + ' 3 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 0.8 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 4 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '1/6'
        Board_Design.Text_A_A = A + ' 0.8 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 0.9 A'
        Board_Design.Text_A_A2 = A2 + ' 4 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 3 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_200_220('1/8'))
    def Horse_Power_A_200_220_0_125(Self):
        print('1/8')
        print(A + ' 0.7 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 0.7 A')
        print(A2 + ' 2 A')
        print(N + ' 30-SS')
        print(A3 + ' 3 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 0.7 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 2 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '1/8'
        Board_Design.Text_A_A = A + ' 0.7 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 0.7 A'
        Board_Design.Text_A_A2 = A2 + ' 2 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 3 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_200_220('1/12'))
    def Horse_Power_A_200_220_0_083(Self):
        print('1/12')
        print(A + ' 0.5 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 0.5 A')
        print(A2 + ' 2 A')
        print(N + ' 30-SS')
        print(A3 + ' 3 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 0.5 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 2 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '1/12'
        Board_Design.Text_A_A = A + ' 0.5 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 0.5 A'
        Board_Design.Text_A_A2 = A2 + ' 2 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 3 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
#_________________________________________________________________________________________________________________________________
#                                                        A  V : 380
#_________________________________________________________________________________________________________________________________

    @Rule (Horse_Power_A_380('180'))
    def Horse_Power_A_380_180(Self):
        print('180')
        print(A + ' 245 A')
        print(cA + ' 220 KPPMCG')
        print(AA + ' 220 RH KP')
        print(A1 + ' 210 A')
        print(A2 + ' 500 A')
        print(N + ' 400-SS')
        print(A3 + ' 400 A')
        print(m + ' 150 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 245 A'
        Board_Design.MS_A = ' 220 KPPMCG'
        Board_Design.OLR_A = ' 220RH KP'
        Board_Design.FUSE_A =' 500 A'
        Board_Design.MCCB_A =' 400-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '180'
        Board_Design.Text_A_A = A + ' 245 A'
        Board_Design.Text_A_cA = cA + ' 220 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 220RH KP'
        Board_Design.Text_A_A1 = A1 + ' 210 A'
        Board_Design.Text_A_A2 = A2 + ' 500 A'
        Board_Design.Text_A_N = N + ' 400-SS'
        Board_Design.Text_A_A3 = A3 + ' 400 A'
        Board_Design.Text_A_m = m + ' 150 mm^2'
        
    @Rule (Horse_Power_A_380('150'))
    def Horse_Power_A_380_150(Self):
        print('150')
        print(A + ' 205 A')
        print(cA + ' 220 KPPMCG')
        print(AA + ' 220 RH KP')
        print(A1 + ' 180 A')
        print(A2 + ' 500 A')
        print(N + ' 400-SS')
        print(A3 + ' 300 A')
        print(m + ' 95 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 205 A'
        Board_Design.MS_A = ' 220 KPPMCG'
        Board_Design.OLR_A = ' 220RH KP'
        Board_Design.FUSE_A =' 500 A'
        Board_Design.MCCB_A =' 400-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '150'
        Board_Design.Text_A_A = A + ' 205 A'
        Board_Design.Text_A_cA = cA + ' 220 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 220RH KP'
        Board_Design.Text_A_A1 = A1 + ' 180 A'
        Board_Design.Text_A_A2 = A2 + ' 500 A'
        Board_Design.Text_A_N = N + ' 400-SS'
        Board_Design.Text_A_A3 = A3 + ' 300 A'
        Board_Design.Text_A_m = m + ' 95 mm^2'
        
    @Rule (Horse_Power_A_380('125'))
    def Horse_Power_A_380_125(Self):
        print('125')
        print(A + ' 168 A')
        print(cA + ' 180 KPPMCG')
        print(AA + ' 220 RH KP')
        print(A1 + ' 150 A')
        print(A2 + ' 315 A')
        print(N + ' 250-SS')
        print(A3 + ' 250 A')
        print(m + ' 70 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 168 A'
        Board_Design.MS_A = ' 180 KPPMCG'
        Board_Design.OLR_A = ' 220RH KP'
        Board_Design.FUSE_A =' 315 A'
        Board_Design.MCCB_A =' 250-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '125'
        Board_Design.Text_A_A = A + ' 168 A'
        Board_Design.Text_A_cA = cA + ' 180 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 220RH KP'
        Board_Design.Text_A_A1 = A1 + ' 150 A'
        Board_Design.Text_A_A2 = A2 + ' 315 A'
        Board_Design.Text_A_N = N + ' 250-SS'
        Board_Design.Text_A_A3 = A3 + ' 250 A'
        Board_Design.Text_A_m = m + ' 70 mm^2'
        
    @Rule (Horse_Power_A_380('100'))
    def Horse_Power_A_380_100(Self):
        print('100')
        print(A + ' 140 A')
        print(cA + ' 150 KPPMCG')
        print(AA + ' 120 TA KP')
        print(A1 + ' 125 A')
        print(A2 + ' 315 A')
        print(N + ' 250-SS')
        print(A3 + ' 225 A')
        print(m + ' 50 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 140 A'
        Board_Design.MS_A = ' 150 KPPMCG'
        Board_Design.OLR_A = ' 120TA KP'
        Board_Design.FUSE_A =' 315 A'
        Board_Design.MCCB_A =' 250-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '100'
        Board_Design.Text_A_A = A + ' 140 A'
        Board_Design.Text_A_cA = cA + ' 150 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 120TA KP'
        Board_Design.Text_A_A1 = A1 + ' 125 A'
        Board_Design.Text_A_A2 = A2 + ' 315 A'
        Board_Design.Text_A_N = N + ' 250-SS'
        Board_Design.Text_A_A3 = A3 + ' 225 A'
        Board_Design.Text_A_m = m + ' 50 mm^2'
        
    @Rule (Horse_Power_A_380('75'))
    def Horse_Power_A_380_75(Self):
        print('75')
        print(A + ' 105 A')
        print(cA + ' 105 KPPMCG')
        print(AA + ' 60 TA KP')
        print(A1 + ' 95 A')
        print(A2 + ' 200 A')
        print(N + ' 250-SS')
        print(A3 + ' 175 A')
        print(m + ' 50 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 105 A'
        Board_Design.MS_A = ' 105 KPPMCG'
        Board_Design.OLR_A = ' 60TA KP'
        Board_Design.FUSE_A =' 200 A'
        Board_Design.MCCB_A =' 250-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '75'
        Board_Design.Text_A_A = A + ' 105 A'
        Board_Design.Text_A_cA = cA + ' 105 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 60TA KP'
        Board_Design.Text_A_A1 = A1 + ' 95 A'
        Board_Design.Text_A_A2 = A2 + ' 200 A'
        Board_Design.Text_A_N = N + ' 250-SS'
        Board_Design.Text_A_A3 = A3 + ' 175 A'
        Board_Design.Text_A_m = m + ' 50 mm^2'
        
    @Rule (Horse_Power_A_380('60'))
    def Horse_Power_A_380_60(Self):
        print('60')
        print(A + ' 86 A')
        print(cA + ' 80 KPPMCG')
        print(AA + ' 60 TA KP')
        print(A1 + ' 82 A')
        print(A2 + ' 200 A')
        print(N + ' 160-SS')
        print(A3 + ' 125 A')
        print(m + ' 35 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 86 A'
        Board_Design.MS_A = ' 80 KPPMCG'
        Board_Design.OLR_A = ' 60TA KP'
        Board_Design.FUSE_A =' 200 A'
        Board_Design.MCCB_A =' 160-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '60'
        Board_Design.Text_A_A = A + ' 86 A'
        Board_Design.Text_A_cA = cA + ' 80 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 60TA KP'
        Board_Design.Text_A_A1 = A1 + ' 82 A'
        Board_Design.Text_A_A2 = A2 + ' 200 A'
        Board_Design.Text_A_N = N + ' 160-SS'
        Board_Design.Text_A_A3 = A3 + ' 125 A'
        Board_Design.Text_A_m = m + ' 35 mm^2'
        
    @Rule (Horse_Power_A_380('50'))
    def Horse_Power_A_380_50(Self):
        print('50')
        print(A + ' 72 A')
        print(cA + ' 80 KPPMCG')
        print(AA + ' 60 TA KP')
        print(A1 + ' 67 A')
        print(A2 + ' 160 A')
        print(N + ' 100-SS')
        print(A3 + ' 100 A')
        print(m + ' 25 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 72 A'
        Board_Design.MS_A = ' 80 KPPMCG'
        Board_Design.OLR_A = ' 60TA KP'
        Board_Design.FUSE_A =' 160 A'
        Board_Design.MCCB_A =' 100-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '50'
        Board_Design.Text_A_A = A + ' 72 A'
        Board_Design.Text_A_cA = cA + ' 80 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 60TA KP'
        Board_Design.Text_A_A1 = A1 + ' 67 A'
        Board_Design.Text_A_A2 = A2 + ' 160 A'
        Board_Design.Text_A_N = N + ' 160-SS'
        Board_Design.Text_A_A3 = A3 + ' 100 A'
        Board_Design.Text_A_m = m + ' 25 mm^2'
        
    @Rule (Horse_Power_A_380('40'))
    def Horse_Power_A_380_40(Self):
        print('40')
        print(A + ' 57 A')
        print(cA + ' 65 KPPMCG')
        print(AA + ' 60 KP')
        print(A1 + ' 54 A')
        print(A2 + ' 160 A')
        print(N + ' 100-SS')
        print(A3 + ' 100 A')
        print(m + ' 25 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 57 A'
        Board_Design.MS_A = ' 65 KPPMCG'
        Board_Design.OLR_A = ' 60 KP'
        Board_Design.FUSE_A =' 160 A'
        Board_Design.MCCB_A =' 100-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '40'
        Board_Design.Text_A_A = A + ' 57 A'
        Board_Design.Text_A_cA = cA + ' 65 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 60 KP'
        Board_Design.Text_A_A1 = A1 + ' 54 A'
        Board_Design.Text_A_A2 = A2 + ' 160 A'
        Board_Design.Text_A_N = N + ' 100-SS'
        Board_Design.Text_A_A3 = A3 + ' 100 A'
        Board_Design.Text_A_m = m + ' 25 mm^2'
        
        
    @Rule (Horse_Power_A_380('30'))
    def Horse_Power_A_380_30(Self):
        print('30')
        print(A + ' 43 A')
        print(cA + ' 50 KPPMCG')
        print(AA + ' 60 KP')
        print(A1 + ' 42 A')
        print(A2 + ' 125 A')
        print(N + ' 100-SS')
        print(A3 + ' 75 A')
        print(m + ' 16 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 43 A'
        Board_Design.MS_A = ' 50 KPPMCG'
        Board_Design.OLR_A = ' 60 KP'
        Board_Design.FUSE_A =' 125 A'
        Board_Design.MCCB_A =' 100-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '30'
        Board_Design.Text_A_A = A + ' 43 A'
        Board_Design.Text_A_cA = cA + ' 50 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 60 KP'
        Board_Design.Text_A_A1 = A1 + ' 42 A'
        Board_Design.Text_A_A2 = A2 + ' 125 A'
        Board_Design.Text_A_N = N + ' 100-SS'
        Board_Design.Text_A_A3 = A3 + ' 75 A'
        Board_Design.Text_A_m = m + ' 16 mm^2'
        
    @Rule (Horse_Power_A_380('25'))
    def Horse_Power_A_380_25(Self):
        print('25')
        print(A + ' 37 A')
        print(cA + ' 35 KPPMCG')
        print(AA + ' 20 TA KP')
        print(A1 + ' 35 A')
        print(A2 + ' 80 A')
        print(N + ' 60-SH')
        print(A3 + ' 60 A')
        print(m + ' 10 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 37 A'
        Board_Design.MS_A = ' 35 KPPMCG'
        Board_Design.OLR_A = ' 20TA KP'
        Board_Design.FUSE_A =' 80 A'
        Board_Design.MCCB_A =' 60-SH'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '25'
        Board_Design.Text_A_A = A + ' 37 A'
        Board_Design.Text_A_cA = cA + ' 35 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 20TA KP'
        Board_Design.Text_A_A1 = A1 + ' 35 A'
        Board_Design.Text_A_A2 = A2 + ' 80 A'
        Board_Design.Text_A_N = N + ' 60-SH'
        Board_Design.Text_A_A3 = A3 + ' 60 A'
        Board_Design.Text_A_m = m + ' 10 mm^2'
        
    @Rule (Horse_Power_A_380('20'))
    def Horse_Power_A_380_20(Self):
        print('20')
        print(A + ' 30 A')
        print(cA + ' 25 KPPMCG')
        print(AA + ' 20 TA KP')
        print(A1 + ' 29 A')
        print(A2 + ' 80 A')
        print(N + ' 60-SH')
        print(A3 + ' 60 A')
        print(m + ' 10 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 30 A'
        Board_Design.MS_A = ' 25 KPPMCG'
        Board_Design.OLR_A = ' 20TA KP'
        Board_Design.FUSE_A =' 80 A'
        Board_Design.MCCB_A =' 60-SH'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '20'
        Board_Design.Text_A_A = A + ' 30 A'
        Board_Design.Text_A_cA = cA + ' 25 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 20TA KP'
        Board_Design.Text_A_A1 = A1 + ' 29 A'
        Board_Design.Text_A_A2 = A2 + ' 80 A'
        Board_Design.Text_A_N = N + ' 60-SH'
        Board_Design.Text_A_A3 = A3 + ' 60 A'
        Board_Design.Text_A_m = m + ' 10 mm^2'
        
    @Rule (Horse_Power_A_380('15'))
    def Horse_Power_A_380_15(Self):
        print('15')
        print(A + ' 22 A')
        print(cA + ' 20-21 KPPMCG')
        print(AA + ' 20 KP')
        print(A1 + ' 19 A')
        print(A2 + ' 50 A')
        print(N + ' 50-SH')
        print(A3 + ' 50 A')
        print(m + ' 6 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 22 A'
        Board_Design.MS_A = ' 20-21 KPPMCG'
        Board_Design.OLR_A = ' 20 KP'
        Board_Design.FUSE_A =' 50 A'
        Board_Design.MCCB_A =' 50-SH'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '15'
        Board_Design.Text_A_A = A + ' 22 A'
        Board_Design.Text_A_cA = cA + ' 20-21 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 20 KP'
        Board_Design.Text_A_A1 = A1 + ' 19 A'
        Board_Design.Text_A_A2 = A2 + ' 50 A'
        Board_Design.Text_A_N = N + ' 50-SH'
        Board_Design.Text_A_A3 = A3 + ' 50 A'
        Board_Design.Text_A_m = m + ' 6 mm^2'
        
    @Rule (Horse_Power_A_380('10'))
    def Horse_Power_A_380_10(Self):
        print('10')
        print(A + ' 16 A')
        print(cA + ' 18 KPPMCG')
        print(AA + ' 18 KP')
        print(A1 + ' 15 A')
        print(A2 + ' 50 A')
        print(N + ' 50-SH')
        print(A3 + ' 30 A')
        print(m + ' 4 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 16 A'
        Board_Design.MS_A = ' 18 KPPMCG'
        Board_Design.OLR_A = ' 18 KP'
        Board_Design.FUSE_A =' 50 A'
        Board_Design.MCCB_A =' 50-SH'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '10'
        Board_Design.Text_A_A = A + ' 16 A'
        Board_Design.Text_A_cA = cA + ' 18 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 18 KP'
        Board_Design.Text_A_A1 = A1 + ' 15 A'
        Board_Design.Text_A_A2 = A2 + ' 50 A'
        Board_Design.Text_A_N = N + ' 50-SH'
        Board_Design.Text_A_A3 = A3 + ' 30 A'
        Board_Design.Text_A_m = m + ' 4 mm^2'
        
        
    @Rule (Horse_Power_A_380('7.5'))
    def Horse_Power_A_380_7_5(Self):
        print('7.5')
        print(A + ' 11.8 A')
        print(cA + ' 11 KPPMCG')
        print(AA + ' 12 AB KP')
        print(A1 + ' 11 A')
        print(A2 + ' 35 A')
        print(N + ' 30-SS')
        print(A3 + ' 30 A')
        print(m + ' 2.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 11.8 A'
        Board_Design.MS_A = ' 11 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 35 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '7.5'
        Board_Design.Text_A_A = A + ' 11.8 A'
        Board_Design.Text_A_cA = cA + ' 11 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 11 A'
        Board_Design.Text_A_A2 = A2 + ' 35 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 30 A'
        Board_Design.Text_A_m = m + ' 2.5 mm^2'
        
    @Rule (Horse_Power_A_380('5.5'))
    def Horse_Power_A_380_5_5(Self):
        print('5.5')
        print(A + ' 8.7 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12 AB KP')
        print(A1 + ' 9 A')
        print(A2 + ' 25 A')
        print(N + ' 30-SS')
        print(A3 + ' 20 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 8.7 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 25 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '5.5'
        Board_Design.Text_A_A = A + ' 8.7 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 9 A'
        Board_Design.Text_A_A2 = A2 + ' 25 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 20 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_380('5'))
    def Horse_Power_A_380_5(Self):
        print('5')
        print(A + ' 8.5 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12 AB KP')
        print(A1 + ' 9 A')
        print(A2 + ' 25 A')
        print(N + ' 30-SS')
        print(A3 + ' 20 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 8.5 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 25 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '5'
        Board_Design.Text_A_A = A + ' 8.5 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 9 A'
        Board_Design.Text_A_A2 = A2 + ' 25 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 20 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_380('4'))
    def Horse_Power_A_380_4(Self):
        print('4')
        print(A + ' 6.8 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12 AB KP')
        print(A1 + ' 6.6 A')
        print(A2 + ' 20 A')
        print(N + ' 30-SS')
        print(A3 + ' 15 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 6.8 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 25 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '4'
        Board_Design.Text_A_A = A + ' 6.8 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 6.6 A'
        Board_Design.Text_A_A2 = A2 + ' 20 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 15 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
        
    @Rule (Horse_Power_A_380('3'))
    def Horse_Power_A_380_3(Self):
        print('3')
        print(A + ' 5.1 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12 AB KP')
        print(A1 + ' 5 A')
        print(A2 + ' 16 A')
        print(N + ' 30-SS')
        print(A3 + ' 10 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 5.1 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 16 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '3'
        Board_Design.Text_A_A = A + ' 5.1 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 5 A'
        Board_Design.Text_A_A2 = A2 + ' 16 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 10 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
        
    @Rule (Horse_Power_A_380('2'))
    def Horse_Power_A_380_2(Self):
        print('2')
        print(A + ' 3.6 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12 AB KP')
        print(A1 + ' 3.6 A')
        print(A2 + ' 16 A')
        print(N + ' 30-SS')
        print(A3 + ' 10 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 3.6 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 16 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '2'
        Board_Design.Text_A_A = A + ' 3.6 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 3.6 A'
        Board_Design.Text_A_A2 = A2 + ' 16 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 10 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
        
    @Rule (Horse_Power_A_380('1.5'))
    def Horse_Power_A_380_1_5(Self):
        print('1.5')
        print(A + ' 2.7 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12 AB KP')
        print(A1 + ' 2.5 A')
        print(A2 + ' 10 A')
        print(N + ' 30-SS')
        print(A3 + ' 5 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 2.7 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 10 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '1.5'
        Board_Design.Text_A_A = A + ' 2.7 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 2.5 A'
        Board_Design.Text_A_A2 = A2 + ' 10 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 5 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
        
    @Rule (Horse_Power_A_380('1'))
    def Horse_Power_A_380_1(Self):
        print('1')
        print(A + ' 2 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12 AB KP')
        print(A1 + ' 2.1 A')
        print(A2 + ' 6 A')
        print(N + ' 30-SS')
        print(A3 + ' 5 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 2 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 6 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '1'
        Board_Design.Text_A_A = A + ' 2 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 2.1 A'
        Board_Design.Text_A_A2 = A2 + ' 6 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 5 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
        
    @Rule (Horse_Power_A_380('0.75'))
    def Horse_Power_A_380_0_75(Self):
        print('0.75')
        print(A + ' 1.6 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12 AB KP')
        print(A1 + ' 1.7 A')
        print(A2 + ' 6 A')
        print(N + ' 30-SS')
        print(A3 + ' 3 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 1.6 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 6 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '0.75'
        Board_Design.Text_A_A = A + ' 1.6 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 1.7 A'
        Board_Design.Text_A_A2 = A2 + ' 6 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 3 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_380('0.5'))
    def Horse_Power_A_380_0_5(Self):
        print('0.5')
        print(A + ' 1.2 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12 AB KP')
        print(A1 + ' 1.3 A')
        print(A2 + ' 4 A')
        print(N + ' 30-SS')
        print(A3 + ' 3 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 1.2 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 4 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '0.5'
        Board_Design.Text_A_A = A + ' 1.2 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 1.3 A'
        Board_Design.Text_A_A2 = A2 + ' 4 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 3 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
        
    @Rule (Horse_Power_A_380('1/3'))
    def Horse_Power_A_380_0_33(Self):
        print('1/3')
        print(A + ' 0.85 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12 AB KP')
        print(A1 + ' 0.9 A')
        print(A2 + ' 4 A')
        print(N + ' 30-SS')
        print(A3 + ' 3 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 0.85 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 4 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '1/3'
        Board_Design.Text_A_A = A + ' 0.85 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 0.9 A'
        Board_Design.Text_A_A2 = A2 + ' 4 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 3 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_380('0.25'))
    def Horse_Power_A_380_0_25(Self):
        print('0.25')
        print(A + ' 0.7 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12 AB KP')
        print(A1 + ' 0.7 A')
        print(A2 + ' 2 A')
        print(N + ' 30-SS')
        print(A3 + ' 3 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 0.7 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 2 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '0.25'
        Board_Design.Text_A_A = A + ' 0.7 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 0.7 A'
        Board_Design.Text_A_A2 = A2 + ' 2 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 3 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_380('1/6'))
    def Horse_Power_A_380_0_1667(Self):
        print('1/6')
        print(A + ' 0.5 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12 AB KP')
        print(A1 + ' 0.5 A')
        print(A2 + ' 2 A')
        print(N + ' 30-SS')
        print(A3 + ' 3 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 0.5 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 2 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '1/6'
        Board_Design.Text_A_A = A + ' 0.5 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 0.5 A'
        Board_Design.Text_A_A2 = A2 + ' 2 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 3 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_380('1/8'))
    def Horse_Power_A_380_0_125(Self):
        print('1/8')
        print(A + ' 0.4 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12 AB KP')
        print(A1 + ' 0.35 A')
        print(A2 + ' 2 A')
        print(N + '__')
        print(A3 + '__')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 0.4 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 2 A'
        Board_Design.MCCB_A =' __'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '1/8'
        Board_Design.Text_A_A = A + ' 0.4 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 0.35 A'
        Board_Design.Text_A_A2 = A2 + ' 2 A'
        Board_Design.Text_A_N = N + ' __'
        Board_Design.Text_A_A3 = A3 + ' __'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_380('1/12'))
    def Horse_Power_A_380_0_083(Self):
        print('1/12')
        print(A + ' 0.3 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12 AB KP')
        print(A1 + ' 0.24 A')
        print(A2 + ' 2 A')
        print(N + '__')
        print(A3 + '__')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 0.3 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 2 A'
        Board_Design.MCCB_A =' __'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '1/12'
        Board_Design.Text_A_A = A + ' 0.3 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 0.24 A'
        Board_Design.Text_A_A2 = A2 + ' 2 A'
        Board_Design.Text_A_N = N + ' __'
        Board_Design.Text_A_A3 = A3 + ' __'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'

#_________________________________________________________________________________________________________________________________
#                                                        A  V : 415
#_________________________________________________________________________________________________________________________________

    @Rule (Horse_Power_A_415('180'))
    def Horse_Power_A_415_180(Self):
        print('180')
        print(A + ' 230 A')
        print(cA + ' 220 KPPMCG')
        print(AA + ' 220 RH KP')
        print(A1 + ' 210 A')
        print(A2 + ' 500 A')
        print(N + ' 400-SS')
        print(A3 + ' 400 A')
        print(m + ' 150 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 230 A'
        Board_Design.MS_A = ' 220 KPPMCG'
        Board_Design.OLR_A = ' 220RH KP'
        Board_Design.FUSE_A =' 500 A'
        Board_Design.MCCB_A =' 400-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '180'
        Board_Design.Text_A_A = A + ' 230 A'
        Board_Design.Text_A_cA = cA + ' 220 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 220RH KP'
        Board_Design.Text_A_A1 = A1 + ' 210 A'
        Board_Design.Text_A_A2 = A2 + ' 500 A'
        Board_Design.Text_A_N = N + ' 400-SS'
        Board_Design.Text_A_A3 = A3 + ' 400 A'
        Board_Design.Text_A_m = m + ' 150 mm^2'
        
        
    @Rule (Horse_Power_A_415('150'))
    def Horse_Power_A_415_150(Self):
        print('150')
        print(A + ' 190 A')
        print(cA + ' 220 KPPMCG')
        print(AA + ' 220 RH KP')
        print(A1 + ' 180 A')
        print(A2 + ' 500 A')
        print(N + ' 400-SS')
        print(A3 + ' 300 A')
        print(m + ' 95 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 190 A'
        Board_Design.MS_A = ' 220 KPPMCG'
        Board_Design.OLR_A = ' 220RH KP'
        Board_Design.FUSE_A =' 500 A'
        Board_Design.MCCB_A =' 400-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '150'
        Board_Design.Text_A_A = A + ' 190 A'
        Board_Design.Text_A_cA = cA + ' 220 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 220RH KP'
        Board_Design.Text_A_A1 = A1 + ' 180 A'
        Board_Design.Text_A_A2 = A2 + ' 500 A'
        Board_Design.Text_A_N = N + ' 400-SS'
        Board_Design.Text_A_A3 = A3 + ' 300 A'
        Board_Design.Text_A_m = m + ' 95 mm^2'
        
    @Rule (Horse_Power_A_415('125'))
    def Horse_Power_A_415_125(Self):
        print('125')
        print(A + ' 160 A')
        print(cA + ' 180 KPPMCG')
        print(AA + ' 220 RH KP')
        print(A1 + ' 150 A')
        print(A2 + ' 315 A')
        print(N + ' 250-SS')
        print(A3 + ' 250 A')
        print(m + ' 70 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 160 A'
        Board_Design.MS_A = ' 180 KPPMCG'
        Board_Design.OLR_A = ' 220RH KP'
        Board_Design.FUSE_A =' 315 A'
        Board_Design.MCCB_A =' 250-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '125'
        Board_Design.Text_A_A = A + ' 160 A'
        Board_Design.Text_A_cA = cA + ' 180 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 220RH KP'
        Board_Design.Text_A_A1 = A1 + ' 150 A'
        Board_Design.Text_A_A2 = A2 + ' 315 A'
        Board_Design.Text_A_N = N + ' 250-SS'
        Board_Design.Text_A_A3 = A3 + ' 250 A'
        Board_Design.Text_A_m = m + ' 70 mm^2'
        
    @Rule (Horse_Power_A_415('100'))
    def Horse_Power_A_415_100(Self):
        print('100')
        print(A + ' 130 A')
        print(cA + ' 150 KPPMCG')
        print(AA + ' 120 TA KP')
        print(A1 + ' 125 A')
        print(A2 + ' 315 A')
        print(N + ' 250-SS')
        print(A3 + ' 225 A')
        print(m + ' 50 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 130 A'
        Board_Design.MS_A = ' 150 KPPMCG'
        Board_Design.OLR_A = ' 120TA KP'
        Board_Design.FUSE_A =' 315 A'
        Board_Design.MCCB_A =' 250-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '100'
        Board_Design.Text_A_A = A + ' 130 A'
        Board_Design.Text_A_cA = cA + ' 150 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 120TA KP'
        Board_Design.Text_A_A1 = A1 + ' 125 A'
        Board_Design.Text_A_A2 = A2 + ' 315 A'
        Board_Design.Text_A_N = N + ' 250-SS'
        Board_Design.Text_A_A3 = A3 + ' 225 A'
        Board_Design.Text_A_m = m + ' 50 mm^2'
        
    @Rule (Horse_Power_A_415('75'))
    def Horse_Power_A_415_75(Self):
        print('75')
        print(A + ' 98 A')
        print(cA + ' 105 KPPMCG')
        print(AA + ' 60 TA KP')
        print(A1 + ' 95 A')
        print(A2 + ' 200 A')
        print(N + ' 250-SS')
        print(A3 + ' 175 A')
        print(m + ' 50 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 98 A'
        Board_Design.MS_A = ' 105 KPPMCG'
        Board_Design.OLR_A = ' 60TA KP'
        Board_Design.FUSE_A =' 200 A'
        Board_Design.MCCB_A =' 250-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '75'
        Board_Design.Text_A_A = A + ' 98 A'
        Board_Design.Text_A_cA = cA + ' 105 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 60TA KP'
        Board_Design.Text_A_A1 = A1 + ' 95 A'
        Board_Design.Text_A_A2 = A2 + ' 200 A'
        Board_Design.Text_A_N = N + ' 250-SS'
        Board_Design.Text_A_A3 = A3 + ' 175 A'
        Board_Design.Text_A_m = m + ' 50 mm^2'
        
    @Rule (Horse_Power_A_415('60'))
    def Horse_Power_A_415_60(Self):
        print('60')
        print(A + ' 79 A')
        print(cA + ' 80 KPPMCG')
        print(AA + ' 60 TA KP')
        print(A1 + ' 82 A')
        print(A2 + ' 200 A')
        print(N + ' 160-SS')
        print(A3 + ' 125 A')
        print(m + ' 35 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 79 A'
        Board_Design.MS_A = ' 80 KPPMCG'
        Board_Design.OLR_A = ' 60TA KP'
        Board_Design.FUSE_A =' 200 A'
        Board_Design.MCCB_A =' 160-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '60'
        Board_Design.Text_A_A = A + ' 79 A'
        Board_Design.Text_A_cA = cA + ' 80 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 60TA KP'
        Board_Design.Text_A_A1 = A1 + ' 82 A'
        Board_Design.Text_A_A2 = A2 + ' 200 A'
        Board_Design.Text_A_N = N + ' 160-SS'
        Board_Design.Text_A_A3 = A3 + ' 125 A'
        Board_Design.Text_A_m = m + ' 35 mm^2'
        
    @Rule (Horse_Power_A_415('50'))
    def Horse_Power_A_415_50(Self):
        print('50')
        print(A + ' 67 A')
        print(cA + ' 80 KPPMCG')
        print(AA + ' 60 TA KP')
        print(A1 + ' 67 A')
        print(A2 + ' 160 A')
        print(N + ' 100-SS')
        print(A3 + ' 100 A')
        print(m + ' 25 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 67 A'
        Board_Design.MS_A = ' 80 KPPMCG'
        Board_Design.OLR_A = ' 60TA KP'
        Board_Design.FUSE_A =' 160 A'
        Board_Design.MCCB_A =' 100-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '50'
        Board_Design.Text_A_A = A + ' 67 A'
        Board_Design.Text_A_cA = cA + ' 80 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 60TA KP'
        Board_Design.Text_A_A1 = A1 + ' 67 A'
        Board_Design.Text_A_A2 = A2 + ' 160 A'
        Board_Design.Text_A_N = N + ' 100-SS'
        Board_Design.Text_A_A3 = A3 + ' 100 A'
        Board_Design.Text_A_m = m + ' 25 mm^2'
        
    @Rule (Horse_Power_A_415('40'))
    def Horse_Power_A_415_40(Self):
        print('40')
        print(A + ' 54 A')
        print(cA + ' 65 KPPMCG')
        print(AA + ' 60 KP')
        print(A1 + ' 54 A')
        print(A2 + ' 160 A')
        print(N + ' 100-SS')
        print(A3 + ' 100 A')
        print(m + ' 25 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 54 A'
        Board_Design.MS_A = ' 65 KPPMCG'
        Board_Design.OLR_A = ' 60 KP'
        Board_Design.FUSE_A =' 160 A'
        Board_Design.MCCB_A =' 100-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '40'
        Board_Design.Text_A_A = A + ' 54 A'
        Board_Design.Text_A_cA = cA + ' 65 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 60 KP'
        Board_Design.Text_A_A1 = A1 + ' 54 A'
        Board_Design.Text_A_A2 = A2 + ' 160 A'
        Board_Design.Text_A_N = N + ' 100-SS'
        Board_Design.Text_A_A3 = A3 + ' 100 A'
        Board_Design.Text_A_m = m + ' 25 mm^2'
        
    @Rule (Horse_Power_A_415('30'))
    def Horse_Power_A_415_30(Self):
        print('30')
        print(A + ' 40 A')
        print(cA + ' 50 KPPMCG')
        print(AA + ' 60 KP')
        print(A1 + ' 42 A')
        print(A2 + ' 125 A')
        print(N + ' 100-SS')
        print(A3 + ' 75 A')
        print(m + ' 16 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 40 A'
        Board_Design.MS_A = ' 50 KPPMCG'
        Board_Design.OLR_A = ' 60 KP'
        Board_Design.FUSE_A =' 125 A'
        Board_Design.MCCB_A =' 100-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '30'
        Board_Design.Text_A_A = A + ' 40 A'
        Board_Design.Text_A_cA = cA + ' 50 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 60 KP'
        Board_Design.Text_A_A1 = A1 + ' 42 A'
        Board_Design.Text_A_A2 = A2 + ' 125 A'
        Board_Design.Text_A_N = N + ' 100-SS'
        Board_Design.Text_A_A3 = A3 + ' 75 A'
        Board_Design.Text_A_m = m + ' 16 mm^2'
        
    @Rule (Horse_Power_A_415('25'))
    def Horse_Power_A_415_25(Self):
        print('25')
        print(A + ' 35 A')
        print(cA + ' 35 KPPMCG')
        print(AA + ' 20 TA KP')
        print(A1 + ' 35 A')
        print(A2 + ' 80 A')
        print(N + ' 60-SH')
        print(A3 + ' 60 A')
        print(m + ' 10 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 35 A'
        Board_Design.MS_A = ' 35 KPPMCG'
        Board_Design.OLR_A = ' 20TA KP'
        Board_Design.FUSE_A =' 80 A'
        Board_Design.MCCB_A =' 60-SH'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '25'
        Board_Design.Text_A_A = A + ' 35 A'
        Board_Design.Text_A_cA = cA + ' 35 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 20TA KP'
        Board_Design.Text_A_A1 = A1 + ' 35 A'
        Board_Design.Text_A_A2 = A2 + ' 80 A'
        Board_Design.Text_A_N = N + ' 60-SH'
        Board_Design.Text_A_A3 = A3 + ' 60 A'
        Board_Design.Text_A_m = m + ' 10 mm^2'
        
    @Rule (Horse_Power_A_415('20'))
    def Horse_Power_A_415_20(Self):
        print('20')
        print(A + ' 28 A')
        print(cA + ' 25 KPPMCG')
        print(AA + ' 20 TA KP')
        print(A1 + ' 29 A')
        print(A2 + ' 80 A')
        print(N + ' 60-SH')
        print(A3 + ' 60 A')
        print(m + ' 10 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 28 A'
        Board_Design.MS_A = ' 25 KPPMCG'
        Board_Design.OLR_A = ' 20TA KP'
        Board_Design.FUSE_A =' 80 A'
        Board_Design.MCCB_A =' 60-SH'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '20'
        Board_Design.Text_A_A = A + ' 28 A'
        Board_Design.Text_A_cA = cA + ' 25 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 20TA KP'
        Board_Design.Text_A_A1 = A1 + ' 29 A'
        Board_Design.Text_A_A2 = A2 + ' 80 A'
        Board_Design.Text_A_N = N + ' 60-SH'
        Board_Design.Text_A_A3 = A3 + ' 60 A'
        Board_Design.Text_A_m = m + ' 10 mm^2'
        
    @Rule (Horse_Power_A_415('15'))
    def Horse_Power_A_415_15(Self):
        print('15')
        print(A + ' 21 A')
        print(cA + ' 20-21 KPPMCG')
        print(AA + ' 20 KP')
        print(A1 + ' 19 A')
        print(A2 + ' 50 A')
        print(N + ' 50-SH')
        print(A3 + ' 50 A')
        print(m + ' 6 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 21 A'
        Board_Design.MS_A = ' 20-21 KPPMCG'
        Board_Design.OLR_A = ' 20 KP'
        Board_Design.FUSE_A =' 50 A'
        Board_Design.MCCB_A =' 50-SH'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '15'
        Board_Design.Text_A_A = A + ' 21 A'
        Board_Design.Text_A_cA = cA + ' 20-21 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 20 KP'
        Board_Design.Text_A_A1 = A1 + ' 19 A'
        Board_Design.Text_A_A2 = A2 + ' 50 A'
        Board_Design.Text_A_N = N + ' 50-SH'
        Board_Design.Text_A_A3 = A3 + ' 50 A'
        Board_Design.Text_A_m = m + ' 6 mm^2'
        
    @Rule (Horse_Power_A_415('10'))
    def Horse_Power_A_415_10(Self):
        print('10')
        print(A + ' 15 A')
        print(cA + ' 18 KPPMCG')
        print(AA + ' 18 KP')
        print(A1 + ' 15 A')
        print(A2 + ' 50 A')
        print(N + ' 50-SH')
        print(A3 + ' 30 A')
        print(m + ' 4 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 15 A'
        Board_Design.MS_A = ' 18 KPPMCG'
        Board_Design.OLR_A = ' 18 KP'
        Board_Design.FUSE_A =' 50 A'
        Board_Design.MCCB_A =' 50-SH'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '10'
        Board_Design.Text_A_A = A + ' 21 A'
        Board_Design.Text_A_cA = cA + ' 20-21 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 20 KP'
        Board_Design.Text_A_A1 = A1 + ' 19 A'
        Board_Design.Text_A_A2 = A2 + ' 50 A'
        Board_Design.Text_A_N = N + ' 50-SH'
        Board_Design.Text_A_A3 = A3 + ' 50 A'
        Board_Design.Text_A_m = m + ' 6 mm^2'
        
    @Rule (Horse_Power_A_415('7.5'))
    def Horse_Power_A_415_10(Self):
        print('7.5')
        print(A + ' 11 A')
        print(cA + ' 11 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 11 A')
        print(A2 + ' 35 A')
        print(N + ' 30-SS')
        print(A3 + ' 30 A')
        print(m + ' 2.5 mm^2') 
        #VAR______________________________
        Board_Design.MOTOR_A = ' 11 A'
        Board_Design.MS_A = ' 11 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 35 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '7.5'
        Board_Design.Text_A_A = A + ' 11 A'
        Board_Design.Text_A_cA = cA + ' 11 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 11 A'
        Board_Design.Text_A_A2 = A2 + ' 35 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 30 A'
        Board_Design.Text_A_m = m + ' 2.5 mm^2'
        
    @Rule (Horse_Power_A_415('5.5'))
    def Horse_Power_A_415_5_5(Self):
        print('5.5')
        print(A + ' 8.0 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 9 A')
        print(A2 + ' 25 A')
        print(N + ' 33-SS')
        print(A3 + ' 20 A')
        print(m + ' 1.5 mm^2') 
        #VAR______________________________
        Board_Design.MOTOR_A = ' 8.0 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 25 A'
        Board_Design.MCCB_A =' 33-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '5.5'
        Board_Design.Text_A_A = A + ' 8.0 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 9 A'
        Board_Design.Text_A_A2 = A2 + ' 25 A'
        Board_Design.Text_A_N = N + ' 33-SS'
        Board_Design.Text_A_A3 = A3 + ' 20 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_415('5'))
    def Horse_Power_A_415_5(Self):
        print('5')
        print(A + ' 7.5 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 6.6 A')
        print(A2 + ' 20 A')
        print(N + ' 30-SS')
        print(A3 + ' 20 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 7.5 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 20 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '5'
        Board_Design.Text_A_A = A + ' 7.5 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 6.6 A'
        Board_Design.Text_A_A2 = A2 + ' 20 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 20 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_415('4'))
    def Horse_Power_A_415_4(Self):
        print('4')
        print(A + ' 6.3 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 6.6 A')
        print(A2 + ' 20 A')
        print(N + ' 30-SS')
        print(A3 + ' 15 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 6.3 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 20 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '4'
        Board_Design.Text_A_A = A + ' 6.3 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 6.6 A'
        Board_Design.Text_A_A2 = A2 + ' 20 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 15 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_415('3'))
    def Horse_Power_A_415_3(Self):
        print('3')
        print(A + ' 5.0 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 5 A')
        print(A2 + ' 16 A')
        print(N + ' 30-SS')
        print(A3 + ' 10 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 5.0 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 16 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '3'
        Board_Design.Text_A_A = A + ' 5.0 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 5 A'
        Board_Design.Text_A_A2 = A2 + ' 16 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 10 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
        
    @Rule (Horse_Power_A_415('2'))
    def Horse_Power_A_415_2(Self):
        print('2')
        print(A + ' 3.5 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 6.6 A')
        print(A2 + ' 16 A')
        print(N + ' 30-SS')
        print(A3 + ' 10 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 3.5 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 16 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '2'
        Board_Design.Text_A_A = A + ' 3.5 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 6.6 A'
        Board_Design.Text_A_A2 = A2 + ' 16 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 10 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_415('1.5'))
    def Horse_Power_A_415_1_5(Self):
        print('1.5')
        print(A + ' 2.6 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 2.5 A')
        print(A2 + ' 10 A')
        print(N + ' 30-SS')
        print(A3 + ' 5 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 2.6 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 10 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '1.5'
        Board_Design.Text_A_A = A + ' 2.6 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 2.5 A'
        Board_Design.Text_A_A2 = A2 + ' 10 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 5 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_415('1'))
    def Horse_Power_A_415_1(Self):
        print('1')
        print(A + ' 1.9 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 1.7 A')
        print(A2 + ' 6 A')
        print(N + ' 30-SS')
        print(A3 + ' 5 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 1.9 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 6 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '1'
        Board_Design.Text_A_A = A + ' 1.9 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 1.7 A'
        Board_Design.Text_A_A2 = A2 + ' 6 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 5 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_415('0.75'))
    def Horse_Power_A_415_0_75(Self):
        print('0.75')
        print(A + ' 1.5 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 1.7 A')
        print(A2 + ' 6 A')
        print(N + ' 30-SS')
        print(A3 + ' 3 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 1.5 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 6 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '0.75'
        Board_Design.Text_A_A = A + ' 1.5 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 1.7 A'
        Board_Design.Text_A_A2 = A2 + ' 6 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 3 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_415('0.5'))
    def Horse_Power_A_415_0_5(Self):
        print('0.5')
        print(A + ' 1.1 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 1.3 A')
        print(A2 + ' 4 A')
        print(N + ' 30-SS')
        print(A3 + ' 3 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 1.1 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 4 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '0.5'
        Board_Design.Text_A_A = A + ' 1.1 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 1.3 A'
        Board_Design.Text_A_A2 = A2 + ' 4 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 3 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_415('1/3'))
    def Horse_Power_A_415_0_33(Self):
        print('1/3')
        print(A + ' 0.8 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 0.9 A')
        print(A2 + ' 4 A')
        print(N + ' 30-SS')
        print(A3 + ' 3 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 0.8 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 4 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '1/3'
        Board_Design.Text_A_A = A + ' 0.8 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 0.9 A'
        Board_Design.Text_A_A2 = A2 + ' 4 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 3 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_415('0.25'))
    def Horse_Power_A_415_0_25(Self):
        print('0.25')
        print(A + ' 0.65 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 0.7 A')
        print(A2 + ' 2 A')
        print(N + ' 30-SS')
        print(A3 + ' 3 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 0.65 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 2 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '0.25'
        Board_Design.Text_A_A = A + ' 0.65 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 0.7 A'
        Board_Design.Text_A_A2 = A2 + ' 2 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 3 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_415('1/6'))
    def Horse_Power_A_415_5_0_1667(Self):
        print('1/6')
        print(A + ' 0.65 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 0.5 A')
        print(A2 + ' 2 A')
        print(N + ' 30-SS')
        print(A3 + ' 3 A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 0.65 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 2 A'
        Board_Design.MCCB_A =' 30-SS'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '1/6'
        Board_Design.Text_A_A = A + ' 0.65 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 0.5 A'
        Board_Design.Text_A_A2 = A2 + ' 2 A'
        Board_Design.Text_A_N = N + ' 30-SS'
        Board_Design.Text_A_A3 = A3 + ' 3 A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_415('1/8'))
    def Horse_Power_A_415_0_125(Self):
        print('1/8')
        print(A + ' 0.4 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 0.35 A')
        print(A2 + ' 2 A')
        print(N + ' _ ')
        print(A3 + ' _ A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 0.4 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 2 A'
        Board_Design.MCCB_A =' __'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '1/8'
        Board_Design.Text_A_A = A + ' 0.4 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 0.35 A'
        Board_Design.Text_A_A2 = A2 + ' 2 A'
        Board_Design.Text_A_N = N + ' __'
        Board_Design.Text_A_A3 = A3 + ' __ A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
    @Rule (Horse_Power_A_415('1/12'))
    def Horse_Power_A_415_0_083(Self):
        print('1/12')
        print(A + ' 0.3 A')
        print(cA + ' 10 KPPMCG')
        print(AA + ' 12AB KP')
        print(A1 + ' 0.24 A')
        print(A2 + ' 2 A')
        print(N + ' _ ')
        print(A3 + ' _ A')
        print(m + ' 1.5 mm^2')
        #VAR______________________________
        Board_Design.MOTOR_A = ' 0.3 A'
        Board_Design.MS_A = ' 10 KPPMCG'
        Board_Design.OLR_A = ' 12AB KP'
        Board_Design.FUSE_A =' 2 A'
        Board_Design.MCCB_A =' __'
        #TEXT_____________________________
        Board_Design.Text_A_HP = 'HP : ' + '1/12'
        Board_Design.Text_A_A = A + ' 0.3 A'
        Board_Design.Text_A_cA = cA + ' 10 KPPMCG'
        Board_Design.Text_A_AA = AA + ' 12AB KP'
        Board_Design.Text_A_A1 = A1 + ' 0.24 A'
        Board_Design.Text_A_A2 = A2 + ' 2 A'
        Board_Design.Text_A_N = N + ' __'
        Board_Design.Text_A_A3 = A3 + ' __ A'
        Board_Design.Text_A_m = m + ' 1.5 mm^2'
        
#_________________________________________________________________________________________________________________________________
#                                                        CONCLUSION RULES -.-
#_________________________________________________________________________________________________________________________________
    #                                                HEATER = 0.24 -.-
    
    @Rule(motor_full_load_current('0.3'))
    def motor_0_3 (Self):
        Self.declare(heater_designation('0.24'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('2'))
    
          

          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('0.3'),heater_designation('0.24'))))
    def vol_380_motor_0_3_heater_0_24 (Self):
        Self.declare(Horse_Power_A_380('1/12'))

    
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('0.3'),heater_designation('0.24'))))
    def vol_415_motor_0_3_heater_0_24 (Self):
        Self.declare(Horse_Power_A_415('1/12'))
        
#_________________________________________________________________________________________________________________________________
    #                                                HEATER = 0.35 -.-
    
    @Rule(motor_full_load_current('0.4'))
    def motor_0_4 (Self):
        Self.declare(heater_designation('0.35'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('2'))
    
          

          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('0.4'),heater_designation('0.35'))))
    def vol_380_motor_0_4_heater_0_35 (Self):
        Self.declare(Horse_Power_A_380('1/8'))

    
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('0.4'),heater_designation('0.35'))))
    def vol_415_motor_0_4_heater_0_35 (Self):
        Self.declare(Horse_Power_A_415('1/8'))
        
#_________________________________________________________________________________________________________________________________
    #                                                HEATER = 0.5 -.-
    
    @Rule(OR(motor_full_load_current('0.5'),motor_full_load_current('0.4')))
    def motor_0_5_4 (Self):
        Self.declare(heater_designation('0.5'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('2'))
        
        
    
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('0.5'),heater_designation('0.5'))))
    def vol_200_220_motor_0_5_heater_0_5 (Self):
        Self.declare(Horse_Power_A_200_220('1/12'))  
        
        

          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('0.5'),heater_designation('0.5'))))
    def vol_380_motor_0_5_heater_0_5 (Self):
        Self.declare(Horse_Power_A_380('1/6'))

    
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('0.4'),heater_designation('0.5'))))
    def vol_415_motor_0_4_heater_0_5 (Self):
        Self.declare(Horse_Power_A_415('1/6'))
        
#_________________________________________________________________________________________________________________________________
    #                                                HEATER = 0.7 -.-
    
    @Rule(OR(motor_full_load_current('0.7'),motor_full_load_current('0.65')))
    def motor_0_7_65 (Self):
        Self.declare(heater_designation('0.7'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('2'))
        
        
    
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('0.7'),heater_designation('0.7'))))
    def vol_200_220_motor_0_7_heater_0_7 (Self):
        Self.declare(Horse_Power_A_200_220('1/8'))  
        
        

          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('0.7'),heater_designation('0.7'))))
    def vol_380_motor_0_7_heater_0_7 (Self):
        Self.declare(Horse_Power_A_380('1/4'))

    
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('0.65'),heater_designation('0.7'))))
    def vol_415_motor_0_65_heater_0_7 (Self):
        Self.declare(Horse_Power_A_415('1/4'))
        
#_________________________________________________________________________________________________________________________________
    #                                                HEATER = 0.9 -.-
    
    @Rule(OR(motor_full_load_current('0.8'),motor_full_load_current('0.85')))
    def motor_0_8_85 (Self):
        Self.declare(heater_designation('0.8'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('4'))
        
        
    
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('0.8'),heater_designation('0.9'))))
    def vol_200_220_motor_0_8_heater_0_9 (Self):
        Self.declare(Horse_Power_A_200_220('1/6'))  
        
        

          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('0.85'),heater_designation('0.9'))))
    def vol_380_motor_0_85_heater_0_9 (Self):
        Self.declare(Horse_Power_A_380('1/3'))

    
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('0.8'),heater_designation('0.9'))))
    def vol_415_motor_0_8_heater_0_9 (Self):
        Self.declare(Horse_Power_A_415('1/3'))
        
#_________________________________________________________________________________________________________________________________
    #                                                HEATER = 1.3 -.-
    
    @Rule(OR(motor_full_load_current('1.2'),motor_full_load_current('1.1')))
    def motor_1_2_1 (Self):
        Self.declare(heater_designation('1.3'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('4'))
        
        
    
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('1.2'),heater_designation('1.3'))))
    def vol_200_220_motor_1_2_heater_1_3 (Self):
        Self.declare(Horse_Power_A_200_220('1/4'))  
        
        

          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('1.2'),heater_designation('1.3'))))
    def vol_380_motor_1_2_heater_1_3 (Self):
        Self.declare(Horse_Power_A_380('0.5'))

    
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('1.1'),heater_designation('1.3'))))
    def vol_415_motor_1_1_heater_1_3 (Self):
        Self.declare(Horse_Power_A_415('0.5'))
        
#_________________________________________________________________________________________________________________________________
    #                                                HEATER = 1.7 -.-
    
    @Rule(OR(motor_full_load_current('1.5'),motor_full_load_current('1.6'),motor_full_load_current('1.9')))
    def motor_1_5_6_9 (Self):
        Self.declare(heater_designation('1.7'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('6'))
        
        
    
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('1.5'),heater_designation('1.7'))))
    def vol_200_220_motor_1_5_heater_1_7 (Self):
        Self.declare(Horse_Power_A_200_220('1/3'))  
        
        

          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('1.6'),heater_designation('1.7'))))
    def vol_380_motor_1_6_heater_1_7 (Self):
        Self.declare(Horse_Power_A_380('0.75'))

    
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('1.5'),heater_designation('1.7'))))
    def vol_415_motor_1_5_heater_1_7 (Self):
        Self.declare(Horse_Power_A_415('0.75'))
        
    @Rule(AND(Volt('415 V'),motor_full_load_current('1.9')))
    def vol_415_motor_1_9 (Self):
        Self.declare(Horse_Power_A_415('1'))
        
#_________________________________________________________________________________________________________________________________
    #                                                HEATER = 2.1 -.-
    
    @Rule(OR(motor_full_load_current('2.1'),motor_full_load_current('2.0')))
    def motor_2_1_0 (Self):
        Self.declare(heater_designation('2.1'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('6'))
        
        
    
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('2.1'),heater_designation('2.1'))))
    def vol_200_220_motor_2_1_heater_2_1 (Self):
        Self.declare(Horse_Power_A_200_220('0.5'))  
        
        

          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('2.0'),heater_designation('2.1'))))
    def vol_380_motor_2_0_heater_2_1 (Self):
        Self.declare(Horse_Power_A_380('1'))
        
#_________________________________________________________________________________________________________________________________
    #                                                HEATER = 2.5 -.-
    
    @Rule(OR(motor_full_load_current('2.7'),motor_full_load_current('2.6')))
    def motor_2_7_6 (Self):
        Self.declare(heater_designation('2.5'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('10'))
        
        
    
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('2.7'),heater_designation('2.5'))))
    def vol_200_220_motor_2_7_heater_2_5 (Self):
        Self.declare(Horse_Power_A_200_220('0.75'))  
        
        

          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('2.7'),heater_designation('2.5'))))
    def vol_380_motor_2_7_heater_2_5 (Self):
        Self.declare(Horse_Power_A_380('1.5'))

    
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('2.6'),heater_designation('2.5'))))
    def vol_415_motor_2_6_heater_2_5 (Self):
        Self.declare(Horse_Power_A_415('1.5'))
        
#_________________________________________________________________________________________________________________________________
    #                                                HEATER = 3.6 -.-
    
    @Rule(OR(motor_full_load_current('3.5'),motor_full_load_current('3.6')))
    def motor_3_5_6 (Self):
        Self.declare(heater_designation('3.6'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('16'))
        
        
    
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('3.5'),heater_designation('3.6'))))
    def vol_200_220_motor_3_5_heater_3_6 (Self):
        Self.declare(Horse_Power_A_200_220('1'))  
        
        

          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('3.6'),heater_designation('3.6'))))
    def vol_380_motor_3_6_heater_3_6 (Self):
        Self.declare(Horse_Power_A_380('2'))

    
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('3.5'),heater_designation('3.6'))))
    def vol_415_motor_3_5_heater_3_6 (Self):
        Self.declare(Horse_Power_A_415('2'))
        
#_________________________________________________________________________________________________________________________________
    #                                                HEATER = 5 -.-
    
    @Rule(OR(motor_full_load_current('4.5'),motor_full_load_current('5.1'),motor_full_load_current('5.0')))
    def motor_4_5_5_1_0 (Self):
        Self.declare(heater_designation('5'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('16'))
        
        
    
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('4.5'),heater_designation('5'))))
    def vol_200_220_motor_4_5_heater_5 (Self):
        Self.declare(Horse_Power_A_200_220('1.5'))  
        
        

          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('5.1'),heater_designation('5'))))
    def vol_380_motor_5_1_heater_5 (Self):
        Self.declare(Horse_Power_A_380('3'))

    
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('5.0'),heater_designation('5'))))
    def vol_415_motor_5_0_heater_5 (Self):
        Self.declare(Horse_Power_A_415('3'))

#_______________________________________________________________________________________________________________________________________
    #                                                HEATER = 6.6 -.-
          
    @Rule(AND(OR(motor_full_load_current('6.1'),motor_full_load_current('6.3'),motor_full_load_current('6.8'),motor_full_load_current('7.5')),Boot_type('A')))
    def motor_6_1_3_8_7_5_A (Self):
        Self.declare(heater_designation('6.6'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('20'))
    
    @Rule(AND(OR(motor_full_load_current('6.1'),motor_full_load_current('6.3'),motor_full_load_current('6.8'),motor_full_load_current('7.5')),Boot_type('B')))
    def motor_6_1_3_8_7_5_B (Self):
        Self.declare(heater_designation('6.6'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('16'))
          
       
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('6.1'),heater_designation('6.6'))))
    def vol_200_220_motor_6_1_heater_6_6 (Self):
        Self.declare(Horse_Power_A_200_220('2'))
          
    
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('6.8'),heater_designation('6.6')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('20'))))
    def vol_380_motor_6_8_heater_6_6_A_MS_FUSE_20 (Self):
        Self.declare(Horse_Power_A_380('4'))
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('6.8'),heater_designation('6.6')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('16'))))
    def vol_380_motor_6_8_heater_6_6_B_MCM_MCD_MCS_FUSE_16 (Self):
        Self.declare(Horse_Power_B_380('4'))
    
    
          
    @Rule(AND(Volt('415 V'),motor_full_load_current('7.5')))
    def vol_415_motor_7_5 (Self):
        Self.declare(Horse_Power_A_415('5'))
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('6.3'),heater_designation('6.6')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('20'))))
    def vol_415_motor_6_3_heater_6_6_A_MS_FUSE_20 (Self):
        Self.declare(Horse_Power_A_415('4'))
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('6.3'),heater_designation('6.6')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('16'))))
    def vol_415_motor_6_3_heater_6_6_B_MCM_MCD_MCS_FUSE_16 (Self):
        Self.declare(Horse_Power_B_415('4'))
          
#_______________________________________________________________________________________________________________________________________
    #                                                HEATER = 9 -.-

    @Rule(AND(OR(motor_full_load_current('8.7'),motor_full_load_current('8.5'),motor_full_load_current('8.0')),Boot_type('A')))
    def motor_8_7_5_0_A (Self):
        Self.declare(heater_designation('9'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('25'))
        print('HI')
    
    @Rule(AND(OR(motor_full_load_current('8.7'),motor_full_load_current('8.5'),motor_full_load_current('8.0')),Boot_type('B')))
    def motor_8_7_5_0_B (Self):
        Self.declare(heater_designation('9'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('16'))
          
          
          
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('8.7'),heater_designation('9')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('25'))))
    def vol_200_220_motor_8_7_heater_9_A_MS_FUSE_25 (Self):
        Self.declare(Horse_Power_A_200_220('3'))
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('8.7'),heater_designation('9')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('16'))))
    def vol_200_220_motor_8_7_heater_9_B_MCM_MCD_MCS_FUSE_16 (Self):
        Self.declare(Horse_Power_B_200_220('3'))
          
          
          
          
    @Rule(AND(Volt('380 V'),motor_full_load_current('8.5')))
    def vol_380_motor_8_5 (Self):
        Self.declare(Horse_Power_A_380('5'))
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('8.7'),heater_designation('9')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('25'))))
    def vol_380_motor_8_7_heater_9_A_MS_FUSE_25 (Self):
        Self.declare(Horse_Power_A_380('5.5'))
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('8.7'),heater_designation('9')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('16'))))
    def vol_380_motor_8_7_heater_9_B_MCM_MCD_MCS_FUSE_16 (Self):
        Self.declare(Horse_Power_B_380('5.5'))
    
          
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('8.0'),heater_designation('9')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('25'))))
    def vol_415_motor_8_0_heater_9_A_MS_FUSE_25 (Self):
        Self.declare(Horse_Power_A_415('5.5'))
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('8.0'),heater_designation('9')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('16'))))
    def vol_415_motor_8_0_heater_9_B_MCM_MCD_MCS_FUSE_16 (Self):
        Self.declare(Horse_Power_B_415('5.5'))
          
#_______________________________________________________________________________________________________________________________________
    #                                                HEATER = 11 -.-

    @Rule(AND(OR(motor_full_load_current('11.5'),motor_full_load_current('11.8'),motor_full_load_current('11.0')),Boot_type('A')))
    def motor_11_5_8_0_A (Self):
        Self.declare(heater_designation('11'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('35'))
    
    @Rule(AND(OR(motor_full_load_current('11.5'),motor_full_load_current('11.8'),motor_full_load_current('11.0')),Boot_type('B')))
    def motor_11_5_8_0_B (Self):
        Self.declare(heater_designation('11'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('20'))
          
          
          
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('11.5'),heater_designation('11')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('35'))))
    def vol_200_220_motor_11_5_heater_11_A_MS_FUSE_35 (Self):
        Self.declare(Horse_Power_A_200_220('4'))
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('11.5'),heater_designation('11')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('20'))))
    def vol_200_220_motor_11_5_heater_11_B_MCM_MCD_MCS_FUSE_20 (Self):
        Self.declare(Horse_Power_B_200_220('4'))
          
          
          
          
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('11.8'),heater_designation('11')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('35'))))
    def vol_380_motor_11_8_heater_11_A_MS_FUSE_35 (Self):
        Self.declare(Horse_Power_A_380('7.5'))
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('11.8'),heater_designation('11')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('20'))))
    def vol_380_motor_11_8_heater_11_B_MCM_MCD_MCS_FUSE_20 (Self):
        Self.declare(Horse_Power_B_380('7.5'))
    
          
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('11.0'),heater_designation('11')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('35'))))
    def vol_415_motor_11_0_heater_11_A_MS_FUSE_35 (Self):
        Self.declare(Horse_Power_A_415('7.5'))
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('11.0'),heater_designation('11')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('20'))))
    def vol_415_motor_11_0_heater_11_B_MCM_MCD_MCS_FUSE_20 (Self):
        Self.declare(Horse_Power_B_415('7.5'))
          
#_______________________________________________________________________________________________________________________________________
    #                                                HEATER = 15 -.-

    @Rule(AND(OR(motor_full_load_current('14.2'),motor_full_load_current('15.2'),motor_full_load_current('16.0'),motor_full_load_current('15.0')),Boot_type('A')))
    def motor_14_2_15_2_0_16_A (Self):
        Self.declare(heater_designation('15'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('50'))
    
    @Rule(AND(OR(motor_full_load_current('14.2'),motor_full_load_current('15.2'),motor_full_load_current('16.0'),motor_full_load_current('15.0')),Boot_type('B')))
    def motor_14_2_15_2_0_16_B (Self):
        Self.declare(heater_designation('15'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('32'))
          
          
          
          
    @Rule(AND(Volt('200-220 V'),motor_full_load_current('14.2')))
    def vol_200_220_motor_14_2 (Self):
        Self.declare(Horse_Power_A_200_220('5'))      
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('15.2'),heater_designation('15')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('50'))))
    def vol_200_220_motor_15_2_heater_15_A_MS_FUSE_50 (Self):
        Self.declare(Horse_Power_A_200_220('5.5'))
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('15.2'),heater_designation('15')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('32'))))
    def vol_200_220_motor_15_2_heater_15_B_MCM_MCD_MCS_FUSE_32 (Self):
        Self.declare(Horse_Power_B_200_220('5.5'))
          
          
          
          
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('16.0'),heater_designation('15')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('50'))))
    def vol_380_motor_16_0_heater_15_A_MS_FUSE_50 (Self):
        Self.declare(Horse_Power_A_380('10'))
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('16.0'),heater_designation('15')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('32'))))
    def vol_380_motor_16_0_heater_15_B_MCM_MCD_MCS_FUSE_32 (Self):
        Self.declare(Horse_Power_B_380('10'))
    
          
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('15.0'),heater_designation('15')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('50'))))
    def vol_415_motor_15_0_heater_15_A_MS_FUSE_50 (Self):
        Self.declare(Horse_Power_A_415('10'))
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('15.0'),heater_designation('15')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('32'))))
    def vol_415_motor_15_0_heater_15_B_MCM_MCD_MCS_FUSE_32 (Self):
        Self.declare(Horse_Power_B_415('10'))
          
#_______________________________________________________________________________________________________________________________________
    #                                                HEATER = 19 & 22 -.-

    @Rule(AND(OR(motor_full_load_current('20.0'),motor_full_load_current('22.0'),motor_full_load_current('21.0')),Boot_type('A')))
    def motor_20_22_21_A (Self):
        Self.declare(heater_designation('19'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('50'))
    
    @Rule(AND(OR(motor_full_load_current('20.0'),motor_full_load_current('22.0'),motor_full_load_current('21.0')),Boot_type('B')))
    def motor_20_22_21_B (Self):
        Self.declare(heater_designation('19'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('32'))
          
    @Rule(AND(OR(motor_full_load_current('21.0'),motor_full_load_current('22.0'))))
    def motor_21_22 (Self):
        Self.declare(heater_designation('22'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('32'))
          
          
          
          
 
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('20.0'),heater_designation('19')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('50'))))
    def vol_200_220_motor_20_heater_19_A_MS_FUSE_50 (Self):
        Self.declare(Horse_Power_A_200_220('7.5'))
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('20.0'),heater_designation('19')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('32'))))
    def vol_200_220_motor_20_0_heater_19_B_MCM_MCD_MCS_FUSE_32 (Self):
        Self.declare(Horse_Power_B_200_220('7.5'))
          
          
          
          
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('22.0'),heater_designation('19'),heater_designation('22'))))
    def vol_380_motor_22_0_heater_19_22 (Self):
        Self.declare(Horse_Power_A_380('15'))

          
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('21.0'),heater_designation('19'),heater_designation('22'))))
    def vol_415_motor_21_0_heater_19_22 (Self):
        Self.declare(Horse_Power_A_415('15'))
          
#_______________________________________________________________________________________________________________________________________
    #                                                HEATER = 29 -.-

    @Rule(AND(OR(motor_full_load_current('26.5'),motor_full_load_current('30.0'),motor_full_load_current('28.0')),Boot_type('A')))
    def motor_26_5_30_28_A (Self):
        Self.declare(heater_designation('29'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('80'))
    
    @Rule(AND(OR(motor_full_load_current('26.5'),motor_full_load_current('30.0'),motor_full_load_current('28.0')),Boot_type('B')))
    def motor_26_5_30_28_B (Self):
        Self.declare(heater_designation('29'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('40'))
          
          
          

    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('26.5'),heater_designation('29')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('80'))))
    def vol_200_220_motor_26_5_heater_29_A_MS_FUSE_80 (Self):
        Self.declare(Horse_Power_A_200_220('10'))
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('26.5'),heater_designation('29')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('40'))))
    def vol_200_220_motor_26_5_heater_29_B_MCM_MCD_MCS_FUSE_40 (Self):
        Self.declare(Horse_Power_B_200_220('10'))
          
          
          
          
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('30.0'),heater_designation('29')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('80'))))
    def vol_380_motor_30_0_heater_29_A_MS_FUSE_80 (Self):
        Self.declare(Horse_Power_A_380('20'))
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('30.0'),heater_designation('29')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('40'))))
    def vol_380_motor_30_0_heater_29_B_MCM_MCD_MCS_FUSE_40 (Self):
        Self.declare(Horse_Power_B_380('20'))
    
          
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('28.0'),heater_designation('29')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('80'))))
    def vol_415_motor_28_0_heater_29_A_MS_FUSE_80 (Self):
        Self.declare(Horse_Power_A_415('20'))
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('28.0'),heater_designation('29')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('40'))))
    def vol_415_motor_28_0_heater_29_B_MCM_MCD_MCS_FUSE_40 (Self):
        Self.declare(Horse_Power_B_415('20'))
          
#_______________________________________________________________________________________________________________________________________
    #                                                HEATER = 35 -.-

    @Rule(AND(OR(motor_full_load_current('39.0'),motor_full_load_current('37.0'),motor_full_load_current('35.0')),Boot_type('A')))
    def motor_39_37_35_A (Self):
        Self.declare(heater_designation('35'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('80'))
    
    @Rule(AND(motor_full_load_current('39.5'),Boot_type('B')))
    def motor_39_B (Self):
        Self.declare(heater_designation('35'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('63'))
          
    @Rule(AND(OR(motor_full_load_current('37.0'),motor_full_load_current('35.0')),Boot_type('B')))
    def motor_37_35_B (Self):
        Self.declare(heater_designation('35'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('40'))
          
          
          

    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('39.0'),heater_designation('35')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('80'))))
    def vol_200_220_motor_39_heater_35_A_MS_FUSE_80 (Self):
        Self.declare(Horse_Power_A_200_220('15'))
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('39.0'),heater_designation('35')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('63'))))
    def vol_200_220_motor_39_heater_35_B_MCM_MCD_MCS_FUSE_63 (Self):
        Self.declare(Horse_Power_B_200_220('15'))
          
          
          
          
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('37.0'),heater_designation('35')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('80'))))
    def vol_380_motor_37_0_heater_35_A_MS_FUSE_80 (Self):
        Self.declare(Horse_Power_A_380('25'))
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('37.0'),heater_designation('35')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('40'))))
    def vol_380_motor_37_0_heater_35_B_MCM_MCD_MCS_FUSE_40 (Self):
        Self.declare(Horse_Power_B_380('25'))
    
          
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('35.0'),heater_designation('35')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('80'))))
    def vol_415_motor_35_0_heater_35_A_MS_FUSE_80 (Self):
        Self.declare(Horse_Power_A_415('25'))
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('35.0'),heater_designation('35')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('40'))))
    def vol_415_motor_35_0_heater_35_B_MCM_MCD_MCS_FUSE_40 (Self):
        Self.declare(Horse_Power_B_415('25'))
          
#_______________________________________________________________________________________________________________________________________
    #                                                HEATER = 42 -.-

    @Rule(AND(OR(motor_full_load_current('43.0'),motor_full_load_current('40.0')),Boot_type('A')))
    def motor_43_40_A (Self):
        Self.declare(heater_designation('42'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('125'))

    @Rule(AND(motor_full_load_current('50.0'),Boot_type('B')))
    def motor_50_B (Self):
        Self.declare(heater_designation('42'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('80'))
          
    @Rule(AND(OR(motor_full_load_current('43.0'),motor_full_load_current('40.0')),Boot_type('B')))
    def motor_43_40_B (Self):
        Self.declare(heater_designation('42'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('63'))
          
          
          
          
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('50.0'),heater_designation('42')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('100'))))
    def vol_200_220_motor_50_heater_42_B_MCM_MCD_MCS_FUSE_100 (Self):
        Self.declare(Horse_Power_B_200_220('20'))
          
          
          
          
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('43.0'),heater_designation('42')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('125'))))
    def vol_380_motor_43_0_heater_42_A_MS_FUSE_125 (Self):
        Self.declare(Horse_Power_A_380('30'))
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('43.0'),heater_designation('42')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('63'))))
    def vol_380_motor_43_0_heater_42_B_MCM_MCD_MCS_FUSE_63 (Self):
        Self.declare(Horse_Power_B_380('30'))
    
          
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('40.0'),heater_designation('42')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('125'))))
    def vol_415_motor_40_0_heater_42_A_MS_FUSE_142 (Self):
        Self.declare(Horse_Power_A_415('30'))
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('40.0'),heater_designation('42')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('63'))))
    def vol_415_motor_40_0_heater_42_B_MCM_MCD_MCS_FUSE_63 (Self):
        Self.declare(Horse_Power_B_415('30'))
          
#_______________________________________________________________________________________________________________________________________
    #                                                HEATER = 54 -.-

    @Rule(AND(OR(motor_full_load_current('50.0'),motor_full_load_current('52.0'),motor_full_load_current('57.0'),motor_full_load_current('54.0')),Boot_type('A')))
    def motor_50_52_57_54_A (Self):
        Self.declare(heater_designation('54'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('160'))

    @Rule(AND(motor_full_load_current('62.0'),Boot_type('B')))
    def motor_62_B (Self):
        Self.declare(heater_designation('54'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('100'))
          
    @Rule(AND(OR(motor_full_load_current('57.0'),motor_full_load_current('54.0')),Boot_type('B')))
    def motor_57_54_B (Self):
        Self.declare(heater_designation('54'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('63'))
          
          
          
          
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('50.0'),heater_designation('54')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('160'))))
    def vol_200_220_motor_50_heater_54_A_MS_FUSE_160 (Self):
        Self.declare(Horse_Power_A_200_220('20'))
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('62.0'),heater_designation('54')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('160'))))
    def vol_200_220_motor_62_heater_54_B_MCM_MCD_MCS_FUSE_160 (Self):
        Self.declare(Horse_Power_B_200_220('25'))
        
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('62.0'),heater_designation('54')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('100'))))
    def vol_200_220_motor_62_heater_54_B_MCM_MCD_MCS_FUSE_100 (Self):
        Self.declare(Horse_Power_B_200_220('25'))
          
          
          
          
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('57.0'),heater_designation('54')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('160'))))
    def vol_380_motor_57_0_heater_54_A_MS_FUSE_160 (Self):
        Self.declare(Horse_Power_A_380('40'))
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('57.0'),heater_designation('54')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('63'))))
    def vol_380_motor_57_0_heater_54_B_MCM_MCD_MCS_FUSE_63 (Self):
        Self.declare(Horse_Power_B_380('40'))
    
          
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('54.0'),heater_designation('54')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('160'))))
    def vol_415_motor_54_0_heater_54_A_MS_FUSE_160 (Self):
        Self.declare(Horse_Power_A_415('40'))
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('54.0'),heater_designation('54')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('63'))))
    def vol_415_motor_54_0_heater_54_B_MCM_MCD_MCS_FUSE_63 (Self):
        Self.declare(Horse_Power_B_415('40'))
          
#_______________________________________________________________________________________________________________________________________
    #                                                HEATER = 67 -.-


    @Rule(AND(OR(motor_full_load_current('72.0'),motor_full_load_current('67.0')),Boot_type('A')))
    def motor_72_67_B (Self):
        Self.declare(heater_designation('67'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('160'))

          
          
          
          
    @Rule(AND(Volt('380 V'),motor_full_load_current('72.0'),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('160'))))
    def vol_380_motor_72_0_A_MS_FUSE_160 (Self):
        Self.declare(Horse_Power_A_380('50'))
          
    @Rule(AND(Volt('380 V'),heater_designation('67')))
    def vol_380_heater_67 (Self):
        Self.declare(Horse_Power_A_380('50'))

    
          
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('67.0'),heater_designation('67')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('160'))))
    def vol_415_motor_67_0_A_MS_FUSE_160 (Self):
        Self.declare(Horse_Power_A_415('50'))
    
    @Rule(AND(Volt('415 V'),heater_designation('67')))
    def vol_415_heater_67 (Self):
        Self.declare(Horse_Power_A_415('50'))
          
#_______________________________________________________________________________________________________________________________________
    #                                                HEATER = 82 -.-

    @Rule(AND(OR(motor_full_load_current('75.0'),motor_full_load_current('86.0'),motor_full_load_current('79.0')),Boot_type('A')))
    def motor_75_86_79_A (Self):
        Self.declare(heater_designation('82'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('200'))
          
    @Rule(AND(OR(motor_full_load_current('75.0'),motor_full_load_current('86.0'),motor_full_load_current('79.0'),motor_full_load_current('72.0'),motor_full_load_current('67.0')),Boot_type('B')))
    def motor_75_86_79_B (Self):
        Self.declare(heater_designation('82'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('100'))

              
          
          
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('75.0'),heater_designation('82')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('200'))))
    def vol_200_220_motor_75_heater_82_A_MS_FUSE_200 (Self):
        Self.declare(Horse_Power_A_200_220('30'))
          
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('75.0'),heater_designation('82')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('100'))))
    def vol_200_220_motor_75_heater_82_B_MCM_MCD_MCS_FUSE_100 (Self):
        Self.declare(Horse_Power_B_200_220('30'))
          
          
          
          
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('86.0'),heater_designation('82')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('200'))))
    def vol_380_motor_86_0_heater_82_A_MS_FUSE_200 (Self):
        Self.declare(Horse_Power_A_380('60'))
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('86.0'),heater_designation('82')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('100'))))
    def vol_380_motor_86_0_heater_82_B_MCM_MCD_MCS_FUSE_100 (Self):
        Self.declare(Horse_Power_B_380('60'))
          
    @Rule(AND(Volt('380 V'),motor_full_load_current('72.0'),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('100'))))
    def vol_380_motor_72_0_A_MS_FUSE_100 (Self):
        Self.declare(Horse_Power_B_380('50'))
    
          
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('79.0'),heater_designation('82')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('200'))))
    def vol_415_motor_79_0_heater_82_A_MS_FUSE_200 (Self):
        Self.declare(Horse_Power_A_415('60'))
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('79.0'),heater_designation('82')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('100'))))
    def vol_415_motor_79_0_heater_82_B_MCM_MCD_MCS_FUSE_100 (Self):
        Self.declare(Horse_Power_B_415('60'))
          
    @Rule(AND(Volt('415 V'),motor_full_load_current('67.0'),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('100'))))
    def vol_415_motor_67_0_A_MS_FUSE_100 (Self):
        Self.declare(Horse_Power_B_415('50'))
          
#_______________________________________________________________________________________________________________________________________
    #                                                HEATER = 95 -.-

    @Rule(OR(motor_full_load_current('100.0'),motor_full_load_current('105.0'),motor_full_load_current('98.0')))
    def motor_100_105_98_A (Self):
        Self.declare(heater_designation('95'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('200'))

              
          
          
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('100.0'),heater_designation('95'))))
    def vol_200_220_motor_100_heater_95 (Self):
        Self.declare(Horse_Power_A_200_220('40'))
 
          
          
          
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('105.0'),heater_designation('95'))))
    def vol_380_motor_105_0_heater_95 (Self):
        Self.declare(Horse_Power_A_380('75'))

    
          
         
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('98.0'),heater_designation('95'))))
    def vol_415_motor_98_0_heater_95 (Self):
        Self.declare(Horse_Power_A_415('75'))
          
#_______________________________________________________________________________________________________________________________________
    #                                                HEATER = 105 -.-

    @Rule(AND(motor_full_load_current('124.0'),Boot_type('A')))
    def motor_124_A (Self):
        Self.declare(heater_designation('105'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('315'))
          
    @Rule(AND(OR(motor_full_load_current('100.0'),motor_full_load_current('124.0'),motor_full_load_current('105.0'),motor_full_load_current('98.0')),Boot_type('B')))
    def motor_100_124_105_98_B (Self):
        Self.declare(heater_designation('105'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('160'))
          
    @Rule(AND(OR(motor_full_load_current('105.0'),motor_full_load_current('98.0')),Boot_type('B')))
    def motor_100_124_105_98_B (Self):
        Self.declare(heater_designation('105'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('125'))

              
          
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('124.0'),heater_designation('105')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('315'))))
    def vol_200_220_motor_124_heater_105_A_MS_FUSE_315 (Self):
        Self.declare(Horse_Power_A_200_220('50'))
          
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('124.0'),heater_designation('105')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('160'))))
    def vol_200_220_motor_124_heater_105_B_MCM_MCD_MCS_FUSE_160 (Self):
        Self.declare(Horse_Power_B_200_220('50'))
          
    @Rule(AND(Volt('200-220 V'),motor_full_load_current('100.0'),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('125'))))
    def vol_200_220_motor_100_B_MCM_MCD_MCS_FUSE_125 (Self):
        Self.declare(Horse_Power_B_200_220('40'))
          
          
          
          
    @Rule(AND(Volt('380 V'),motor_full_load_current('105.0'),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('125'))))
    def vol_380_motor_105_B_MCM_MCD_MCS_FUSE_125 (Self):
        Self.declare(Horse_Power_B_380('75'))
          
    @Rule(AND(Volt('380 V'),heater_designation('105')))
    def vol_380_heater_105 (Self):
        Self.declare(Horse_Power_B_380('75'))

    
          
    
          
    @Rule(AND(Volt('415 V'),motor_full_load_current('98.0'),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('125'))))
    def vol_415_motor_98_B_MCM_MCD_MCS_FUSE_125 (Self):
        Self.declare(Horse_Power_B_415('75'))
          
    @Rule(AND(Volt('415 V'),heater_designation('105')))
    def vol_415_heater_105 (Self):
        Self.declare(Horse_Power_B_415('75'))
          
#_______________________________________________________________________________________________________________________________________
    #                                                HEATER = 125 -.-

    @Rule(AND(OR(motor_full_load_current('148.0'),motor_full_load_current('140.0'),motor_full_load_current('130.0')),Boot_type('A')))
    def motor_148_140_130_A (Self):
        Self.declare(heater_designation('125'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('315'))
    
    @Rule(AND(motor_full_load_current('148.0'),Boot_type('B')))
    def motor_148_B (Self):
        Self.declare(heater_designation('125'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('200'))
          
    @Rule(AND(OR(motor_full_load_current('140.0'),motor_full_load_current('130.0')),Boot_type('B')))
    def motor_140_130_B (Self):
        Self.declare(heater_designation('125'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('160'))
          
          
          

    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('148.0'),heater_designation('125')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('315'))))
    def vol_200_220_motor_148_heater_125_A_MS_FUSE_315 (Self):
        Self.declare(Horse_Power_A_200_220('60'))
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('148.0'),heater_designation('125')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('200'))))
    def vol_200_220_motor_148_heater_125_B_MCM_MCD_MCS_FUSE_200 (Self):
        Self.declare(Horse_Power_B_200_220('60'))
          
          
          
          
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('140.0'),heater_designation('125')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('315'))))
    def vol_380_motor_140_heater_125_A_MS_FUSE_315 (Self):
        Self.declare(Horse_Power_A_380('100'))
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('140.0'),heater_designation('125')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('160'))))
    def vol_380_motor_140_heater_125_B_MCM_MCD_MCS_FUSE_160 (Self):
        Self.declare(Horse_Power_B_380('100'))
    
          
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('130.0'),heater_designation('125')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('315'))))
    def vol_415_motor_130_heater_125_A_MS_FUSE_315 (Self):
        Self.declare(Horse_Power_A_415('100'))
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('130.0'),heater_designation('125')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('160'))))
    def vol_415_motor_130_0_heater_125_B_MCM_MCD_MCS_FUSE_160 (Self):
        Self.declare(Horse_Power_B_415('100'))
          
#_______________________________________________________________________________________________________________________________________
    #                                                HEATER = 150 -.-

    @Rule(AND(motor_full_load_current('180.0'),Boot_type('A')))
    def motor_180_A (Self):
        Self.declare(heater_designation('150'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('400'))
 
    @Rule(AND(OR(motor_full_load_current('168.0'),motor_full_load_current('160.0')),Boot_type('A')))
    def motor_168_160_A (Self):
        Self.declare(heater_designation('150'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('315'))
          
    @Rule(AND(motor_full_load_current('180.0'),Boot_type('B')))
    def motor_180_B (Self):
        Self.declare(heater_designation('150'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('220'))
          
    @Rule(AND(motor_full_load_current('168.0'),Boot_type('B')))
    def motor_168_B (Self):
        Self.declare(heater_designation('150'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('200'))
          
    @Rule(AND(motor_full_load_current('160.0'),Boot_type('B')))
    def motor_160_B (Self):
        Self.declare(heater_designation('150'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('160'))
          
          
          

    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('180.0'),heater_designation('150')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('400'))))
    def vol_200_220_motor_180_heater_150_A_MS_FUSE_400 (Self):
        Self.declare(Horse_Power_A_200_220('75'))
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('180.0'),heater_designation('150')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('220'))))
    def vol_200_220_motor_180_heater_150_B_MCM_MCD_MCS_FUSE_220 (Self):
        Self.declare(Horse_Power_B_200_220('75'))
          
          
          
          
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('168.0'),heater_designation('150')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('315'))))
    def vol_380_motor_168_heater_150_A_MS_FUSE_315 (Self):
        Self.declare(Horse_Power_A_380('125'))
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('168.0'),heater_designation('150')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('200'))))
    def vol_380_motor_168_heater_150_B_MCM_MCD_MCS_FUSE_200 (Self):
        Self.declare(Horse_Power_B_380('125'))
    
          
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('160.0'),heater_designation('150')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('315'))))
    def vol_415_motor_160_heater_150_A_MS_FUSE_315 (Self):
        Self.declare(Horse_Power_A_415('125'))
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('160.0'),heater_designation('150')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('160'))))
    def vol_415_motor_160_0_heater_150_B_MCM_MCD_MCS_FUSE_160 (Self):
        Self.declare(Horse_Power_B_415('125'))
        
#_______________________________________________________________________________________________________________________________________
    #                                                HEATER = 180 -.-
 
    @Rule(AND(OR(motor_full_load_current('205.0'),motor_full_load_current('190.0')),Boot_type('A')))
    def motor_205_190_A (Self):
        Self.declare(heater_designation('180'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('500'))
        
    @Rule(AND(OR(motor_full_load_current('202.0'),motor_full_load_current('205.0'),motor_full_load_current('190.0')),Boot_type('B')))
    def motor_202_205_190_B (Self):
        Self.declare(heater_designation('180'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('250'))
          
          
          
          
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('202.0'),heater_designation('180'))))
    def vol_200_220_motor_202_heater_180 (Self):
        Self.declare(Horse_Power_B_200_220('85'))
          
          
          
            
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('205.0'),heater_designation('180')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('500'))))
    def vol_380_motor_205_heater_180_A_MS_FUSE_500 (Self):
        Self.declare(Horse_Power_A_380('150'))
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('205.0'),heater_designation('180')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('250'))))
    def vol_380_motor_205_heater_180_B_MCM_MCD_MCS_FUSE_250 (Self):
        Self.declare(Horse_Power_B_380('150'))
    
          
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('190.0'),heater_designation('180')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('500'))))
    def vol_415_motor_190_heater_180_A_MS_FUSE_500 (Self):
        Self.declare(Horse_Power_A_415('150'))
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('190.0'),heater_designation('180')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('250'))))
    def vol_415_motor_190_0_heater_180_B_MCM_MCD_MCS_FUSE_250 (Self):
        Self.declare(Horse_Power_B_415('150'))
        
#_______________________________________________________________________________________________________________________________________
    #                                                HEATER = 210 -.-
 
        
    @Rule(AND(OR(motor_full_load_current('245.0'),motor_full_load_current('230.0')),Boot_type('A')))
    def motor_245_230_A (Self):
        Self.declare(heater_designation('210'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('500'))
        
    @Rule(AND(motor_full_load_current('245.0'),Boot_type('B')))
    def motor_245_B (Self):
        Self.declare(heater_designation('210'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('315'))
        
    @Rule(AND(motor_full_load_current('230.0'),Boot_type('B')))
    def motor_230_B (Self):
        Self.declare(heater_designation('210'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('250'))
          
          
          
          
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('245.0'),heater_designation('210')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('500'))))
    def vol_200_220_motor_245_heater_210_A_MS_FUSE_500 (Self):
        Self.declare(Horse_Power_A_200_220('100'))
        
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('245.0'),heater_designation('210')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('315'))))
    def vol_200_220_motor_245_heater_210_B_MCM_MCD_MCS_FUSE_315 (Self):
        Self.declare(Horse_Power_B_200_220('100'))
          
          
          
            
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('245.0'),heater_designation('210')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('500'))))
    def vol_380_motor_245_heater_210_A_MS_FUSE_500 (Self):
        Self.declare(Horse_Power_A_380('180'))
          
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('245.0'),heater_designation('210')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('250'))))
    def vol_380_motor_245_heater_210_B_MCM_MCD_MCS_FUSE_250 (Self):
        Self.declare(Horse_Power_B_380('180'))
    
          
    
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('230.0'),heater_designation('210')),OR(Boot_type('A'),Type_designation_of_Magnetic_Startar('Any'),Fuse_VDE0660_9T_Time_delay('500'))))
    def vol_415_motor_230_heater_210_A_MS_FUSE_500 (Self):
        Self.declare(Horse_Power_A_415('180'))
          
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('230.0'),heater_designation('210')),OR(Boot_type('B'),Type_designation_of_Contactor_MCM_and_MCD('Any'),Type_designation_of_Contactor_MCS('Any'),Fuse_VDE0660_9T_Time_delay('250'))))
    def vol_415_motor_230_0_heater_210_B_MCM_MCD_MCS_FUSE_250 (Self):
        Self.declare(Horse_Power_B_415('180'))
        
#_______________________________________________________________________________________________________________________________________
    #                                                HEATER = 250 -.-
 
        
    @Rule(motor_full_load_current('295.0'))
    def motor_295 (Self):
        Self.declare(heater_designation('250'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('400'))
        
    @Rule(motor_full_load_current('290.0'))
    def motor_290 (Self):
        Self.declare(heater_designation('250'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('310'))
        
    @Rule(motor_full_load_current('270.0'))
    def motor_270 (Self):
        Self.declare(heater_designation('250'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('315'))
          
          
          
          
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('295.0'),heater_designation('250'))))
    def vol_200_220_motor_295_heater_250 (Self):
        Self.declare(Horse_Power_B_200_220('125'))
          
          
          
            
            
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('290.0'),heater_designation('250'))))
    def vol_380_motor_290_heater_250 (Self):
        Self.declare(Horse_Power_A_380('220'))

    
          
    
    
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('270.0'),heater_designation('250'))))
    def vol_415_motor_270_heater_250 (Self):
        Self.declare(Horse_Power_A_415('220'))
        
#_______________________________________________________________________________________________________________________________________
    #                                                HEATER = 330 -.-
 
        
    @Rule(OR(motor_full_load_current('350.0'),motor_full_load_current('360.0'),motor_full_load_current('328.0')))
    def motor_350_360_328 (Self):
        Self.declare(heater_designation('330'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('400'))
          
          
          
          
          
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('350.0'),heater_designation('330'))))
    def vol_200_220_motor_350_heater_330 (Self):
        Self.declare(Horse_Power_B_200_220('150'))
          
          
          
            
            
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('360.0'),heater_designation('330'))))
    def vol_380_motor_360_heater_330 (Self):
        Self.declare(Horse_Power_A_380('270'))

    
          
    
    
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('328.0'),heater_designation('330'))))
    def vol_415_motor_328_heater_330 (Self):
        Self.declare(Horse_Power_A_415('270'))
        
#_______________________________________________________________________________________________________________________________________
    #                                                HEATER = 500 -.-
 
        
    @Rule(motor_full_load_current('420.0'))
    def motor_420 (Self):
        Self.declare(heater_designation('500'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('500'))
        
    @Rule(OR(motor_full_load_current('520.0'),motor_full_load_current('475.0'),motor_full_load_current('435.0')))
    def motor_520_475_435 (Self):
        Self.declare(heater_designation('500'))
        Self.declare(Fuse_VDE0660_9T_Time_delay('630'))
          
          
          
          
    @Rule(AND(Volt('200-220 V'),motor_full_load_current('420.0')))
    def vol_200_220_motor_420 (Self):
        Self.declare(Horse_Power_B_200_220('180'))
        
    @Rule(AND(Volt('200-220 V'),OR(motor_full_load_current('520.0'),heater_designation('500'))))
    def vol_200_220_motor_520_heater_500 (Self):
        Self.declare(Horse_Power_B_200_220('220'))
          
          
          
            
            
    @Rule(AND(Volt('380 V'),OR(motor_full_load_current('475.0'),heater_designation('500'))))
    def vol_380_motor_475_heater_500 (Self):
        Self.declare(Horse_Power_A_380('340'))

    
          
    
    
    @Rule(AND(Volt('415 V'),OR(motor_full_load_current('435.0'),heater_designation('500'))))
    def vol_415_motor_435_heater_500 (Self):
        Self.declare(Horse_Power_A_415('340'))                
    
#_____________________________________________________________________________________________________________________________________________________________
#_____________________________________________________________________________________________________________________________________________________________
#_____________________________________________________________________________________________________________________________________________________________
#________________________________________________________________THE END -.-__________________________________________________________________________________
#_____________________________________________________________________________________________________________________________________________________________
#_____________________________________________________________________________________________________________________________________________________________
#_____________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# # GUI Inputs -.-
# # Get The Result -.-

# %%
root = tk.Tk()
root.title('Design electrical panel -.-')

fname = "img6.gif"
bg_image = tk.PhotoImage(file=fname)

fnameA = "electric panel A.gif"
bg_imageA = tk.PhotoImage(file=fnameA)
    
fnameB = "electric panel B.gif"
bg_imageB = tk.PhotoImage(file=fnameB)
w = bg_image.width()
h = bg_image.height()


root.geometry("1000x625")

combostyle = ttk.Style()

combostyle.theme_create('combostyle', parent='alt',
                         settings = {'TCombobox':
                                     {'configure':
                                      {'selectbackground': 'red',
                                       'fieldbackground': 'silver',
                                       'background': 'white'
                                       }}}
                         )
combostyle.theme_use('combostyle') 

cv = tk.Canvas(width=w, height=h)
cv.pack(side='top', fill='both', expand='yes')

cv.create_image(0, 0, image=bg_image, anchor='nw')

cv.create_text(120, 10, text="Design your own electrical panel", fill="red", anchor='nw',font=('Cooper Black',32,'bold'))

cv.create_text(10, 100, text="Motor Rating << HP >>", fill="white", anchor='nw',font=('JF Flat',18,'bold'))
HP=StringVar()
combo4 = ttk.Combobox(cv,width=30,textvariable=HP)
combo4['values']=("Not Set","1/12","1/8","1/6","0.25","1/3","0.5","0.75","1","1.5","2","3","4","5","5.5","7.5","10","15","20","25","30","40","50","60","75","85","100","125","150","180","220","270","340")
combo4.pack()
combo4.place(x=30,y=140)
combo4.current(0)

cv.create_text(125, 180, text="Motor Full Load", fill="white", anchor='n',font=('JF Flat',18,'bold'))
cv.create_text(128, 210, text="Current << Ampere >>", fill="white", anchor='n',font=('JF Flat',18,'bold'))
MOTOR=StringVar()
combo = ttk.Combobox(cv,width=30,textvariable=MOTOR)
combo['values']=("0","0.3","0.4","0.5","0.65","0.7","0.8","0.85","1.1","1.2","1.5","1.6"," 1.9","2.0","2.1","2.6","2.7","3.5","3.6","4.5","5.0","5.1","6.1","6.3","6.8","7.5","8.0","8.5","8.7","11.0","11.5","11.8","12.2","15.0","15.2","16.0","20.0","21.0","22.0","26.5","28.0","30.0","35.0","37.0","39.0","40.0","43.0","50.0","54.0","57.0","62.0","67.0","72.0","75.0","79.0","86.0","98.0","100.0","105.0","124.0","130.0","140.0","148.0","160.0","168.0","180.0","190.0","202.0","205.0","230.0","245.0","270.0","290.0","295.0","328.0","350.0","360.0","420.0","435.0","475.0","520.0")
combo.pack()
combo.place(x=30,y=250)
combo.current(0)

cv.create_text(130, 290, text="Heater Designation", fill="white", anchor='n',font=('JF Flat',18,'bold'))
cv.create_text(125, 320, text="<< Ampere >>", fill="white", anchor='n',font=('JF Flat',18,'bold'))
HEATER=StringVar()
combo1 = ttk.Combobox(cv,width=30,textvariable=HEATER)
combo1['values']=("0","0.24","0.35","0.5","0.7","0.9","1.3","1.7","2.1","2.5","3.6","5","6.6","9","11","15","19","29","22","35","42","54","67","82","95","105","125","150","180","210","250","330","500")
combo1.pack()
combo1.place(x=30,y=360)
combo1.current(0)

cv.create_text(130, 400, text="Voltage << Volt >> ", fill="white", anchor='n',font=('JF Flat',18,'bold'))
VOLT=StringVar()
combo2 = ttk.Combobox(cv,width=30,textvariable=VOLT)
combo2['values']=("200-220 V","380 V","415 V")
combo2.pack()
combo2.place(x=30,y=440)
combo2.current(0)

cv.create_text(130, 480, text="Fuse << Ampere >>", fill="white", anchor='n',font=('JF Flat',18,'bold'))
FUSE=StringVar()
combo3 = ttk.Combobox(cv,width=30,textvariable=FUSE)
combo3['values']=("0","2","4","6","10","12","16","20","25","32","35","40","50","63","80","100","125","160","200","220","250","310","315","400","500","630")
combo3.pack()
combo3.place(x=30,y=520)
combo3.current(0)

cv.create_text(870, 100, text="Type of takeoff", fill="white", anchor='n',font=('JF Flat',18,'bold'))
TYPE=StringVar()
combo5 = ttk.Combobox(cv,width=30,textvariable=TYPE)
combo5['values']=("Not Set","A","B")
combo5.pack()
combo5.place(x=773,y=140)
combo5.current(0)

cv.create_text(870, 180, text="Type Designation", fill="white", anchor='n',font=('JF Flat',18,'bold'))
cv.create_text(870, 210, text="Magnetic Starter", fill="white", anchor='n',font=('JF Flat',18,'bold'))
MS=StringVar()
combo6 = ttk.Combobox(cv,width=30,textvariable=MS)
combo6['values']=("Not Set","10","11","18","20","21","25","35","50","65","80","105","125","150","180","220")
combo6.pack()
combo6.place(x=773,y=250)
combo6.current(0)

cv.create_text(870, 290, text="Type Designation", fill="white", anchor='n',font=('JF Flat',18,'bold'))
cv.create_text(870, 320, text="Contactor MCM,MCD", fill="white", anchor='n',font=('JF Flat',18,'bold'))
cv.create_text(870, 350, text="<< S-K >>", fill="white", anchor='n',font=('JF Flat',18,'bold'))
MCM_MCD=StringVar()
combo7 = ttk.Combobox(cv,width=30,textvariable=MCM_MCD)
combo7['values']=("Not Set","11","20","25","35","50","65","80","105")
combo7.pack()
combo7.place(x=773,y=390)
combo7.current(0)

cv.create_text(870, 430, text="Type Designation", fill="white", anchor='n',font=('JF Flat',18,'bold'))
cv.create_text(870, 460, text="Contactor MCS", fill="white", anchor='n',font=('JF Flat',18,'bold'))
cv.create_text(870, 490, text="<< S-K >>", fill="white", anchor='n',font=('JF Flat',18,'bold'))
MCS=StringVar()
combo8 = ttk.Combobox(cv,width=30,textvariable=MCS)
combo8['values']=("Not Set","12","18","20","25","35","50","65","80","105","125","150","180","220","300")
combo8.pack()
combo8.place(x=773,y=530)
combo8.current(0)

cv.create_text(500, 150, text="It is not necessary", fill="red", anchor='n',font=('Cooper Black',22,'bold'))
cv.create_text(500, 180, text="to enter all the values in order", fill="red", anchor='n',font=('Cooper Black',22,'bold'))
cv.create_text(500, 210, text="to get your panel", fill="red", anchor='n',font=('Cooper Black',22,'bold'))
cv.create_text(500, 240, text="-.-", fill="red", anchor='n',font=('Cooper Black',32,'bold'))

cv.create_text(500, 420, text="Show The Designed Panel", fill="white", anchor='n',font=('Cooper Black',25,'bold'))
button=ttk.Button(cv,text="Show The Designed Panel")
img = PhotoImage(file="i.png")
button.config(image=img)
button.pack()
button.place(x=440,y=480)
def buClick():
    TYPE = combo5.get()
    HP = combo4.get()
    print(HP)
    if HP == "1/12" or HP == "1/8" or HP == "1/6" or HP == "0.25" or HP == "1/3" or HP == "0.5" or HP == "0.75" or HP == "1" or HP == "1.5" or HP == "2":
        TYPE = "A"
    MOTOR = combo.get()
    print(MOTOR)
    if float(MOTOR) < 5 :
        if float(MOTOR)!=0 :
            TYPE = "A"
    if float(MOTOR) > 245 :
        if float(MOTOR)!=0 :
            TYPE = "B"
    HEATER = combo1.get()
    print(HEATER)
    if float(HEATER) < 9 :
        if float(HEATER)!=0 :
            TYPE = "A"
    if float(HEATER) > 210 :
        if float(HEATER)!=0 :
            TYPE = "B"
    VOLT=combo2.get()
    print(VOLT)
    FUSE = combo3.get()
    print(FUSE)
    if float(FUSE) < 12:
        if float(FUSE)!=0 :
            TYPE = "B"        
    print(TYPE)
    MS = combo6.get()
    print(MS)
    MCM_MCD = combo7.get()
    print(MCM_MCD)
    MCS = combo8.get()
    print(MCS)
    print('________________________________________________________________________________________________')
    engine = Board_Design()
    engine.reset()

    # Volt
    engine.declare(Volt(VOLT))

    # Boot Type    
    if TYPE != "Not Set":
        engine.declare(Boot_type(TYPE))

    if HP == "Not Set":
        # Motor Full Load Current
        if MOTOR != "0":
            engine.declare(motor_full_load_current(MOTOR))
        if MS != "Not Set":
            engine.declare(Type_designation_of_Magnetic_Startar('Any'))

        # Type designation of Contactor MCM and MCD    
        if MCM_MCD != "Not Set":
            engine.declare(Type_designation_of_Contactor_MCM_and_MCD('Any'))

        # Type designation of Contactor MCS    
        if MCS != "Not Set":
            engine.declare(Type_designation_of_Contactor_MCS('Any'))



    # Motor Rating    
    if HP != "Not Set":
        if VOLT == "200-220 V" and TYPE =="A":
            engine.declare(Horse_Power_A_200_220(HP))
        elif VOLT == "200-220 V" and TYPE =="B":
            engine.declare(Horse_Power_B_200_220(HP))
        elif VOLT == "380 V" and TYPE =="A":
            engine.declare(Horse_Power_A_380(HP))
        elif VOLT == "380 V" and TYPE =="B":
            engine.declare(Horse_Power_B_380(HP))
        elif VOLT == "415 V" and TYPE =="A":
            engine.declare(Horse_Power_A_415(HP))
        elif VOLT == "415 V" and TYPE =="B":
            engine.declare(Horse_Power_B_415(HP))
            
    print(VOLT)
    print(TYPE)
    print(MOTOR)
            
    engine.run()
    
    if TYPE == "A":
        winA = Toplevel()
        winA.geometry("1000x702")
        #fnameA = "C:\\Users\\Billy Cobix 2\\Desktop\\KBS\\electric panel A.gif"
        #bg_imageA = tk.PhotoImage(file=fnameA)
        wA = bg_imageA.width()
        hA = bg_imageA.height()
        cv1 = tk.Canvas(winA,width=wA, height=hA)
        cv1.configure(background='white')
        cv1.pack(side='top', fill='both', expand='yes')
        cv1.create_image(5, 0, image=bg_imageA, anchor='nw')
        cv1.create_text(660, 1, text="Specifications", fill="red", anchor='n',font=('JF Flat',32,'bold'))
        cv1.create_text(660, 100, text="Boot Type : A", fill="black", anchor='n',font=('JF Flat',18,'bold'))
        cv1.create_text(270, 84, text=Board_Design.MCCB_A, fill="red", anchor='n',font=('JF Flat',18,'bold'))
        cv1.create_text(255, 223, text=Board_Design.FUSE_A, fill="red", anchor='n',font=('JF Flat',18,'bold'))
        cv1.create_text(280, 406, text=Board_Design.MS_A, fill="red", anchor='n',font=('JF Flat',18,'bold'))
        cv1.create_text(270, 488, text=Board_Design.OLR_A, fill="red", anchor='n',font=('JF Flat',18,'bold'))
        cv1.create_text(250, 637, text=Board_Design.MOTOR_A, fill="red", anchor='n',font=('JF Flat',18,'bold'))

        cv1.create_text(660, 150, text=Board_Design.Text_A_HP, fill="black", anchor='n',font=('JF Flat',18,'bold'))
        cv1.create_text(660, 200, text=Board_Design.Text_A_A, fill="black", anchor='n',font=('JF Flat',18,'bold'))
        cv1.create_text(660, 250, text=Board_Design.Text_A_cA, fill="black", anchor='n',font=('JF Flat',16,'bold'))
        cv1.create_text(660, 300, text=Board_Design.Text_A_AA, fill="black", anchor='n',font=('JF Flat',18,'bold'))
        cv1.create_text(660, 350, text=Board_Design.Text_A_A1, fill="black", anchor='n',font=('JF Flat',18,'bold'))
        cv1.create_text(660, 400, text=Board_Design.Text_A_A2, fill="black", anchor='n',font=('JF Flat',18,'bold'))
        cv1.create_text(660, 450, text=Board_Design.Text_A_N, fill="black", anchor='n',font=('JF Flat',18,'bold'))
        cv1.create_text(660, 500, text=Board_Design.Text_A_A3, fill="black", anchor='n',font=('JF Flat',18,'bold'))
        cv1.create_text(660, 550, text=Board_Design.Text_A_m, fill="black", anchor='n',font=('JF Flat',18,'bold'))
        
    if TYPE == "B":
        winB = Toplevel()
        winB.geometry("1000x702")
        #fnameB = "C:\\Users\\Billy Cobix 2\\Desktop\\KBS\\electric panel B.gif"
        #bg_imageB = tk.PhotoImage(file=fnameB)
        wB = bg_imageB.width()
        hB = bg_imageB.height()
        cv2 = tk.Canvas(winB,width=wB, height=hB)
        cv2.configure(background='white')
        cv2.pack(side='top', fill='both', expand='yes')
        cv2.create_image(5, 0, image=bg_imageB, anchor='nw')
        cv2.create_text(530, 1, text="Specifications : ", fill="red", anchor='n',font=('JF Flat',20,'bold'))
        cv2.create_text(800, 1, text="Boot Type : B", fill="black", anchor='n',font=('JF Flat',20,'bold'))
        cv2.create_text(215, 64, text=Board_Design.MCCB_B, fill="red", anchor='n',font=('JF Flat',16,'bold'))
        cv2.create_text(203, 171, text=Board_Design.FUSE_B, fill="red", anchor='n',font=('JF Flat',16,'bold'))
        cv2.create_text(213, 240, text=Board_Design.OLR_B, fill="red", anchor='n',font=('JF Flat',16,'bold'))
        cv2.create_text(173, 381, text=Board_Design.MCM_B_MCD, fill="red", anchor='n',font=('JF Flat',16,'bold'))
        cv2.create_text(380, 380, text=Board_Design.MCM_B_MCD, fill="red", anchor='n',font=('JF Flat',16,'bold'))
        cv2.create_text(190, 614, text=Board_Design.MCS_B, fill="red", anchor='n',font=('JF Flat',16,'bold'))
        cv2.create_text(182, 493, text=Board_Design.MOTOR_B, fill="red", anchor='n',font=('JF Flat',16,'bold'))
        cv2.create_text(490, 514, text=Board_Design.MCM_B_MCD, fill="red", anchor='n',font=('JF Flat',12,'bold'))
        cv2.create_text(635, 502, text=Board_Design.MCM_B_MCD, fill="red", anchor='n',font=('JF Flat',12,'bold'))
        cv2.create_text(760, 500, text=Board_Design.MCS_B, fill="red", anchor='n',font=('JF Flat',12,'bold'))

        cv2.create_text(800, 40, text=Board_Design.TEXT_B_HP, fill="black", anchor='n',font=('JF Flat',16,'bold'))
        cv2.create_text(800, 70, text=Board_Design.TEXT_B_A, fill="black", anchor='n',font=('JF Flat',16,'bold'))
        cv2.create_text(700, 100, text=Board_Design.TEXT_B_C, fill="black", anchor='n',font=('JF Flat',16,'bold'))
        cv2.create_text(750, 130, text=Board_Design.TEXT_B_C1, fill="black", anchor='n',font=('JF Flat',16,'bold'))
        cv2.create_text(670, 160, text=Board_Design.TEXT_B_KP, fill="black", anchor='n',font=('JF Flat',16,'bold'))
        cv2.create_text(800, 190, text=Board_Design.TEXT_B_A1, fill="black", anchor='n',font=('JF Flat',16,'bold'))
        cv2.create_text(800, 220, text=Board_Design.TEXT_B_A2, fill="black", anchor='n',font=('JF Flat',16,'bold'))
        cv2.create_text(800, 250, text=Board_Design.TEXT_B_N, fill="black", anchor='n',font=('JF Flat',16,'bold'))
        cv2.create_text(800, 280, text=Board_Design.TEXT_B_A3, fill="black", anchor='n',font=('JF Flat',16,'bold'))
        cv2.create_text(770, 340, text=Board_Design.TEXT_B_m, fill="black", anchor='n',font=('JF Flat',14,'bold'))
        cv2.create_text(800, 310, text=Board_Design.TEXT_B_m1, fill="black", anchor='n',font=('JF Flat',16,'bold'))
        
button.config(command=buClick)

cv.mainloop()
# Out:
# Not Set
# 0.85
# 0
# 200-220 V
# 0
# A
# Not Set
# Not Set
# Not Set
# ________________________________________________________________________________________________
# 200-220 V
# A
# 0.85
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Billy Cobix 2\Anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-4-bba0bc09e885>", line 231, in buClick
#     cv1.create_text(660, 150, text=Board_Design.Text_A_HP, fill="black", anchor='n',font=('JF Flat',18,'bold'))
# AttributeError: type object 'Board_Design' has no attribute 'Text_A_HP'
